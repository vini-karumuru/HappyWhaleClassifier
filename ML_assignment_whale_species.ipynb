# %% [markdown]
# # Image Classification ML Assignment
#
# The goal of this assignment is to learn fundamentals of machine learning and image analysis. You will analyze images from Happy Whale, an organization that tracks whales globally, and modify a classifier for these images.
#
# Part 1: Walk through (Due Feb 27)
# - In class, we will walk through the provided code
# - This script has several functions that are written for you. For part 1, please do NOT modify any code unless it specifies to change it.
# - Answer the questions as you go through the code
#
# Part 2: Make modifications (Due Feb 27)
# - Change model parameters or other model aspects at least 3 times
# - Describe what happened when you made these changes
#
# Part 3: Create a team, get inspired and try a new approach to your model (Due March 6)
# - Have a group meeting and record your meeting with audio or video (you can record with zoom!)
#     - Start by discussing part 2 of the assignment:
#         - What approaches you each took to change the ML model in part 2
#         - What are similarities and differences between your approaches
#         - What types of changes improved model performance
#         - What types of changes made model performance worse
#         - Based on the whole group's work, what would y'all want to do next in terms of model optimization?
#     - Next, look at code and approaches from the [Happy Whales competition leaderboard](https://www.kaggle.com/competitions/happy-whale-and-dolphin/leaderboard).
#         - Is there any strategy that someone used that you could implement?
#             - Ex: learning rate value, # epochs, transformation strategy, or more complex changes to the models
#         - Are there strategies that you are interested in learning about?
#     - Lastly, make a plan for 1 more round of model optimization
#         - Assign each member something to attempt for training the model. Use your cumulative experience to decide the most important things to test.
#         - Group members can make as small as changing the value for a parameter or as big as changing the model.
# - Have each member complete their test
# - Share results with each other
# - Write a 1-3 paragraph summary on your group's attempts and recommendations moving forward
# - For Part 3: Turn in the audio/video recording of the group meeting, each member's code (uploaded to their original git repo), and the team's 1-3 paragraph summary over canvas.

# %% [markdown]
# ### Your choices on data
# You can chose between 3 datasets for this assignment. This jupyter notebook is set up using the Species dataset. If you change the dataset, you will need to change the number of classes parameter for the model.
# - Species = you will classify images by species (gray, killer, beluga, humpback, false killer, and common dolphin)
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
# - Species_all = you will classify images by species (minke, gray, killer, beluga, humpback, false killer, and bottlenose and common dolphin). There are a high number of images for bottlenose dolphins and minke whales which leads to this dataset being quite large. Due to the size of the dataset, it has a longer training time than the "Species" dataset.
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species_all
#   - Num classes: 8
# - Individuals = you will classify images by individuals. This is a much more challenging classification task because you have different individuals from different species. However, this was the original goal of the Happy Whale competition, so try challenging yourself to this important task!
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/individuals
#   - Num classes: 110
#
# You are NOT graded by the success of your model, so you are free to train the model on whichever dataset is more interesting to you. However, **everyone on your team for part 3 should be using the same dataset**.

# %% [markdown]
# ### Part 1

# %%
## Importing packages - Please DO NOT alter this box ##
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data.sampler import WeightedRandomSampler
torch.manual_seed(0)

from captum.attr import IntegratedGradients
from captum.attr import DeepLift
from captum.attr import NoiseTunnel
from captum.attr import visualization as viz

import torchvision
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

import os
import imageio
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tqdm import tqdm
from scipy.ndimage import binary_erosion
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

import wandb #comment this out if you are not using weights and biases
import random #comment this out if you are not using weights and biases

# Set device to cuda if it's available otherwise default to "cpu"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Loading in the dataset
#
# By default, this will load in the species dataset, this is the smallest dataset (i.e., it will be relatively fast to train) and has a simple goal (i.e., you will be able to create an accurate model). If you want a challenge, I highly encourage you to try the Species_all (a dataset with 2 additional species) or the individual dataset (a dataset where whales are characterized by individual rather than species).

# %%
images = "/projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species"

# %%
# We must turn our images into tensors, resize, and normalize them 
# We can also add additional transformations to images 
transform = transforms.Compose([transforms.ToTensor(), 
                                #We will start with a model called Resnet18 that is optimized for 224x224 images
                                #It is set to a very SMALL size initially so the model will train fast in class
                                transforms.Resize([32,32]),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences)
                               ])
all_images = datasets.ImageFolder(images, transform)
print(all_images)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# <font color='magenta'>What is the purpose(s) of transforming image data? (2 pts)

# %% [markdown]
# *Transforming image data helps standardize the images so that (a) they are in the format that can be taken in by the model (i.e. particular dimensions ideal for the model) and (b) differences in image characteristics that are not due to differences in the classification categories (i.e. lighting, quality, saturation, zoom, etc.) are minimized or are randomized across all images.*

# %% [markdown]
# <font color='green'>The below code completes the image transformations as coded in the above box.

# %%
all_images = datasets.ImageFolder(images, transform )
print(len(all_images))
print(all_images)
# Out:
# 2794
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Our classification labels will be converted to indices, we can determine which indices is which label using the below code

# %%
print(all_images.class_to_idx)
# Out:
# {'beluga': 0, 'common_dolphin': 1, 'false_killer_whale': 2, 'fin_whale': 3, 'gray_whale': 4, 'humpback_whale': 5}

# %% [markdown]
# <font color='green'>The below function is used to randomly select dataset images to evaluate how the transformations altered the images.

# %%
def show_random_dataset_image(dataset):
    idx = np.random.randint(0, len(dataset))    # take a random sample
    img, mask = dataset[idx]                    # get the image and the nuclei masks
    f, axarr = plt.subplots(1, 2)               # make two plots on one figure
    axarr[0].imshow(img[0], cmap="viridis")                     # show the image, cmap is the color map that the image is being shown in
    #axarr[1].imshow(mask[0])                    # show the masks
    _ = [ax.axis('off') for ax in axarr]        # remove the axes
    print('Image size is %s' % {img[0].shape})
    print(img.shape)
    plt.show()

# %%
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([32, 32])}
# torch.Size([3, 32, 32])

# %% [markdown]
# <font color='magenta'>What is the difference between image size and torch image size? (2 pts)

# %% [markdown]
# *Image size is the height and width of the image, whereas torch image size is the height and width plus batch size (number of images in the batch). When denoting the order of dimensions, batch size comes before the height and width.*

# %% [markdown]
# <font color='magenta'>Add a new transformation to the training data. After your first run of this model during class time, resize the image to 224x224 pixels. (2 pts)

# %%
## ADD YOUR TRANSFORMATION HERE
transform = transforms.Compose([
            transforms.Resize([224,224]), # Resize the image as our model is optimized for 224x224 pixels
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))
            transforms.RandomInvert(),
            transforms.RandomAdjustSharpness(sharpness_factor=2)])
all_images = datasets.ImageFolder(images, transform)
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([224, 224])}
# torch.Size([3, 224, 224])

# %% [markdown]
# <font color='magenta'>How did your transformation impact the images? (1 pt)

# %% [markdown]
# *I added a RandomInvert transformation, which inverts the colors of random images, as well as a RandomAdjustSharpness transformation, which changes the sharpness of the images at random.*

# %% [markdown]
# ### Creating datasets used in training and testing
#
# After loading in the data, we separate the data into training, validation, and testing datasets. The training data is inputted into the model during the training phase, and the model's predictions from this data is used to modulate the weights of the model. The validation data is used while the model trains, but the model is in a evaluation rather than training mode. The validation data gives us a real time view on how accurately the model is predicting our labels. The testing data is used after the model has completed training and tells us how successful our model will be with a novel dataset.
#
# Once creating these 3 datasets, we prepare dataloaders which are used to load the images into our models. These images are loaded in batches into the model (a parameter called batch size). Because our dataset is imbalanced, we use a weighted random sampler to select images for our batches in the dataloader. Therefore to create our dataloader, we start by creating a function to get weights, calculating weights, initiating our weighted random sampler, and then creating our dataloaders.

# %% [markdown]
# <font color='green'>The below code eastablishes the data split between training, validation, and testing.

# %%
train_size = int(0.7 * len(all_images))
val_size = int(0.15 * len(all_images))
test_size = len(all_images) - (train_size + val_size)
print(train_size, val_size, test_size)
assert train_size + val_size + test_size == len(all_images)
# Out:
# 1955 419 420

# %%
train_set, val_set, test_set = torch.utils.data.random_split(all_images, [train_size, val_size, test_size])

# %% [markdown]
# <font color='green'>The below function is used to get weights for the image classes.

# %%
def _get_weights(subset,full_dataset):
    ys = np.array([y for _, y in subset])
    counts = np.bincount(ys)
    label_weights = 1.0 / counts
    weights = label_weights[ys]

    print("Number of images per class:")
    for c, n, w in zip(full_dataset.classes, counts, label_weights):
        print(f"\t{c}:\tn={n}\tweight={w}")
        
    return weights

# %%
train_weights = _get_weights(train_set,all_images)
train_sampler = WeightedRandomSampler(train_weights, len(train_weights))
# Out:
# Number of images per class:
# 	beluga:	n=454	weight=0.0022026431718061676
# 	common_dolphin:	n=55	weight=0.01818181818181818
# 	false_killer_whale:	n=719	weight=0.0013908205841446453
# 	fin_whale:	n=124	weight=0.008064516129032258
# 	gray_whale:	n=39	weight=0.02564102564102564
# 	humpback_whale:	n=564	weight=0.0017730496453900709

# %% [markdown]
# <font color='magenta'>What is the impact of the class weight on how data is loaded into the model? What does it mean if a class has a low vs high weight? (2 pts)

# %% [markdown]
# <details>
#   <summary>Hint</summary>
#
# Check out this resource: https://towardsdatascience.com/demystifying-pytorchs-weightedrandomsampler-by-example-a68aceccb452

# %% [markdown]
# *The class weight helps ensure that the combination of images loaded into each batch is relatively class balanced, which would yield a better balanced accuracy. A class having a low weight signfies that this class is an overrepresented class in the dataset, and that a fewer proportion of images in the class will be seen in each batch. On the other hand, a class having a high weight signifies that this class is an underrepresented class, and a relatively higher proportion of images from this class will be seen in each batch.*

# %%
train_loader = DataLoader(train_set, batch_size=48, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=48, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=48, drop_last=True, shuffle=True)

# %% [markdown]
# ### Picking hyperparameters
#
# We can set a few hyperparameters that we decide and can tune. These include:
#
# - Learning rate = how much to update our model's parameters at each batch/epoch
# - batch size = the number of data samples to pass through the network before updating it
#     - If you change the batchsize below, make sure you ALSO change it in the commands above for the DataLoader
# - Number of epochs = # of times to iterate over the dataset in model training

# %%
learning_rate=1e-3
batchsize=48
epochs=5

# %% [markdown]
# <font color='magenta'>How would model training be impacted if we decreased our learning rate? What about if we increased it? (2 pts)

# %% [markdown]
# *Decreasing the learning rate would result in the model taking longer to train, as more possible weights/biases will be evaluated. Too low of a learning rate could mean that the model does not reach the optimal weights/biases (that yield the best performance). Increasing the learning rate would speed up training, as less values for weights/biases will be tested. Too high a learning rate could mean optimal parameters are skipped over.*

# %% [markdown]
# ### Training our model
#
# For part 1, we are going to use the model ResNet18. This is a published model for imaging data. Resnet18 is built from 4 residual blocks with two convolutional layers (Conv2d). Each convolutional layer is followed by a batch normalization step (BatchNorm2D) and a ReLU activation layer (ReLU). There is also a shortcut connection which adds input to output and allows the network to learn residual mapping.
#
# I provided the complete code for the ResNet18 model. In the future, if you want to use resnet18, you can load it simply by running `resnet18_model = torchvision.models.resnet18(weights = False, progress  = True, num_classes=XXX)`. We will look at the full code for the model so you can see how this model was created.

# %% [markdown]
# <font color='green'>The below code builds the residual blocks that ResNet18 uses in the model.

# %%
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    # Initializing method for the basic block (It's OOP!)
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

# %% [markdown]
# <font color='green'>The below code builds and initializes the ResNet18 model.

# %%
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)
print(model)
# Out:
# ResNet18(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %% [markdown]
# <font color='green'>The below code eastablishes the loss function and optimizer used in training the model.

# %%
#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# <font color='green'>The below functions are used to train, evaluate, and test the Machine Learning model.

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Vini-HappyWhale-SpeciesDataset-hyperparameters", ### Update with your name!
    config={"learning rate":0.001,
        "architecture": "CNN",
        "dataset": "Species",
        "epochs":5}
)

num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0
    batch=0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/vini/.netrc.
# wandb: Currently logged in as: vini_k (vini_k-university-of-oregon) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/vini/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_133612-vqzqk6fz</code>
# Syncing run <strong><a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/vqzqk6fz' target="_blank">Vini-HappyWhale-SpeciesDataset-hyperparameters</a></strong> to <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/vqzqk6fz' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/vqzqk6fz</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 12.50%
# Epoch [1/5] | Batch #2 | Batch Accuracy 17.71%
# Epoch [1/5] | Batch #3 | Batch Accuracy 15.97%
# Epoch [1/5] | Batch #4 | Batch Accuracy 15.10%
# Epoch [1/5] | Batch #5 | Batch Accuracy 17.92%
# Epoch [1/5] | Batch #6 | Batch Accuracy 20.14%
# Epoch [1/5] | Batch #7 | Batch Accuracy 20.54%
# Epoch [1/5] | Batch #8 | Batch Accuracy 21.09%
# Epoch [1/5] | Batch #9 | Batch Accuracy 20.37%
# Epoch [1/5] | Batch #10 | Batch Accuracy 22.92%
# Epoch [1/5] | Batch #11 | Batch Accuracy 24.05%
# Epoch [1/5] | Batch #12 | Batch Accuracy 24.65%
# Epoch [1/5] | Batch #13 | Batch Accuracy 25.64%
# Epoch [1/5] | Batch #14 | Batch Accuracy 25.89%
# Epoch [1/5] | Batch #15 | Batch Accuracy 26.53%
# Epoch [1/5] | Batch #16 | Batch Accuracy 27.34%
# Epoch [1/5] | Batch #17 | Batch Accuracy 28.06%
# Epoch [1/5] | Batch #18 | Batch Accuracy 28.01%
# Epoch [1/5] | Batch #19 | Batch Accuracy 28.40%
# Epoch [1/5] | Batch #20 | Batch Accuracy 28.33%
# Epoch [1/5] | Batch #21 | Batch Accuracy 29.07%
# Epoch [1/5] | Batch #22 | Batch Accuracy 29.45%
# Epoch [1/5] | Batch #23 | Batch Accuracy 29.71%
# Epoch [1/5] | Batch #24 | Batch Accuracy 30.82%
# Epoch [1/5] | Batch #25 | Batch Accuracy 31.42%
# Epoch [1/5] | Batch #26 | Batch Accuracy 31.89%
# Epoch [1/5] | Batch #27 | Batch Accuracy 32.25%
# Epoch [1/5] | Batch #28 | Batch Accuracy 32.51%
# Epoch [1/5] | Batch #29 | Batch Accuracy 32.97%
# Epoch [1/5] | Batch #30 | Batch Accuracy 33.40%
# Epoch [1/5] | Batch #31 | Batch Accuracy 34.14%
# Epoch [1/5] | Batch #32 | Batch Accuracy 34.77%
# Epoch [1/5] | Batch #33 | Batch Accuracy 34.85%
# Epoch [1/5] | Batch #34 | Batch Accuracy 35.29%
# Epoch [1/5] | Batch #35 | Batch Accuracy 35.54%
# Epoch [1/5] | Batch #36 | Batch Accuracy 35.88%
# Epoch [1/5] | Batch #37 | Batch Accuracy 36.32%
# Epoch [1/5] | Batch #38 | Batch Accuracy 36.68%
# Epoch [1/5] | Batch #39 | Batch Accuracy 36.70%
# Epoch [1/5] | Batch #40 | Batch Accuracy 36.61%
# Epoch [1/5] Train Loss: 1.7098 | Train Acc: 36.61% | Val Acc: 40.62% | Val Loss: 1.43%
# Epoch [2/5] | Batch #1 | Batch Accuracy 60.42%
# Epoch [2/5] | Batch #2 | Batch Accuracy 53.12%
# Epoch [2/5] | Batch #3 | Batch Accuracy 53.47%
# Epoch [2/5] | Batch #4 | Batch Accuracy 52.08%
# Epoch [2/5] | Batch #5 | Batch Accuracy 53.33%
# Epoch [2/5] | Batch #6 | Batch Accuracy 54.17%
# Epoch [2/5] | Batch #7 | Batch Accuracy 53.57%
# Epoch [2/5] | Batch #8 | Batch Accuracy 52.08%
# Epoch [2/5] | Batch #9 | Batch Accuracy 52.08%
# Epoch [2/5] | Batch #10 | Batch Accuracy 52.50%
# Epoch [2/5] | Batch #11 | Batch Accuracy 52.27%
# Epoch [2/5] | Batch #12 | Batch Accuracy 51.74%
# Epoch [2/5] | Batch #13 | Batch Accuracy 52.24%
# Epoch [2/5] | Batch #14 | Batch Accuracy 52.23%
# Epoch [2/5] | Batch #15 | Batch Accuracy 52.08%
# Epoch [2/5] | Batch #16 | Batch Accuracy 52.08%
# Epoch [2/5] | Batch #17 | Batch Accuracy 51.47%
# Epoch [2/5] | Batch #18 | Batch Accuracy 51.16%
# Epoch [2/5] | Batch #19 | Batch Accuracy 51.10%
# Epoch [2/5] | Batch #20 | Batch Accuracy 51.15%
# Epoch [2/5] | Batch #21 | Batch Accuracy 50.89%
# Epoch [2/5] | Batch #22 | Batch Accuracy 50.47%
# Epoch [2/5] | Batch #23 | Batch Accuracy 50.72%
# Epoch [2/5] | Batch #24 | Batch Accuracy 50.52%
# Epoch [2/5] | Batch #25 | Batch Accuracy 50.75%
# Epoch [2/5] | Batch #26 | Batch Accuracy 50.40%
# Epoch [2/5] | Batch #27 | Batch Accuracy 50.54%
# Epoch [2/5] | Batch #28 | Batch Accuracy 50.97%
# Epoch [2/5] | Batch #29 | Batch Accuracy 50.93%
# Epoch [2/5] | Batch #30 | Batch Accuracy 50.90%
# Epoch [2/5] | Batch #31 | Batch Accuracy 51.14%
# Epoch [2/5] | Batch #32 | Batch Accuracy 51.43%
# Epoch [2/5] | Batch #33 | Batch Accuracy 51.20%
# Epoch [2/5] | Batch #34 | Batch Accuracy 51.41%
# Epoch [2/5] | Batch #35 | Batch Accuracy 51.43%
# Epoch [2/5] | Batch #36 | Batch Accuracy 51.50%
# Epoch [2/5] | Batch #37 | Batch Accuracy 51.07%
# Epoch [2/5] | Batch #38 | Batch Accuracy 51.48%
# Epoch [2/5] | Batch #39 | Batch Accuracy 51.71%
# Epoch [2/5] | Batch #40 | Batch Accuracy 51.88%
# Epoch [2/5] Train Loss: 1.2918 | Train Acc: 51.88% | Val Acc: 47.40% | Val Loss: 1.23%
# Epoch [3/5] | Batch #1 | Batch Accuracy 64.58%
# Epoch [3/5] | Batch #2 | Batch Accuracy 61.46%
# Epoch [3/5] | Batch #3 | Batch Accuracy 56.25%
# Epoch [3/5] | Batch #4 | Batch Accuracy 56.25%
# Epoch [3/5] | Batch #5 | Batch Accuracy 55.42%
# Epoch [3/5] | Batch #6 | Batch Accuracy 56.25%
# Epoch [3/5] | Batch #7 | Batch Accuracy 55.95%
# Epoch [3/5] | Batch #8 | Batch Accuracy 56.25%
# Epoch [3/5] | Batch #9 | Batch Accuracy 56.71%
# Epoch [3/5] | Batch #10 | Batch Accuracy 56.88%
# Epoch [3/5] | Batch #11 | Batch Accuracy 57.95%
# Epoch [3/5] | Batch #12 | Batch Accuracy 57.64%
# Epoch [3/5] | Batch #13 | Batch Accuracy 56.89%
# Epoch [3/5] | Batch #14 | Batch Accuracy 56.40%
# Epoch [3/5] | Batch #15 | Batch Accuracy 55.97%
# Epoch [3/5] | Batch #16 | Batch Accuracy 55.34%
# Epoch [3/5] | Batch #17 | Batch Accuracy 55.51%
# Epoch [3/5] | Batch #18 | Batch Accuracy 55.56%
# Epoch [3/5] | Batch #19 | Batch Accuracy 55.59%
# Epoch [3/5] | Batch #20 | Batch Accuracy 55.83%
# Epoch [3/5] | Batch #21 | Batch Accuracy 55.75%
# Epoch [3/5] | Batch #22 | Batch Accuracy 55.68%
# Epoch [3/5] | Batch #23 | Batch Accuracy 55.98%
# Epoch [3/5] | Batch #24 | Batch Accuracy 55.30%
# Epoch [3/5] | Batch #25 | Batch Accuracy 55.42%
# Epoch [3/5] | Batch #26 | Batch Accuracy 55.37%
# Epoch [3/5] | Batch #27 | Batch Accuracy 55.32%
# Epoch [3/5] | Batch #28 | Batch Accuracy 55.36%
# Epoch [3/5] | Batch #29 | Batch Accuracy 55.60%
# Epoch [3/5] | Batch #30 | Batch Accuracy 55.83%
# Epoch [3/5] | Batch #31 | Batch Accuracy 55.78%
# Epoch [3/5] | Batch #32 | Batch Accuracy 55.79%
# Epoch [3/5] | Batch #33 | Batch Accuracy 55.56%
# Epoch [3/5] | Batch #34 | Batch Accuracy 55.45%
# Epoch [3/5] | Batch #35 | Batch Accuracy 55.77%
# Epoch [3/5] | Batch #36 | Batch Accuracy 55.61%
# Epoch [3/5] | Batch #37 | Batch Accuracy 55.74%
# Epoch [3/5] | Batch #38 | Batch Accuracy 55.65%
# Epoch [3/5] | Batch #39 | Batch Accuracy 55.82%
# Epoch [3/5] | Batch #40 | Batch Accuracy 55.99%
# Epoch [3/5] Train Loss: 1.1625 | Train Acc: 55.99% | Val Acc: 47.14% | Val Loss: 1.22%
# Epoch [4/5] | Batch #1 | Batch Accuracy 39.58%
# Epoch [4/5] | Batch #2 | Batch Accuracy 52.08%
# Epoch [4/5] | Batch #3 | Batch Accuracy 54.86%
# Epoch [4/5] | Batch #4 | Batch Accuracy 55.73%
# Epoch [4/5] | Batch #5 | Batch Accuracy 53.33%
# Epoch [4/5] | Batch #6 | Batch Accuracy 53.12%
# Epoch [4/5] | Batch #7 | Batch Accuracy 54.46%
# Epoch [4/5] | Batch #8 | Batch Accuracy 54.95%
# Epoch [4/5] | Batch #9 | Batch Accuracy 55.32%
# Epoch [4/5] | Batch #10 | Batch Accuracy 56.04%
# Epoch [4/5] | Batch #11 | Batch Accuracy 56.44%
# Epoch [4/5] | Batch #12 | Batch Accuracy 55.90%
# Epoch [4/5] | Batch #13 | Batch Accuracy 55.93%
# Epoch [4/5] | Batch #14 | Batch Accuracy 56.55%
# Epoch [4/5] | Batch #15 | Batch Accuracy 55.83%
# Epoch [4/5] | Batch #16 | Batch Accuracy 55.47%
# Epoch [4/5] | Batch #17 | Batch Accuracy 56.00%
# Epoch [4/5] | Batch #18 | Batch Accuracy 56.71%
# Epoch [4/5] | Batch #19 | Batch Accuracy 57.02%
# Epoch [4/5] | Batch #20 | Batch Accuracy 56.98%
# Epoch [4/5] | Batch #21 | Batch Accuracy 56.55%
# Epoch [4/5] | Batch #22 | Batch Accuracy 56.72%
# Epoch [4/5] | Batch #23 | Batch Accuracy 56.43%
# Epoch [4/5] | Batch #24 | Batch Accuracy 56.77%
# Epoch [4/5] | Batch #25 | Batch Accuracy 56.50%
# Epoch [4/5] | Batch #26 | Batch Accuracy 56.65%
# Epoch [4/5] | Batch #27 | Batch Accuracy 56.64%
# Epoch [4/5] | Batch #28 | Batch Accuracy 56.55%
# Epoch [4/5] | Batch #29 | Batch Accuracy 55.96%
# Epoch [4/5] | Batch #30 | Batch Accuracy 55.76%
# Epoch [4/5] | Batch #31 | Batch Accuracy 55.58%
# Epoch [4/5] | Batch #32 | Batch Accuracy 55.60%
# Epoch [4/5] | Batch #33 | Batch Accuracy 55.74%
# Epoch [4/5] | Batch #34 | Batch Accuracy 55.82%
# Epoch [4/5] | Batch #35 | Batch Accuracy 56.25%
# Epoch [4/5] | Batch #36 | Batch Accuracy 56.37%
# Epoch [4/5] | Batch #37 | Batch Accuracy 56.42%
# Epoch [4/5] | Batch #38 | Batch Accuracy 56.96%
# Epoch [4/5] | Batch #39 | Batch Accuracy 56.78%
# Epoch [4/5] | Batch #40 | Batch Accuracy 56.67%
# Epoch [4/5] Train Loss: 1.1243 | Train Acc: 56.67% | Val Acc: 50.52% | Val Loss: 1.17%
# Epoch [5/5] | Batch #1 | Batch Accuracy 54.17%
# Epoch [5/5] | Batch #2 | Batch Accuracy 55.21%
# Epoch [5/5] | Batch #3 | Batch Accuracy 59.03%
# Epoch [5/5] | Batch #4 | Batch Accuracy 61.46%
# Epoch [5/5] | Batch #5 | Batch Accuracy 60.00%
# Epoch [5/5] | Batch #6 | Batch Accuracy 60.76%
# Epoch [5/5] | Batch #7 | Batch Accuracy 60.12%
# Epoch [5/5] | Batch #8 | Batch Accuracy 59.11%
# Epoch [5/5] | Batch #9 | Batch Accuracy 56.94%
# Epoch [5/5] | Batch #10 | Batch Accuracy 57.71%
# Epoch [5/5] | Batch #11 | Batch Accuracy 56.63%
# Epoch [5/5] | Batch #12 | Batch Accuracy 57.99%
# Epoch [5/5] | Batch #13 | Batch Accuracy 58.97%
# Epoch [5/5] | Batch #14 | Batch Accuracy 59.23%
# Epoch [5/5] | Batch #15 | Batch Accuracy 59.72%
# Epoch [5/5] | Batch #16 | Batch Accuracy 59.51%
# Epoch [5/5] | Batch #17 | Batch Accuracy 59.31%
# Epoch [5/5] | Batch #18 | Batch Accuracy 59.38%
# Epoch [5/5] | Batch #19 | Batch Accuracy 59.76%
# Epoch [5/5] | Batch #20 | Batch Accuracy 59.69%
# Epoch [5/5] | Batch #21 | Batch Accuracy 59.72%
# Epoch [5/5] | Batch #22 | Batch Accuracy 59.75%
# Epoch [5/5] | Batch #23 | Batch Accuracy 59.60%
# Epoch [5/5] | Batch #24 | Batch Accuracy 59.72%
# Epoch [5/5] | Batch #25 | Batch Accuracy 59.92%
# Epoch [5/5] | Batch #26 | Batch Accuracy 59.46%
# Epoch [5/5] | Batch #27 | Batch Accuracy 59.41%
# Epoch [5/5] | Batch #28 | Batch Accuracy 59.30%
# Epoch [5/5] | Batch #29 | Batch Accuracy 59.48%
# Epoch [5/5] | Batch #30 | Batch Accuracy 59.17%
# Epoch [5/5] | Batch #31 | Batch Accuracy 58.74%
# Epoch [5/5] | Batch #32 | Batch Accuracy 58.46%
# Epoch [5/5] | Batch #33 | Batch Accuracy 58.46%
# Epoch [5/5] | Batch #34 | Batch Accuracy 58.58%
# Epoch [5/5] | Batch #35 | Batch Accuracy 58.10%
# Epoch [5/5] | Batch #36 | Batch Accuracy 58.22%
# Epoch [5/5] | Batch #37 | Batch Accuracy 58.22%
# Epoch [5/5] | Batch #38 | Batch Accuracy 58.33%
# Epoch [5/5] | Batch #39 | Batch Accuracy 58.28%
# Epoch [5/5] | Batch #40 | Batch Accuracy 58.23%
# Epoch [5/5] Train Loss: 1.0829 | Train Acc: 58.23% | Val Acc: 48.70% | Val Loss: 1.21%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▃▂▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▆▆█▇</td></tr><tr><td>validation_loss</td><td>█▃▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>1.08288</td></tr><tr><td>validation_accuracy</td><td>48.69792</td></tr><tr><td>validation_loss</td><td>1.20732</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Vini-HappyWhale-SpeciesDataset-hyperparameters</strong> at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/vqzqk6fz' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/vqzqk6fz</a><br> View project at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_133612-vqzqk6fz/logs</code>

# %% [markdown]
# #### For our class training, run the below model and consider the success of the model training.
#
# <font color='magenta'>What is your starting accuracy and final accuracy? What happened to the model to change the accuracy from epoch 1 to 5? (2 pts)

# %% [markdown]
# *The starting validation accuracy for the first epoch was 40.62% and the final accuracy in the 5th epoch was 48.70%. As the model trained, it went through variations of weights/biases and kept going towards the direction that yielded lower loss (and thereby higher accuracy), using a gradient descent optimization algorithm.*

# %%
plt.plot(range(num_epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(num_epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()

# %% [markdown]
# <font color='green'>After running the model and calculating the overall accuracy, we can examine the data via a confusion matrix which highlights the accuracy by class.

# %%
# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# Plot confusion matrix 
# orginally from Runqi Yang; 
# see https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
def cm_analysis(y_true, y_pred, title, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale']
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
                              
    x_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for x-axis
    y_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for y-axis
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels, cmap = "viridis")
    ax.set_title(title)

## This plot only contains the test set of data
## The test set of data has not been seen by the model yet
y_pred, y_true = predict(model, test_set)

print(y_true)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# [2 0 5 2 0 0 5 0 2 5 2 3 0 0 5 3 2 2 2 2 2 5 5 5 2 2 2 2 0 4 0 5 5 2 5 0 0
#  2 5 0 5 0 5 0 5 5 2 0 5 0 0 5 5 2 0 0 5 0 5 5 5 2 5 2 5 0 5 5 2 2 2 2 3 0
#  0 5 0 0 2 5 2 5 5 2 0 0 5 5 5 5 5 0 0 2 5 0 0 2 3 5 2 5 5 2 2 2 4 2 5 0 2
#  0 0 0 2 2 1 1 2 5 5 5 0 0 5 5 0 5 0 2 5 3 2 3 2 2 2 2 0 5 0 0 3 2 2 2 0 2
#  2 0 5 0 0 0 5 2 0 5 5 0 4 2 2 3 3 2 0 0 2 2 2 5 4 5 5 0 0 2 5 2 3 5 0 4 5
#  2 0 2 0 2 2 0 4 3 5 5 2 0 5 5 4 5 3 0 2 5 5 0 5 0 2 2 5 2 2 0 5 2 5 5 5 2
#  5 2 2 0 0 0 3 2 0 5 3 2 3 3 0 3 0 2 1 5 2 2 2 4 4 2 2 0 2 5 2 2 5 2 1 2 5
#  1 5 4 3 2 1 2 0 4 4 5 3 3 4 5 2 2 2 2 0 2 0 2 5 5 5 2 0 2 0 5 2 2 2 5 5 2
#  5 2 0 3 5 0 5 0 2 5 2 2 5 5 2 1 0 2 5 2 0 2 2 5 3 2 0 2 5 5 4 0 3 0 0 2 5
#  5 5 5 0 0 5 2 2 2 2 0 5 2 0 2 0 0 5 2 2 5 5 0 0 0 5 3 2 5 5 0 3 2 5 2 0 2
#  2 5 2 3 5 2 2 5 2 4 5 2 2 2 5 5 5 0 5 2 5 2 2 2 0 0 5 5 5 0 0 5 5 0 2 0 5
#  5 5 5 2 5 2 2 3 3 0 5 0 0]
# /tmp/ipykernel_1918377/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# ### What features did the model use to make decisions?
#
# Based on the confusion matrices and validation loss, it is clear that the model is learning. To determine the features that are involved in decision making, there are a few possible approaches. One options is shown below, integrated gradients.

# %% [markdown]
# #### Understanding feature importance using Integrated Gradients
#
# <font color='green'>Integrated gradients is an attribution method. Attribution methods score the input data based on the prediction that the model makes using scores for each feature. The gradient is the signal that tells the network how much to increase or decrease a certain weight in the network during backpropogation. These gradients are overlaid onto the images to showcase the regions on the images that influence the weights.
#
# Run the below code.

# %%
def visualize_ig(idx, 
                 _train_dataset=train_set, 
                 _test_dataset=test_set):
        
    # Get corresponding input and target tensors:
    input_tensor = _test_dataset[idx][0].unsqueeze(0)
    input_tensor.requires_grad = True
    target = _test_dataset[idx][1]
    
    # We will use the IntegratedGradients algorithm:
    algorithm = IntegratedGradients(model)
    
    # First we clear the gradients from the model:
    model.zero_grad()
    
    # Run attribution:
    attr_ig, delta = algorithm.attribute(input_tensor,
                                          target=target,
                                          baselines=input_tensor * 0,
                                          return_convergence_delta=True
                                        )
    
    # Integrated Gradients:
    attr_ig = np.transpose(attr_ig[0].cpu().detach().numpy(), (1, 2, 0))
    
    # Original image:
    original_image = np.transpose((_test_dataset[idx][0].detach().numpy() * 0.5) + 0.5, (1, 2, 0))
    
    print("Annotated whale species", test_true[idx])
    plt.imshow(original_image)
    
    
    print("Predicted whale species", test_pred[idx])


    # This visualises the attribution of labels to 
    viz.visualize_image_attr(attr_ig, 
                             original_image, 
                             method="blended_heat_map",
                             sign="all",
                             show_colorbar=True, 
                             title="Overlayed Integrated Gradients")

test_pred, test_true = predict(model, test_set)

visualize_ig(0)
visualize_ig(8)
visualize_ig(20)
visualize_ig(32)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.023703814..1.7335817].
# Annotated whale species 2
# Predicted whale species 2
# Annotated whale species 0
# Predicted whale species 0
# Annotated whale species 5
# Predicted whale species 4
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.20287573..1.6907698].
# Annotated whale species 5
# Predicted whale species 3

# %% [markdown]
# <font color='magenta'>Does the integrated gradient show what types of features the model used to classify the images? Do you notice any potential problems? (2 pts)

# %% [markdown]
# *The integrated gradients show the pixels/groups of pixels that the model is using to inform weights/biases. I am having trouble interpreting these because the overlayed gradients are very noisy, particularly the ones that the model did not classify correctly, suggesting that the model is not able to find distinct groups of features that help it classify. Even the ones that the model was able to classify correctly (the top 2), there is no pattern to the gradient itself, other than maybe somewhat darker colors near the border of the whale fin? It seems like integrated gradients need to be manually inspected; I am not sure if there is a way to mass analyze integrated gradients computationally in order to find recurrent features that tend to be weighted more by the model.*

# %% [markdown]
# ## Part 2
#
# Now that you have a sense for how to train a machine learning model, your task is to improve the success of our classification model.
#
# **In three separate training events, make one (or more) modifications to the model training process, re-train the model, and report out your changes and whether they increased model accuracy. Why did you chose your particular change (curiousity, hypothesis, ect.)? Do you have ideas why your modifications were/were not successful?**
#
# Types of changes that you can make include:
# - [Using the pre-trained weights for ResNet18 (transfer learning)](https://docs.pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - Changing hyperparameters (learning rate, batch size)
# - [Changing transformation approach](https://docs.pytorch.org/vision/0.11/auto_examples/plot_transforms.html#sphx-glr-auto-examples-plot-transforms-py)
# - [Changing the optimizer](https://docs.pytorch.org/docs/stable/optim.html)
# - [Changing the model to a different pre-made model architecture](https://docs.pytorch.org/vision/main/models.html)
# - Modifying the ResNet18 model
# - Coming up with a whole new model!
#
# If you decide to change any lines of code that are not in the below box, please add them to the box (DO NOT MODIFY ANY CODE ABOVE THIS MARKDOWN BOX - IT MAY BREAK PART 1).
#
# If your changes are ambitious, the code may take hours to run. If this is the case, please consider turning this notebook into a python script and running it via sBATCH.
#
# **Please note, you will NOT be graded by the success of your classifiers! It is okay if you are unable to improve the accuracy of the classifier**

# %% [markdown]
# #### Your Model 1 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# *I changed the optimizer from Adam to SGD (Stochastic Gradient Descent) with an added momentum hyperparameter. Because the model consistently has higher training accuracy than validation accuracy, SGD might help it generalize better. The momentum value I chose (0.9) was the default recommended online.*

# %%
batchsize = 48
learning_rate=1e-3
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum = 0.9)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Vini-HappyWhale-SpeciesDataset-hyperparameters_mod1", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":48}  # possibly update
) 


num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0
    batch=0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod1</strong> at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/869nea0s' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/869nea0s</a><br> View project at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_140329-869nea0s/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/vini/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_140722-w9qmsuzx</code>
# Syncing run <strong><a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/w9qmsuzx' target="_blank">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod1</a></strong> to <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/w9qmsuzx' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/w9qmsuzx</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 14.58%
# Epoch [1/5] | Batch #2 | Batch Accuracy 16.67%
# Epoch [1/5] | Batch #3 | Batch Accuracy 16.67%
# Epoch [1/5] | Batch #4 | Batch Accuracy 16.67%
# Epoch [1/5] | Batch #5 | Batch Accuracy 17.08%
# Epoch [1/5] | Batch #6 | Batch Accuracy 18.40%
# Epoch [1/5] | Batch #7 | Batch Accuracy 19.05%
# Epoch [1/5] | Batch #8 | Batch Accuracy 19.27%
# Epoch [1/5] | Batch #9 | Batch Accuracy 19.68%
# Epoch [1/5] | Batch #10 | Batch Accuracy 20.00%
# Epoch [1/5] | Batch #11 | Batch Accuracy 22.16%
# Epoch [1/5] | Batch #12 | Batch Accuracy 22.05%
# Epoch [1/5] | Batch #13 | Batch Accuracy 22.12%
# Epoch [1/5] | Batch #14 | Batch Accuracy 22.92%
# Epoch [1/5] | Batch #15 | Batch Accuracy 22.92%
# Epoch [1/5] | Batch #16 | Batch Accuracy 23.44%
# Epoch [1/5] | Batch #17 | Batch Accuracy 24.26%
# Epoch [1/5] | Batch #18 | Batch Accuracy 25.46%
# Epoch [1/5] | Batch #19 | Batch Accuracy 25.55%
# Epoch [1/5] | Batch #20 | Batch Accuracy 26.67%
# Epoch [1/5] | Batch #21 | Batch Accuracy 27.18%
# Epoch [1/5] | Batch #22 | Batch Accuracy 27.56%
# Epoch [1/5] | Batch #23 | Batch Accuracy 28.35%
# Epoch [1/5] | Batch #24 | Batch Accuracy 28.73%
# Epoch [1/5] | Batch #25 | Batch Accuracy 29.33%
# Epoch [1/5] | Batch #26 | Batch Accuracy 29.49%
# Epoch [1/5] | Batch #27 | Batch Accuracy 29.86%
# Epoch [1/5] | Batch #28 | Batch Accuracy 30.06%
# Epoch [1/5] | Batch #29 | Batch Accuracy 30.75%
# Epoch [1/5] | Batch #30 | Batch Accuracy 31.04%
# Epoch [1/5] | Batch #31 | Batch Accuracy 31.65%
# Epoch [1/5] | Batch #32 | Batch Accuracy 31.38%
# Epoch [1/5] | Batch #33 | Batch Accuracy 31.69%
# Epoch [1/5] | Batch #34 | Batch Accuracy 32.17%
# Epoch [1/5] | Batch #35 | Batch Accuracy 32.80%
# Epoch [1/5] | Batch #36 | Batch Accuracy 33.45%
# Epoch [1/5] | Batch #37 | Batch Accuracy 33.67%
# Epoch [1/5] | Batch #38 | Batch Accuracy 33.94%
# Epoch [1/5] | Batch #39 | Batch Accuracy 34.46%
# Epoch [1/5] | Batch #40 | Batch Accuracy 34.84%
# Epoch [1/5] Train Loss: 1.5503 | Train Acc: 34.84% | Val Acc: 36.20% | Val Loss: 1.34%
# Epoch [2/5] | Batch #1 | Batch Accuracy 54.17%
# Epoch [2/5] | Batch #2 | Batch Accuracy 53.12%
# Epoch [2/5] | Batch #3 | Batch Accuracy 51.39%
# Epoch [2/5] | Batch #4 | Batch Accuracy 54.17%
# Epoch [2/5] | Batch #5 | Batch Accuracy 52.08%
# Epoch [2/5] | Batch #6 | Batch Accuracy 52.08%
# Epoch [2/5] | Batch #7 | Batch Accuracy 53.27%
# Epoch [2/5] | Batch #8 | Batch Accuracy 52.60%
# Epoch [2/5] | Batch #9 | Batch Accuracy 52.55%
# Epoch [2/5] | Batch #10 | Batch Accuracy 52.50%
# Epoch [2/5] | Batch #11 | Batch Accuracy 52.27%
# Epoch [2/5] | Batch #12 | Batch Accuracy 52.26%
# Epoch [2/5] | Batch #13 | Batch Accuracy 52.40%
# Epoch [2/5] | Batch #14 | Batch Accuracy 51.79%
# Epoch [2/5] | Batch #15 | Batch Accuracy 51.25%
# Epoch [2/5] | Batch #16 | Batch Accuracy 51.95%
# Epoch [2/5] | Batch #17 | Batch Accuracy 52.33%
# Epoch [2/5] | Batch #18 | Batch Accuracy 53.12%
# Epoch [2/5] | Batch #19 | Batch Accuracy 52.96%
# Epoch [2/5] | Batch #20 | Batch Accuracy 53.12%
# Epoch [2/5] | Batch #21 | Batch Accuracy 53.57%
# Epoch [2/5] | Batch #22 | Batch Accuracy 53.98%
# Epoch [2/5] | Batch #23 | Batch Accuracy 54.08%
# Epoch [2/5] | Batch #24 | Batch Accuracy 54.17%
# Epoch [2/5] | Batch #25 | Batch Accuracy 54.67%
# Epoch [2/5] | Batch #26 | Batch Accuracy 55.21%
# Epoch [2/5] | Batch #27 | Batch Accuracy 55.09%
# Epoch [2/5] | Batch #28 | Batch Accuracy 54.84%
# Epoch [2/5] | Batch #29 | Batch Accuracy 55.03%
# Epoch [2/5] | Batch #30 | Batch Accuracy 55.35%
# Epoch [2/5] | Batch #31 | Batch Accuracy 55.58%
# Epoch [2/5] | Batch #32 | Batch Accuracy 55.99%
# Epoch [2/5] | Batch #33 | Batch Accuracy 55.81%
# Epoch [2/5] | Batch #34 | Batch Accuracy 56.19%
# Epoch [2/5] | Batch #35 | Batch Accuracy 55.95%
# Epoch [2/5] | Batch #36 | Batch Accuracy 55.73%
# Epoch [2/5] | Batch #37 | Batch Accuracy 55.80%
# Epoch [2/5] | Batch #38 | Batch Accuracy 55.81%
# Epoch [2/5] | Batch #39 | Batch Accuracy 55.66%
# Epoch [2/5] | Batch #40 | Batch Accuracy 55.83%
# Epoch [2/5] Train Loss: 1.1680 | Train Acc: 55.83% | Val Acc: 42.45% | Val Loss: 1.30%
# Epoch [3/5] | Batch #1 | Batch Accuracy 68.75%
# Epoch [3/5] | Batch #2 | Batch Accuracy 69.79%
# Epoch [3/5] | Batch #3 | Batch Accuracy 67.36%
# Epoch [3/5] | Batch #4 | Batch Accuracy 65.62%
# Epoch [3/5] | Batch #5 | Batch Accuracy 65.00%
# Epoch [3/5] | Batch #6 | Batch Accuracy 64.58%
# Epoch [3/5] | Batch #7 | Batch Accuracy 64.58%
# Epoch [3/5] | Batch #8 | Batch Accuracy 63.02%
# Epoch [3/5] | Batch #9 | Batch Accuracy 63.89%
# Epoch [3/5] | Batch #10 | Batch Accuracy 64.17%
# Epoch [3/5] | Batch #11 | Batch Accuracy 64.20%
# Epoch [3/5] | Batch #12 | Batch Accuracy 64.06%
# Epoch [3/5] | Batch #13 | Batch Accuracy 62.98%
# Epoch [3/5] | Batch #14 | Batch Accuracy 62.50%
# Epoch [3/5] | Batch #15 | Batch Accuracy 61.94%
# Epoch [3/5] | Batch #16 | Batch Accuracy 62.24%
# Epoch [3/5] | Batch #17 | Batch Accuracy 63.24%
# Epoch [3/5] | Batch #18 | Batch Accuracy 63.77%
# Epoch [3/5] | Batch #19 | Batch Accuracy 64.47%
# Epoch [3/5] | Batch #20 | Batch Accuracy 64.27%
# Epoch [3/5] | Batch #21 | Batch Accuracy 63.89%
# Epoch [3/5] | Batch #22 | Batch Accuracy 63.92%
# Epoch [3/5] | Batch #23 | Batch Accuracy 64.22%
# Epoch [3/5] | Batch #24 | Batch Accuracy 64.32%
# Epoch [3/5] | Batch #25 | Batch Accuracy 64.42%
# Epoch [3/5] | Batch #26 | Batch Accuracy 64.74%
# Epoch [3/5] | Batch #27 | Batch Accuracy 64.81%
# Epoch [3/5] | Batch #28 | Batch Accuracy 64.29%
# Epoch [3/5] | Batch #29 | Batch Accuracy 64.15%
# Epoch [3/5] | Batch #30 | Batch Accuracy 64.10%
# Epoch [3/5] | Batch #31 | Batch Accuracy 64.38%
# Epoch [3/5] | Batch #32 | Batch Accuracy 64.52%
# Epoch [3/5] | Batch #33 | Batch Accuracy 64.65%
# Epoch [3/5] | Batch #34 | Batch Accuracy 64.58%
# Epoch [3/5] | Batch #35 | Batch Accuracy 64.40%
# Epoch [3/5] | Batch #36 | Batch Accuracy 64.64%
# Epoch [3/5] | Batch #37 | Batch Accuracy 64.25%
# Epoch [3/5] | Batch #38 | Batch Accuracy 64.58%
# Epoch [3/5] | Batch #39 | Batch Accuracy 64.26%
# Epoch [3/5] | Batch #40 | Batch Accuracy 64.38%
# Epoch [3/5] Train Loss: 0.9805 | Train Acc: 64.38% | Val Acc: 55.99% | Val Loss: 0.95%
# Epoch [4/5] | Batch #1 | Batch Accuracy 66.67%
# Epoch [4/5] | Batch #2 | Batch Accuracy 66.67%
# Epoch [4/5] | Batch #3 | Batch Accuracy 70.83%
# Epoch [4/5] | Batch #4 | Batch Accuracy 71.88%
# Epoch [4/5] | Batch #5 | Batch Accuracy 71.67%
# Epoch [4/5] | Batch #6 | Batch Accuracy 71.88%
# Epoch [4/5] | Batch #7 | Batch Accuracy 70.24%
# Epoch [4/5] | Batch #8 | Batch Accuracy 69.53%
# Epoch [4/5] | Batch #9 | Batch Accuracy 69.44%
# Epoch [4/5] | Batch #10 | Batch Accuracy 69.38%
# Epoch [4/5] | Batch #11 | Batch Accuracy 70.08%
# Epoch [4/5] | Batch #12 | Batch Accuracy 69.79%
# Epoch [4/5] | Batch #13 | Batch Accuracy 69.87%
# Epoch [4/5] | Batch #14 | Batch Accuracy 70.54%
# Epoch [4/5] | Batch #15 | Batch Accuracy 70.28%
# Epoch [4/5] | Batch #16 | Batch Accuracy 69.92%
# Epoch [4/5] | Batch #17 | Batch Accuracy 69.98%
# Epoch [4/5] | Batch #18 | Batch Accuracy 69.91%
# Epoch [4/5] | Batch #19 | Batch Accuracy 70.39%
# Epoch [4/5] | Batch #20 | Batch Accuracy 70.52%
# Epoch [4/5] | Batch #21 | Batch Accuracy 70.24%
# Epoch [4/5] | Batch #22 | Batch Accuracy 70.45%
# Epoch [4/5] | Batch #23 | Batch Accuracy 70.38%
# Epoch [4/5] | Batch #24 | Batch Accuracy 70.31%
# Epoch [4/5] | Batch #25 | Batch Accuracy 70.50%
# Epoch [4/5] | Batch #26 | Batch Accuracy 70.27%
# Epoch [4/5] | Batch #27 | Batch Accuracy 70.14%
# Epoch [4/5] | Batch #28 | Batch Accuracy 69.79%
# Epoch [4/5] | Batch #29 | Batch Accuracy 70.11%
# Epoch [4/5] | Batch #30 | Batch Accuracy 70.00%
# Epoch [4/5] | Batch #31 | Batch Accuracy 70.30%
# Epoch [4/5] | Batch #32 | Batch Accuracy 70.51%
# Epoch [4/5] | Batch #33 | Batch Accuracy 70.77%
# Epoch [4/5] | Batch #34 | Batch Accuracy 70.65%
# Epoch [4/5] | Batch #35 | Batch Accuracy 70.30%
# Epoch [4/5] | Batch #36 | Batch Accuracy 70.08%
# Epoch [4/5] | Batch #37 | Batch Accuracy 70.27%
# Epoch [4/5] | Batch #38 | Batch Accuracy 70.34%
# Epoch [4/5] | Batch #39 | Batch Accuracy 70.25%
# Epoch [4/5] | Batch #40 | Batch Accuracy 70.47%
# Epoch [4/5] Train Loss: 0.8007 | Train Acc: 70.47% | Val Acc: 53.39% | Val Loss: 0.98%
# Epoch [5/5] | Batch #1 | Batch Accuracy 81.25%
# Epoch [5/5] | Batch #2 | Batch Accuracy 71.88%
# Epoch [5/5] | Batch #3 | Batch Accuracy 74.31%
# Epoch [5/5] | Batch #4 | Batch Accuracy 76.04%
# Epoch [5/5] | Batch #5 | Batch Accuracy 76.25%
# Epoch [5/5] | Batch #6 | Batch Accuracy 77.78%
# Epoch [5/5] | Batch #7 | Batch Accuracy 76.79%
# Epoch [5/5] | Batch #8 | Batch Accuracy 76.56%
# Epoch [5/5] | Batch #9 | Batch Accuracy 76.85%
# Epoch [5/5] | Batch #10 | Batch Accuracy 76.25%
# Epoch [5/5] | Batch #11 | Batch Accuracy 75.95%
# Epoch [5/5] | Batch #12 | Batch Accuracy 75.69%
# Epoch [5/5] | Batch #13 | Batch Accuracy 75.48%
# Epoch [5/5] | Batch #14 | Batch Accuracy 75.89%
# Epoch [5/5] | Batch #15 | Batch Accuracy 75.83%
# Epoch [5/5] | Batch #16 | Batch Accuracy 75.13%
# Epoch [5/5] | Batch #17 | Batch Accuracy 75.12%
# Epoch [5/5] | Batch #18 | Batch Accuracy 75.23%
# Epoch [5/5] | Batch #19 | Batch Accuracy 74.67%
# Epoch [5/5] | Batch #20 | Batch Accuracy 74.48%
# Epoch [5/5] | Batch #21 | Batch Accuracy 73.91%
# Epoch [5/5] | Batch #22 | Batch Accuracy 73.86%
# Epoch [5/5] | Batch #23 | Batch Accuracy 73.82%
# Epoch [5/5] | Batch #24 | Batch Accuracy 73.70%
# Epoch [5/5] | Batch #25 | Batch Accuracy 73.67%
# Epoch [5/5] | Batch #26 | Batch Accuracy 73.72%
# Epoch [5/5] | Batch #27 | Batch Accuracy 73.46%
# Epoch [5/5] | Batch #28 | Batch Accuracy 73.51%
# Epoch [5/5] | Batch #29 | Batch Accuracy 73.56%
# Epoch [5/5] | Batch #30 | Batch Accuracy 73.68%
# Epoch [5/5] | Batch #31 | Batch Accuracy 73.99%
# Epoch [5/5] | Batch #32 | Batch Accuracy 74.02%
# Epoch [5/5] | Batch #33 | Batch Accuracy 74.18%
# Epoch [5/5] | Batch #34 | Batch Accuracy 74.02%
# Epoch [5/5] | Batch #35 | Batch Accuracy 73.93%
# Epoch [5/5] | Batch #36 | Batch Accuracy 73.84%
# Epoch [5/5] | Batch #37 | Batch Accuracy 74.04%
# Epoch [5/5] | Batch #38 | Batch Accuracy 74.45%
# Epoch [5/5] | Batch #39 | Batch Accuracy 74.36%
# Epoch [5/5] | Batch #40 | Batch Accuracy 74.32%
# Epoch [5/5] Train Loss: 0.7053 | Train Acc: 74.32% | Val Acc: 65.62% | Val Loss: 0.85%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▅▃▂▁</td></tr><tr><td>validation_accuracy</td><td>▁▂▆▅█</td></tr><tr><td>validation_loss</td><td>█▇▃▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.70531</td></tr><tr><td>validation_accuracy</td><td>65.625</td></tr><tr><td>validation_loss</td><td>0.8485</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod1</strong> at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/w9qmsuzx' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/w9qmsuzx</a><br> View project at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_140722-w9qmsuzx/logs</code>

# %%
plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_741931/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# *Yes, my change was successful, as validation accuracy increased to 65.62%. From resources online, my understanding is that Adam is more at risk of getting stuck around sharp minima, which aren't as good at generalizing, while SGD can (with the help of momentum) skip over these sharp minima and converge on flatter minima, leading to better performance.*

# %% [markdown]
# #### Your Model 2 (10pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# *I kept my previous change (changing optimizer to SGD with momentum), because it improved model performance, and also increased the number of epochs while decreasing the batch size. Because the validation accuracy increased from the 4th to the 5th epoch in my 1st model by a considerable amount (over 10%), I thought that increasing the number of epochs would help improve performance even more. I also decreased the batch size because there still seems to be a drop in accuracy when going from training to validation accuracy. With a lower batch size, there will be more variability within each batch, which can help prevent overfitting.*

# %%
batchsize = 32
learning_rate = 1e-3
epochs = 15

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum = 0.9)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Vini-HappyWhale-SpeciesDataset-hyperparameters_mod2", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 15, "batch_size":32}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/vini/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_150246-gas35bj8</code>
# Syncing run <strong><a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/gas35bj8' target="_blank">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod2</a></strong> to <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/gas35bj8' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/gas35bj8</a>
# Epoch [1/15] | Batch #1 | Batch Accuracy 15.62%
# Epoch [1/15] | Batch #2 | Batch Accuracy 20.31%
# Epoch [1/15] | Batch #3 | Batch Accuracy 21.88%
# Epoch [1/15] | Batch #4 | Batch Accuracy 17.97%
# Epoch [1/15] | Batch #5 | Batch Accuracy 19.38%
# Epoch [1/15] | Batch #6 | Batch Accuracy 17.71%
# Epoch [1/15] | Batch #7 | Batch Accuracy 19.20%
# Epoch [1/15] | Batch #8 | Batch Accuracy 20.70%
# Epoch [1/15] | Batch #9 | Batch Accuracy 19.79%
# Epoch [1/15] | Batch #10 | Batch Accuracy 21.56%
# Epoch [1/15] | Batch #11 | Batch Accuracy 21.31%
# Epoch [1/15] | Batch #12 | Batch Accuracy 22.14%
# Epoch [1/15] | Batch #13 | Batch Accuracy 22.84%
# Epoch [1/15] | Batch #14 | Batch Accuracy 23.66%
# Epoch [1/15] | Batch #15 | Batch Accuracy 24.58%
# Epoch [1/15] | Batch #16 | Batch Accuracy 25.39%
# Epoch [1/15] | Batch #17 | Batch Accuracy 25.92%
# Epoch [1/15] | Batch #18 | Batch Accuracy 26.56%
# Epoch [1/15] | Batch #19 | Batch Accuracy 26.81%
# Epoch [1/15] | Batch #20 | Batch Accuracy 27.81%
# Epoch [1/15] | Batch #21 | Batch Accuracy 28.72%
# Epoch [1/15] | Batch #22 | Batch Accuracy 28.84%
# Epoch [1/15] | Batch #23 | Batch Accuracy 29.62%
# Epoch [1/15] | Batch #24 | Batch Accuracy 30.60%
# Epoch [1/15] | Batch #25 | Batch Accuracy 31.37%
# Epoch [1/15] | Batch #26 | Batch Accuracy 31.61%
# Epoch [1/15] | Batch #27 | Batch Accuracy 32.29%
# Epoch [1/15] | Batch #28 | Batch Accuracy 32.37%
# Epoch [1/15] | Batch #29 | Batch Accuracy 32.44%
# Epoch [1/15] | Batch #30 | Batch Accuracy 32.40%
# Epoch [1/15] | Batch #31 | Batch Accuracy 32.96%
# Epoch [1/15] | Batch #32 | Batch Accuracy 33.69%
# Epoch [1/15] | Batch #33 | Batch Accuracy 33.81%
# Epoch [1/15] | Batch #34 | Batch Accuracy 34.19%
# Epoch [1/15] | Batch #35 | Batch Accuracy 34.11%
# Epoch [1/15] | Batch #36 | Batch Accuracy 34.20%
# Epoch [1/15] | Batch #37 | Batch Accuracy 34.71%
# Epoch [1/15] | Batch #38 | Batch Accuracy 35.28%
# Epoch [1/15] | Batch #39 | Batch Accuracy 36.06%
# Epoch [1/15] | Batch #40 | Batch Accuracy 36.64%
# Epoch [1/15] | Batch #41 | Batch Accuracy 36.89%
# Epoch [1/15] | Batch #42 | Batch Accuracy 37.05%
# Epoch [1/15] | Batch #43 | Batch Accuracy 37.35%
# Epoch [1/15] | Batch #44 | Batch Accuracy 37.29%
# Epoch [1/15] | Batch #45 | Batch Accuracy 37.57%
# Epoch [1/15] | Batch #46 | Batch Accuracy 37.98%
# Epoch [1/15] | Batch #47 | Batch Accuracy 38.63%
# Epoch [1/15] | Batch #48 | Batch Accuracy 38.80%
# Epoch [1/15] | Batch #49 | Batch Accuracy 39.41%
# Epoch [1/15] | Batch #50 | Batch Accuracy 39.38%
# Epoch [1/15] | Batch #51 | Batch Accuracy 39.22%
# Epoch [1/15] | Batch #52 | Batch Accuracy 39.66%
# Epoch [1/15] | Batch #53 | Batch Accuracy 39.86%
# Epoch [1/15] | Batch #54 | Batch Accuracy 40.28%
# Epoch [1/15] | Batch #55 | Batch Accuracy 40.85%
# Epoch [1/15] | Batch #56 | Batch Accuracy 41.29%
# Epoch [1/15] | Batch #57 | Batch Accuracy 41.50%
# Epoch [1/15] | Batch #58 | Batch Accuracy 41.86%
# Epoch [1/15] | Batch #59 | Batch Accuracy 41.90%
# Epoch [1/15] | Batch #60 | Batch Accuracy 41.72%
# Epoch [1/15] | Batch #61 | Batch Accuracy 42.01%
# Epoch [1/15] Train Loss: 1.4705 | Train Acc: 42.01% | Val Acc: 37.74% | Val Loss: 1.44%
# Epoch [2/15] | Batch #62 | Batch Accuracy 56.25%
# Epoch [2/15] | Batch #63 | Batch Accuracy 56.25%
# Epoch [2/15] | Batch #64 | Batch Accuracy 57.29%
# Epoch [2/15] | Batch #65 | Batch Accuracy 56.25%
# Epoch [2/15] | Batch #66 | Batch Accuracy 55.62%
# Epoch [2/15] | Batch #67 | Batch Accuracy 53.12%
# Epoch [2/15] | Batch #68 | Batch Accuracy 52.68%
# Epoch [2/15] | Batch #69 | Batch Accuracy 52.73%
# Epoch [2/15] | Batch #70 | Batch Accuracy 53.12%
# Epoch [2/15] | Batch #71 | Batch Accuracy 53.44%
# Epoch [2/15] | Batch #72 | Batch Accuracy 54.55%
# Epoch [2/15] | Batch #73 | Batch Accuracy 55.47%
# Epoch [2/15] | Batch #74 | Batch Accuracy 55.29%
# Epoch [2/15] | Batch #75 | Batch Accuracy 55.36%
# Epoch [2/15] | Batch #76 | Batch Accuracy 56.04%
# Epoch [2/15] | Batch #77 | Batch Accuracy 56.25%
# Epoch [2/15] | Batch #78 | Batch Accuracy 56.62%
# Epoch [2/15] | Batch #79 | Batch Accuracy 56.08%
# Epoch [2/15] | Batch #80 | Batch Accuracy 56.58%
# Epoch [2/15] | Batch #81 | Batch Accuracy 57.03%
# Epoch [2/15] | Batch #82 | Batch Accuracy 57.14%
# Epoch [2/15] | Batch #83 | Batch Accuracy 56.96%
# Epoch [2/15] | Batch #84 | Batch Accuracy 57.34%
# Epoch [2/15] | Batch #85 | Batch Accuracy 57.42%
# Epoch [2/15] | Batch #86 | Batch Accuracy 57.88%
# Epoch [2/15] | Batch #87 | Batch Accuracy 57.93%
# Epoch [2/15] | Batch #88 | Batch Accuracy 58.56%
# Epoch [2/15] | Batch #89 | Batch Accuracy 58.48%
# Epoch [2/15] | Batch #90 | Batch Accuracy 58.73%
# Epoch [2/15] | Batch #91 | Batch Accuracy 58.96%
# Epoch [2/15] | Batch #92 | Batch Accuracy 59.17%
# Epoch [2/15] | Batch #93 | Batch Accuracy 58.98%
# Epoch [2/15] | Batch #94 | Batch Accuracy 59.00%
# Epoch [2/15] | Batch #95 | Batch Accuracy 58.82%
# Epoch [2/15] | Batch #96 | Batch Accuracy 59.11%
# Epoch [2/15] | Batch #97 | Batch Accuracy 58.77%
# Epoch [2/15] | Batch #98 | Batch Accuracy 58.78%
# Epoch [2/15] | Batch #99 | Batch Accuracy 59.21%
# Epoch [2/15] | Batch #100 | Batch Accuracy 59.13%
# Epoch [2/15] | Batch #101 | Batch Accuracy 59.06%
# Epoch [2/15] | Batch #102 | Batch Accuracy 58.92%
# Epoch [2/15] | Batch #103 | Batch Accuracy 58.85%
# Epoch [2/15] | Batch #104 | Batch Accuracy 59.23%
# Epoch [2/15] | Batch #105 | Batch Accuracy 59.30%
# Epoch [2/15] | Batch #106 | Batch Accuracy 59.65%
# Epoch [2/15] | Batch #107 | Batch Accuracy 59.71%
# Epoch [2/15] | Batch #108 | Batch Accuracy 59.91%
# Epoch [2/15] | Batch #109 | Batch Accuracy 59.96%
# Epoch [2/15] | Batch #110 | Batch Accuracy 60.14%
# Epoch [2/15] | Batch #111 | Batch Accuracy 60.31%
# Epoch [2/15] | Batch #112 | Batch Accuracy 60.23%
# Epoch [2/15] | Batch #113 | Batch Accuracy 60.70%
# Epoch [2/15] | Batch #114 | Batch Accuracy 60.79%
# Epoch [2/15] | Batch #115 | Batch Accuracy 60.88%
# Epoch [2/15] | Batch #116 | Batch Accuracy 60.91%
# Epoch [2/15] | Batch #117 | Batch Accuracy 61.05%
# Epoch [2/15] | Batch #118 | Batch Accuracy 60.96%
# Epoch [2/15] | Batch #119 | Batch Accuracy 61.05%
# Epoch [2/15] | Batch #120 | Batch Accuracy 61.28%
# Epoch [2/15] | Batch #121 | Batch Accuracy 61.51%
# Epoch [2/15] | Batch #122 | Batch Accuracy 61.37%
# Epoch [2/15] Train Loss: 1.0639 | Train Acc: 61.37% | Val Acc: 49.04% | Val Loss: 1.31%
# Epoch [3/15] | Batch #123 | Batch Accuracy 59.38%
# Epoch [3/15] | Batch #124 | Batch Accuracy 59.38%
# Epoch [3/15] | Batch #125 | Batch Accuracy 59.38%
# Epoch [3/15] | Batch #126 | Batch Accuracy 60.16%
# Epoch [3/15] | Batch #127 | Batch Accuracy 61.25%
# Epoch [3/15] | Batch #128 | Batch Accuracy 59.90%
# Epoch [3/15] | Batch #129 | Batch Accuracy 60.27%
# Epoch [3/15] | Batch #130 | Batch Accuracy 61.72%
# Epoch [3/15] | Batch #131 | Batch Accuracy 61.11%
# Epoch [3/15] | Batch #132 | Batch Accuracy 61.56%
# Epoch [3/15] | Batch #133 | Batch Accuracy 61.36%
# Epoch [3/15] | Batch #134 | Batch Accuracy 60.68%
# Epoch [3/15] | Batch #135 | Batch Accuracy 61.30%
# Epoch [3/15] | Batch #136 | Batch Accuracy 60.71%
# Epoch [3/15] | Batch #137 | Batch Accuracy 60.83%
# Epoch [3/15] | Batch #138 | Batch Accuracy 61.52%
# Epoch [3/15] | Batch #139 | Batch Accuracy 60.85%
# Epoch [3/15] | Batch #140 | Batch Accuracy 62.50%
# Epoch [3/15] | Batch #141 | Batch Accuracy 62.17%
# Epoch [3/15] | Batch #142 | Batch Accuracy 62.66%
# Epoch [3/15] | Batch #143 | Batch Accuracy 63.24%
# Epoch [3/15] | Batch #144 | Batch Accuracy 63.49%
# Epoch [3/15] | Batch #145 | Batch Accuracy 63.86%
# Epoch [3/15] | Batch #146 | Batch Accuracy 63.93%
# Epoch [3/15] | Batch #147 | Batch Accuracy 63.75%
# Epoch [3/15] | Batch #148 | Batch Accuracy 63.82%
# Epoch [3/15] | Batch #149 | Batch Accuracy 64.47%
# Epoch [3/15] | Batch #150 | Batch Accuracy 64.73%
# Epoch [3/15] | Batch #151 | Batch Accuracy 65.41%
# Epoch [3/15] | Batch #152 | Batch Accuracy 65.62%
# Epoch [3/15] | Batch #153 | Batch Accuracy 65.62%
# Epoch [3/15] | Batch #154 | Batch Accuracy 65.92%
# Epoch [3/15] | Batch #155 | Batch Accuracy 66.29%
# Epoch [3/15] | Batch #156 | Batch Accuracy 66.36%
# Epoch [3/15] | Batch #157 | Batch Accuracy 66.43%
# Epoch [3/15] | Batch #158 | Batch Accuracy 66.41%
# Epoch [3/15] | Batch #159 | Batch Accuracy 66.39%
# Epoch [3/15] | Batch #160 | Batch Accuracy 66.20%
# Epoch [3/15] | Batch #161 | Batch Accuracy 65.95%
# Epoch [3/15] | Batch #162 | Batch Accuracy 65.78%
# Epoch [3/15] | Batch #163 | Batch Accuracy 65.93%
# Epoch [3/15] | Batch #164 | Batch Accuracy 66.07%
# Epoch [3/15] | Batch #165 | Batch Accuracy 66.28%
# Epoch [3/15] | Batch #166 | Batch Accuracy 66.41%
# Epoch [3/15] | Batch #167 | Batch Accuracy 65.83%
# Epoch [3/15] | Batch #168 | Batch Accuracy 65.76%
# Epoch [3/15] | Batch #169 | Batch Accuracy 65.69%
# Epoch [3/15] | Batch #170 | Batch Accuracy 65.89%
# Epoch [3/15] | Batch #171 | Batch Accuracy 66.07%
# Epoch [3/15] | Batch #172 | Batch Accuracy 66.25%
# Epoch [3/15] | Batch #173 | Batch Accuracy 66.54%
# Epoch [3/15] | Batch #174 | Batch Accuracy 66.47%
# Epoch [3/15] | Batch #175 | Batch Accuracy 66.10%
# Epoch [3/15] | Batch #176 | Batch Accuracy 66.26%
# Epoch [3/15] | Batch #177 | Batch Accuracy 66.36%
# Epoch [3/15] | Batch #178 | Batch Accuracy 66.41%
# Epoch [3/15] | Batch #179 | Batch Accuracy 66.39%
# Epoch [3/15] | Batch #180 | Batch Accuracy 66.43%
# Epoch [3/15] | Batch #181 | Batch Accuracy 66.58%
# Epoch [3/15] | Batch #182 | Batch Accuracy 66.77%
# Epoch [3/15] | Batch #183 | Batch Accuracy 66.85%
# Epoch [3/15] Train Loss: 0.9005 | Train Acc: 66.85% | Val Acc: 51.68% | Val Loss: 1.14%
# Epoch [4/15] | Batch #184 | Batch Accuracy 75.00%
# Epoch [4/15] | Batch #185 | Batch Accuracy 78.12%
# Epoch [4/15] | Batch #186 | Batch Accuracy 73.96%
# Epoch [4/15] | Batch #187 | Batch Accuracy 78.12%
# Epoch [4/15] | Batch #188 | Batch Accuracy 76.25%
# Epoch [4/15] | Batch #189 | Batch Accuracy 75.00%
# Epoch [4/15] | Batch #190 | Batch Accuracy 73.66%
# Epoch [4/15] | Batch #191 | Batch Accuracy 73.44%
# Epoch [4/15] | Batch #192 | Batch Accuracy 72.57%
# Epoch [4/15] | Batch #193 | Batch Accuracy 73.12%
# Epoch [4/15] | Batch #194 | Batch Accuracy 73.01%
# Epoch [4/15] | Batch #195 | Batch Accuracy 74.22%
# Epoch [4/15] | Batch #196 | Batch Accuracy 73.08%
# Epoch [4/15] | Batch #197 | Batch Accuracy 73.88%
# Epoch [4/15] | Batch #198 | Batch Accuracy 74.58%
# Epoch [4/15] | Batch #199 | Batch Accuracy 74.80%
# Epoch [4/15] | Batch #200 | Batch Accuracy 75.55%
# Epoch [4/15] | Batch #201 | Batch Accuracy 75.52%
# Epoch [4/15] | Batch #202 | Batch Accuracy 74.84%
# Epoch [4/15] | Batch #203 | Batch Accuracy 74.69%
# Epoch [4/15] | Batch #204 | Batch Accuracy 74.85%
# Epoch [4/15] | Batch #205 | Batch Accuracy 74.57%
# Epoch [4/15] | Batch #206 | Batch Accuracy 75.14%
# Epoch [4/15] | Batch #207 | Batch Accuracy 74.35%
# Epoch [4/15] | Batch #208 | Batch Accuracy 74.12%
# Epoch [4/15] | Batch #209 | Batch Accuracy 74.40%
# Epoch [4/15] | Batch #210 | Batch Accuracy 74.77%
# Epoch [4/15] | Batch #211 | Batch Accuracy 75.11%
# Epoch [4/15] | Batch #212 | Batch Accuracy 75.00%
# Epoch [4/15] | Batch #213 | Batch Accuracy 74.69%
# Epoch [4/15] | Batch #214 | Batch Accuracy 74.60%
# Epoch [4/15] | Batch #215 | Batch Accuracy 74.71%
# Epoch [4/15] | Batch #216 | Batch Accuracy 74.81%
# Epoch [4/15] | Batch #217 | Batch Accuracy 74.72%
# Epoch [4/15] | Batch #218 | Batch Accuracy 74.82%
# Epoch [4/15] | Batch #219 | Batch Accuracy 75.00%
# Epoch [4/15] | Batch #220 | Batch Accuracy 74.83%
# Epoch [4/15] | Batch #221 | Batch Accuracy 74.59%
# Epoch [4/15] | Batch #222 | Batch Accuracy 74.44%
# Epoch [4/15] | Batch #223 | Batch Accuracy 74.22%
# Epoch [4/15] | Batch #224 | Batch Accuracy 74.16%
# Epoch [4/15] | Batch #225 | Batch Accuracy 74.11%
# Epoch [4/15] | Batch #226 | Batch Accuracy 74.06%
# Epoch [4/15] | Batch #227 | Batch Accuracy 74.15%
# Epoch [4/15] | Batch #228 | Batch Accuracy 74.24%
# Epoch [4/15] | Batch #229 | Batch Accuracy 74.12%
# Epoch [4/15] | Batch #230 | Batch Accuracy 74.34%
# Epoch [4/15] | Batch #231 | Batch Accuracy 74.41%
# Epoch [4/15] | Batch #232 | Batch Accuracy 74.36%
# Epoch [4/15] | Batch #233 | Batch Accuracy 74.44%
# Epoch [4/15] | Batch #234 | Batch Accuracy 74.39%
# Epoch [4/15] | Batch #235 | Batch Accuracy 74.46%
# Epoch [4/15] | Batch #236 | Batch Accuracy 74.47%
# Epoch [4/15] | Batch #237 | Batch Accuracy 74.13%
# Epoch [4/15] | Batch #238 | Batch Accuracy 74.03%
# Epoch [4/15] | Batch #239 | Batch Accuracy 74.00%
# Epoch [4/15] | Batch #240 | Batch Accuracy 73.90%
# Epoch [4/15] | Batch #241 | Batch Accuracy 74.19%
# Epoch [4/15] | Batch #242 | Batch Accuracy 74.36%
# Epoch [4/15] | Batch #243 | Batch Accuracy 74.38%
# Epoch [4/15] | Batch #244 | Batch Accuracy 74.39%
# Epoch [4/15] Train Loss: 0.6870 | Train Acc: 74.39% | Val Acc: 64.90% | Val Loss: 0.89%
# Epoch [5/15] | Batch #245 | Batch Accuracy 78.12%
# Epoch [5/15] | Batch #246 | Batch Accuracy 81.25%
# Epoch [5/15] | Batch #247 | Batch Accuracy 81.25%
# Epoch [5/15] | Batch #248 | Batch Accuracy 81.25%
# Epoch [5/15] | Batch #249 | Batch Accuracy 79.38%
# Epoch [5/15] | Batch #250 | Batch Accuracy 78.65%
# Epoch [5/15] | Batch #251 | Batch Accuracy 79.02%
# Epoch [5/15] | Batch #252 | Batch Accuracy 79.69%
# Epoch [5/15] | Batch #253 | Batch Accuracy 80.56%
# Epoch [5/15] | Batch #254 | Batch Accuracy 80.31%
# Epoch [5/15] | Batch #255 | Batch Accuracy 80.68%
# Epoch [5/15] | Batch #256 | Batch Accuracy 79.17%
# Epoch [5/15] | Batch #257 | Batch Accuracy 79.09%
# Epoch [5/15] | Batch #258 | Batch Accuracy 78.57%
# Epoch [5/15] | Batch #259 | Batch Accuracy 78.54%
# Epoch [5/15] | Batch #260 | Batch Accuracy 78.71%
# Epoch [5/15] | Batch #261 | Batch Accuracy 79.41%
# Epoch [5/15] | Batch #262 | Batch Accuracy 78.47%
# Epoch [5/15] | Batch #263 | Batch Accuracy 78.95%
# Epoch [5/15] | Batch #264 | Batch Accuracy 78.59%
# Epoch [5/15] | Batch #265 | Batch Accuracy 78.72%
# Epoch [5/15] | Batch #266 | Batch Accuracy 78.55%
# Epoch [5/15] | Batch #267 | Batch Accuracy 78.53%
# Epoch [5/15] | Batch #268 | Batch Accuracy 78.26%
# Epoch [5/15] | Batch #269 | Batch Accuracy 78.50%
# Epoch [5/15] | Batch #270 | Batch Accuracy 78.97%
# Epoch [5/15] | Batch #271 | Batch Accuracy 78.82%
# Epoch [5/15] | Batch #272 | Batch Accuracy 78.68%
# Epoch [5/15] | Batch #273 | Batch Accuracy 79.31%
# Epoch [5/15] | Batch #274 | Batch Accuracy 79.48%
# Epoch [5/15] | Batch #275 | Batch Accuracy 79.54%
# Epoch [5/15] | Batch #276 | Batch Accuracy 79.98%
# Epoch [5/15] | Batch #277 | Batch Accuracy 79.83%
# Epoch [5/15] | Batch #278 | Batch Accuracy 79.78%
# Epoch [5/15] | Batch #279 | Batch Accuracy 79.64%
# Epoch [5/15] | Batch #280 | Batch Accuracy 79.69%
# Epoch [5/15] | Batch #281 | Batch Accuracy 79.73%
# Epoch [5/15] | Batch #282 | Batch Accuracy 79.36%
# Epoch [5/15] | Batch #283 | Batch Accuracy 79.57%
# Epoch [5/15] | Batch #284 | Batch Accuracy 79.61%
# Epoch [5/15] | Batch #285 | Batch Accuracy 79.73%
# Epoch [5/15] | Batch #286 | Batch Accuracy 79.69%
# Epoch [5/15] | Batch #287 | Batch Accuracy 79.94%
# Epoch [5/15] | Batch #288 | Batch Accuracy 79.76%
# Epoch [5/15] | Batch #289 | Batch Accuracy 79.79%
# Epoch [5/15] | Batch #290 | Batch Accuracy 79.76%
# Epoch [5/15] | Batch #291 | Batch Accuracy 79.92%
# Epoch [5/15] | Batch #292 | Batch Accuracy 79.82%
# Epoch [5/15] | Batch #293 | Batch Accuracy 79.91%
# Epoch [5/15] | Batch #294 | Batch Accuracy 80.06%
# Epoch [5/15] | Batch #295 | Batch Accuracy 79.96%
# Epoch [5/15] | Batch #296 | Batch Accuracy 79.81%
# Epoch [5/15] | Batch #297 | Batch Accuracy 79.72%
# Epoch [5/15] | Batch #298 | Batch Accuracy 79.63%
# Epoch [5/15] | Batch #299 | Batch Accuracy 79.49%
# Epoch [5/15] | Batch #300 | Batch Accuracy 79.41%
# Epoch [5/15] | Batch #301 | Batch Accuracy 79.44%
# Epoch [5/15] | Batch #302 | Batch Accuracy 79.47%
# Epoch [5/15] | Batch #303 | Batch Accuracy 79.40%
# Epoch [5/15] | Batch #304 | Batch Accuracy 79.38%
# Epoch [5/15] | Batch #305 | Batch Accuracy 79.51%
# Epoch [5/15] Train Loss: 0.5792 | Train Acc: 79.51% | Val Acc: 67.79% | Val Loss: 0.84%
# Epoch [6/15] | Batch #306 | Batch Accuracy 78.12%
# Epoch [6/15] | Batch #307 | Batch Accuracy 73.44%
# Epoch [6/15] | Batch #308 | Batch Accuracy 77.08%
# Epoch [6/15] | Batch #309 | Batch Accuracy 75.78%
# Epoch [6/15] | Batch #310 | Batch Accuracy 77.50%
# Epoch [6/15] | Batch #311 | Batch Accuracy 77.08%
# Epoch [6/15] | Batch #312 | Batch Accuracy 76.79%
# Epoch [6/15] | Batch #313 | Batch Accuracy 77.73%
# Epoch [6/15] | Batch #314 | Batch Accuracy 78.47%
# Epoch [6/15] | Batch #315 | Batch Accuracy 76.88%
# Epoch [6/15] | Batch #316 | Batch Accuracy 76.99%
# Epoch [6/15] | Batch #317 | Batch Accuracy 77.08%
# Epoch [6/15] | Batch #318 | Batch Accuracy 77.64%
# Epoch [6/15] | Batch #319 | Batch Accuracy 78.35%
# Epoch [6/15] | Batch #320 | Batch Accuracy 78.12%
# Epoch [6/15] | Batch #321 | Batch Accuracy 78.91%
# Epoch [6/15] | Batch #322 | Batch Accuracy 79.96%
# Epoch [6/15] | Batch #323 | Batch Accuracy 80.38%
# Epoch [6/15] | Batch #324 | Batch Accuracy 80.43%
# Epoch [6/15] | Batch #325 | Batch Accuracy 79.69%
# Epoch [6/15] | Batch #326 | Batch Accuracy 79.17%
# Epoch [6/15] | Batch #327 | Batch Accuracy 79.26%
# Epoch [6/15] | Batch #328 | Batch Accuracy 79.21%
# Epoch [6/15] | Batch #329 | Batch Accuracy 79.56%
# Epoch [6/15] | Batch #330 | Batch Accuracy 79.50%
# Epoch [6/15] | Batch #331 | Batch Accuracy 79.81%
# Epoch [6/15] | Batch #332 | Batch Accuracy 80.09%
# Epoch [6/15] | Batch #333 | Batch Accuracy 80.58%
# Epoch [6/15] | Batch #334 | Batch Accuracy 80.50%
# Epoch [6/15] | Batch #335 | Batch Accuracy 80.52%
# Epoch [6/15] | Batch #336 | Batch Accuracy 80.24%
# Epoch [6/15] | Batch #337 | Batch Accuracy 80.37%
# Epoch [6/15] | Batch #338 | Batch Accuracy 80.21%
# Epoch [6/15] | Batch #339 | Batch Accuracy 80.06%
# Epoch [6/15] | Batch #340 | Batch Accuracy 80.36%
# Epoch [6/15] | Batch #341 | Batch Accuracy 80.47%
# Epoch [6/15] | Batch #342 | Batch Accuracy 80.49%
# Epoch [6/15] | Batch #343 | Batch Accuracy 80.35%
# Epoch [6/15] | Batch #344 | Batch Accuracy 80.45%
# Epoch [6/15] | Batch #345 | Batch Accuracy 80.23%
# Epoch [6/15] | Batch #346 | Batch Accuracy 80.11%
# Epoch [6/15] | Batch #347 | Batch Accuracy 80.21%
# Epoch [6/15] | Batch #348 | Batch Accuracy 80.45%
# Epoch [6/15] | Batch #349 | Batch Accuracy 80.47%
# Epoch [6/15] | Batch #350 | Batch Accuracy 80.62%
# Epoch [6/15] | Batch #351 | Batch Accuracy 80.50%
# Epoch [6/15] | Batch #352 | Batch Accuracy 80.19%
# Epoch [6/15] | Batch #353 | Batch Accuracy 80.08%
# Epoch [6/15] | Batch #354 | Batch Accuracy 79.91%
# Epoch [6/15] | Batch #355 | Batch Accuracy 79.88%
# Epoch [6/15] | Batch #356 | Batch Accuracy 79.90%
# Epoch [6/15] | Batch #357 | Batch Accuracy 80.17%
# Epoch [6/15] | Batch #358 | Batch Accuracy 80.13%
# Epoch [6/15] | Batch #359 | Batch Accuracy 80.15%
# Epoch [6/15] | Batch #360 | Batch Accuracy 80.11%
# Epoch [6/15] | Batch #361 | Batch Accuracy 80.30%
# Epoch [6/15] | Batch #362 | Batch Accuracy 80.43%
# Epoch [6/15] | Batch #363 | Batch Accuracy 80.39%
# Epoch [6/15] | Batch #364 | Batch Accuracy 80.67%
# Epoch [6/15] | Batch #365 | Batch Accuracy 80.68%
# Epoch [6/15] | Batch #366 | Batch Accuracy 80.74%
# Epoch [6/15] Train Loss: 0.5475 | Train Acc: 80.74% | Val Acc: 66.11% | Val Loss: 0.88%
# Epoch [7/15] | Batch #367 | Batch Accuracy 84.38%
# Epoch [7/15] | Batch #368 | Batch Accuracy 79.69%
# Epoch [7/15] | Batch #369 | Batch Accuracy 82.29%
# Epoch [7/15] | Batch #370 | Batch Accuracy 84.38%
# Epoch [7/15] | Batch #371 | Batch Accuracy 80.00%
# Epoch [7/15] | Batch #372 | Batch Accuracy 82.29%
# Epoch [7/15] | Batch #373 | Batch Accuracy 81.70%
# Epoch [7/15] | Batch #374 | Batch Accuracy 83.59%
# Epoch [7/15] | Batch #375 | Batch Accuracy 83.68%
# Epoch [7/15] | Batch #376 | Batch Accuracy 82.81%
# Epoch [7/15] | Batch #377 | Batch Accuracy 82.10%
# Epoch [7/15] | Batch #378 | Batch Accuracy 82.29%
# Epoch [7/15] | Batch #379 | Batch Accuracy 81.97%
# Epoch [7/15] | Batch #380 | Batch Accuracy 81.47%
# Epoch [7/15] | Batch #381 | Batch Accuracy 81.25%
# Epoch [7/15] | Batch #382 | Batch Accuracy 81.05%
# Epoch [7/15] | Batch #383 | Batch Accuracy 81.07%
# Epoch [7/15] | Batch #384 | Batch Accuracy 81.08%
# Epoch [7/15] | Batch #385 | Batch Accuracy 81.25%
# Epoch [7/15] | Batch #386 | Batch Accuracy 81.56%
# Epoch [7/15] | Batch #387 | Batch Accuracy 81.25%
# Epoch [7/15] | Batch #388 | Batch Accuracy 81.25%
# Epoch [7/15] | Batch #389 | Batch Accuracy 81.52%
# Epoch [7/15] | Batch #390 | Batch Accuracy 81.64%
# Epoch [7/15] | Batch #391 | Batch Accuracy 81.88%
# Epoch [7/15] | Batch #392 | Batch Accuracy 82.09%
# Epoch [7/15] | Batch #393 | Batch Accuracy 82.29%
# Epoch [7/15] | Batch #394 | Batch Accuracy 82.14%
# Epoch [7/15] | Batch #395 | Batch Accuracy 82.22%
# Epoch [7/15] | Batch #396 | Batch Accuracy 82.50%
# Epoch [7/15] | Batch #397 | Batch Accuracy 82.76%
# Epoch [7/15] | Batch #398 | Batch Accuracy 83.11%
# Epoch [7/15] | Batch #399 | Batch Accuracy 82.95%
# Epoch [7/15] | Batch #400 | Batch Accuracy 83.18%
# Epoch [7/15] | Batch #401 | Batch Accuracy 83.48%
# Epoch [7/15] | Batch #402 | Batch Accuracy 83.68%
# Epoch [7/15] | Batch #403 | Batch Accuracy 83.53%
# Epoch [7/15] | Batch #404 | Batch Accuracy 83.39%
# Epoch [7/15] | Batch #405 | Batch Accuracy 83.33%
# Epoch [7/15] | Batch #406 | Batch Accuracy 83.20%
# Epoch [7/15] | Batch #407 | Batch Accuracy 82.93%
# Epoch [7/15] | Batch #408 | Batch Accuracy 82.81%
# Epoch [7/15] | Batch #409 | Batch Accuracy 82.85%
# Epoch [7/15] | Batch #410 | Batch Accuracy 82.95%
# Epoch [7/15] | Batch #411 | Batch Accuracy 82.92%
# Epoch [7/15] | Batch #412 | Batch Accuracy 83.02%
# Epoch [7/15] | Batch #413 | Batch Accuracy 82.98%
# Epoch [7/15] | Batch #414 | Batch Accuracy 82.94%
# Epoch [7/15] | Batch #415 | Batch Accuracy 83.10%
# Epoch [7/15] | Batch #416 | Batch Accuracy 83.19%
# Epoch [7/15] | Batch #417 | Batch Accuracy 83.46%
# Epoch [7/15] | Batch #418 | Batch Accuracy 83.65%
# Epoch [7/15] | Batch #419 | Batch Accuracy 83.73%
# Epoch [7/15] | Batch #420 | Batch Accuracy 83.39%
# Epoch [7/15] | Batch #421 | Batch Accuracy 83.30%
# Epoch [7/15] | Batch #422 | Batch Accuracy 83.26%
# Epoch [7/15] | Batch #423 | Batch Accuracy 83.33%
# Epoch [7/15] | Batch #424 | Batch Accuracy 83.51%
# Epoch [7/15] | Batch #425 | Batch Accuracy 83.58%
# Epoch [7/15] | Batch #426 | Batch Accuracy 83.59%
# Epoch [7/15] | Batch #427 | Batch Accuracy 83.76%
# Epoch [7/15] Train Loss: 0.4574 | Train Acc: 83.76% | Val Acc: 69.95% | Val Loss: 0.77%
# Epoch [8/15] | Batch #428 | Batch Accuracy 96.88%
# Epoch [8/15] | Batch #429 | Batch Accuracy 92.19%
# Epoch [8/15] | Batch #430 | Batch Accuracy 90.62%
# Epoch [8/15] | Batch #431 | Batch Accuracy 87.50%
# Epoch [8/15] | Batch #432 | Batch Accuracy 86.25%
# Epoch [8/15] | Batch #433 | Batch Accuracy 84.90%
# Epoch [8/15] | Batch #434 | Batch Accuracy 84.82%
# Epoch [8/15] | Batch #435 | Batch Accuracy 85.16%
# Epoch [8/15] | Batch #436 | Batch Accuracy 85.42%
# Epoch [8/15] | Batch #437 | Batch Accuracy 85.31%
# Epoch [8/15] | Batch #438 | Batch Accuracy 84.66%
# Epoch [8/15] | Batch #439 | Batch Accuracy 83.85%
# Epoch [8/15] | Batch #440 | Batch Accuracy 84.38%
# Epoch [8/15] | Batch #441 | Batch Accuracy 84.82%
# Epoch [8/15] | Batch #442 | Batch Accuracy 85.21%
# Epoch [8/15] | Batch #443 | Batch Accuracy 84.96%
# Epoch [8/15] | Batch #444 | Batch Accuracy 84.93%
# Epoch [8/15] | Batch #445 | Batch Accuracy 85.07%
# Epoch [8/15] | Batch #446 | Batch Accuracy 84.54%
# Epoch [8/15] | Batch #447 | Batch Accuracy 84.38%
# Epoch [8/15] | Batch #448 | Batch Accuracy 84.82%
# Epoch [8/15] | Batch #449 | Batch Accuracy 84.80%
# Epoch [8/15] | Batch #450 | Batch Accuracy 84.92%
# Epoch [8/15] | Batch #451 | Batch Accuracy 84.90%
# Epoch [8/15] | Batch #452 | Batch Accuracy 85.00%
# Epoch [8/15] | Batch #453 | Batch Accuracy 85.22%
# Epoch [8/15] | Batch #454 | Batch Accuracy 85.42%
# Epoch [8/15] | Batch #455 | Batch Accuracy 85.49%
# Epoch [8/15] | Batch #456 | Batch Accuracy 85.99%
# Epoch [8/15] | Batch #457 | Batch Accuracy 85.52%
# Epoch [8/15] | Batch #458 | Batch Accuracy 85.99%
# Epoch [8/15] | Batch #459 | Batch Accuracy 86.13%
# Epoch [8/15] | Batch #460 | Batch Accuracy 86.27%
# Epoch [8/15] | Batch #461 | Batch Accuracy 86.21%
# Epoch [8/15] | Batch #462 | Batch Accuracy 86.25%
# Epoch [8/15] | Batch #463 | Batch Accuracy 86.11%
# Epoch [8/15] | Batch #464 | Batch Accuracy 86.23%
# Epoch [8/15] | Batch #465 | Batch Accuracy 86.35%
# Epoch [8/15] | Batch #466 | Batch Accuracy 86.14%
# Epoch [8/15] | Batch #467 | Batch Accuracy 86.17%
# Epoch [8/15] | Batch #468 | Batch Accuracy 86.36%
# Epoch [8/15] | Batch #469 | Batch Accuracy 86.38%
# Epoch [8/15] | Batch #470 | Batch Accuracy 86.26%
# Epoch [8/15] | Batch #471 | Batch Accuracy 86.36%
# Epoch [8/15] | Batch #472 | Batch Accuracy 86.25%
# Epoch [8/15] | Batch #473 | Batch Accuracy 86.28%
# Epoch [8/15] | Batch #474 | Batch Accuracy 86.30%
# Epoch [8/15] | Batch #475 | Batch Accuracy 86.33%
# Epoch [8/15] | Batch #476 | Batch Accuracy 86.35%
# Epoch [8/15] | Batch #477 | Batch Accuracy 86.31%
# Epoch [8/15] | Batch #478 | Batch Accuracy 86.15%
# Epoch [8/15] | Batch #479 | Batch Accuracy 86.18%
# Epoch [8/15] | Batch #480 | Batch Accuracy 86.14%
# Epoch [8/15] | Batch #481 | Batch Accuracy 86.17%
# Epoch [8/15] | Batch #482 | Batch Accuracy 86.19%
# Epoch [8/15] | Batch #483 | Batch Accuracy 85.99%
# Epoch [8/15] | Batch #484 | Batch Accuracy 86.13%
# Epoch [8/15] | Batch #485 | Batch Accuracy 86.21%
# Epoch [8/15] | Batch #486 | Batch Accuracy 86.39%
# Epoch [8/15] | Batch #487 | Batch Accuracy 86.35%
# Epoch [8/15] | Batch #488 | Batch Accuracy 86.58%
# Epoch [8/15] Train Loss: 0.3791 | Train Acc: 86.58% | Val Acc: 71.15% | Val Loss: 0.77%
# Epoch [9/15] | Batch #489 | Batch Accuracy 81.25%
# Epoch [9/15] | Batch #490 | Batch Accuracy 85.94%
# Epoch [9/15] | Batch #491 | Batch Accuracy 85.42%
# Epoch [9/15] | Batch #492 | Batch Accuracy 84.38%
# Epoch [9/15] | Batch #493 | Batch Accuracy 87.50%
# Epoch [9/15] | Batch #494 | Batch Accuracy 88.54%
# Epoch [9/15] | Batch #495 | Batch Accuracy 88.39%
# Epoch [9/15] | Batch #496 | Batch Accuracy 87.50%
# Epoch [9/15] | Batch #497 | Batch Accuracy 88.19%
# Epoch [9/15] | Batch #498 | Batch Accuracy 87.81%
# Epoch [9/15] | Batch #499 | Batch Accuracy 86.93%
# Epoch [9/15] | Batch #500 | Batch Accuracy 86.72%
# Epoch [9/15] | Batch #501 | Batch Accuracy 86.06%
# Epoch [9/15] | Batch #502 | Batch Accuracy 87.05%
# Epoch [9/15] | Batch #503 | Batch Accuracy 87.08%
# Epoch [9/15] | Batch #504 | Batch Accuracy 86.52%
# Epoch [9/15] | Batch #505 | Batch Accuracy 86.58%
# Epoch [9/15] | Batch #506 | Batch Accuracy 86.28%
# Epoch [9/15] | Batch #507 | Batch Accuracy 85.53%
# Epoch [9/15] | Batch #508 | Batch Accuracy 85.62%
# Epoch [9/15] | Batch #509 | Batch Accuracy 85.27%
# Epoch [9/15] | Batch #510 | Batch Accuracy 85.80%
# Epoch [9/15] | Batch #511 | Batch Accuracy 86.28%
# Epoch [9/15] | Batch #512 | Batch Accuracy 86.72%
# Epoch [9/15] | Batch #513 | Batch Accuracy 87.00%
# Epoch [9/15] | Batch #514 | Batch Accuracy 87.14%
# Epoch [9/15] | Batch #515 | Batch Accuracy 87.15%
# Epoch [9/15] | Batch #516 | Batch Accuracy 86.83%
# Epoch [9/15] | Batch #517 | Batch Accuracy 87.18%
# Epoch [9/15] | Batch #518 | Batch Accuracy 87.29%
# Epoch [9/15] | Batch #519 | Batch Accuracy 86.90%
# Epoch [9/15] | Batch #520 | Batch Accuracy 86.91%
# Epoch [9/15] | Batch #521 | Batch Accuracy 87.22%
# Epoch [9/15] | Batch #522 | Batch Accuracy 86.95%
# Epoch [9/15] | Batch #523 | Batch Accuracy 87.05%
# Epoch [9/15] | Batch #524 | Batch Accuracy 86.81%
# Epoch [9/15] | Batch #525 | Batch Accuracy 86.99%
# Epoch [9/15] | Batch #526 | Batch Accuracy 87.25%
# Epoch [9/15] | Batch #527 | Batch Accuracy 87.26%
# Epoch [9/15] | Batch #528 | Batch Accuracy 87.19%
# Epoch [9/15] | Batch #529 | Batch Accuracy 87.12%
# Epoch [9/15] | Batch #530 | Batch Accuracy 86.90%
# Epoch [9/15] | Batch #531 | Batch Accuracy 87.06%
# Epoch [9/15] | Batch #532 | Batch Accuracy 87.14%
# Epoch [9/15] | Batch #533 | Batch Accuracy 87.36%
# Epoch [9/15] | Batch #534 | Batch Accuracy 87.23%
# Epoch [9/15] | Batch #535 | Batch Accuracy 87.30%
# Epoch [9/15] | Batch #536 | Batch Accuracy 87.11%
# Epoch [9/15] | Batch #537 | Batch Accuracy 87.31%
# Epoch [9/15] | Batch #538 | Batch Accuracy 87.19%
# Epoch [9/15] | Batch #539 | Batch Accuracy 87.19%
# Epoch [9/15] | Batch #540 | Batch Accuracy 87.20%
# Epoch [9/15] | Batch #541 | Batch Accuracy 87.26%
# Epoch [9/15] | Batch #542 | Batch Accuracy 87.33%
# Epoch [9/15] | Batch #543 | Batch Accuracy 87.39%
# Epoch [9/15] | Batch #544 | Batch Accuracy 87.44%
# Epoch [9/15] | Batch #545 | Batch Accuracy 87.45%
# Epoch [9/15] | Batch #546 | Batch Accuracy 87.50%
# Epoch [9/15] | Batch #547 | Batch Accuracy 87.34%
# Epoch [9/15] | Batch #548 | Batch Accuracy 87.40%
# Epoch [9/15] | Batch #549 | Batch Accuracy 87.45%
# Epoch [9/15] Train Loss: 0.3443 | Train Acc: 87.45% | Val Acc: 71.88% | Val Loss: 0.76%
# Epoch [10/15] | Batch #550 | Batch Accuracy 93.75%
# Epoch [10/15] | Batch #551 | Batch Accuracy 90.62%
# Epoch [10/15] | Batch #552 | Batch Accuracy 90.62%
# Epoch [10/15] | Batch #553 | Batch Accuracy 86.72%
# Epoch [10/15] | Batch #554 | Batch Accuracy 86.88%
# Epoch [10/15] | Batch #555 | Batch Accuracy 85.94%
# Epoch [10/15] | Batch #556 | Batch Accuracy 86.16%
# Epoch [10/15] | Batch #557 | Batch Accuracy 86.33%
# Epoch [10/15] | Batch #558 | Batch Accuracy 87.15%
# Epoch [10/15] | Batch #559 | Batch Accuracy 86.88%
# Epoch [10/15] | Batch #560 | Batch Accuracy 86.65%
# Epoch [10/15] | Batch #561 | Batch Accuracy 86.46%
# Epoch [10/15] | Batch #562 | Batch Accuracy 86.30%
# Epoch [10/15] | Batch #563 | Batch Accuracy 85.94%
# Epoch [10/15] | Batch #564 | Batch Accuracy 86.04%
# Epoch [10/15] | Batch #565 | Batch Accuracy 86.52%
# Epoch [10/15] | Batch #566 | Batch Accuracy 86.58%
# Epoch [10/15] | Batch #567 | Batch Accuracy 85.94%
# Epoch [10/15] | Batch #568 | Batch Accuracy 86.02%
# Epoch [10/15] | Batch #569 | Batch Accuracy 86.25%
# Epoch [10/15] | Batch #570 | Batch Accuracy 86.46%
# Epoch [10/15] | Batch #571 | Batch Accuracy 86.93%
# Epoch [10/15] | Batch #572 | Batch Accuracy 86.55%
# Epoch [10/15] | Batch #573 | Batch Accuracy 86.85%
# Epoch [10/15] | Batch #574 | Batch Accuracy 87.00%
# Epoch [10/15] | Batch #575 | Batch Accuracy 87.38%
# Epoch [10/15] | Batch #576 | Batch Accuracy 87.38%
# Epoch [10/15] | Batch #577 | Batch Accuracy 87.61%
# Epoch [10/15] | Batch #578 | Batch Accuracy 87.82%
# Epoch [10/15] | Batch #579 | Batch Accuracy 88.02%
# Epoch [10/15] | Batch #580 | Batch Accuracy 88.10%
# Epoch [10/15] | Batch #581 | Batch Accuracy 87.89%
# Epoch [10/15] | Batch #582 | Batch Accuracy 88.16%
# Epoch [10/15] | Batch #583 | Batch Accuracy 88.42%
# Epoch [10/15] | Batch #584 | Batch Accuracy 88.66%
# Epoch [10/15] | Batch #585 | Batch Accuracy 88.72%
# Epoch [10/15] | Batch #586 | Batch Accuracy 88.68%
# Epoch [10/15] | Batch #587 | Batch Accuracy 88.73%
# Epoch [10/15] | Batch #588 | Batch Accuracy 88.70%
# Epoch [10/15] | Batch #589 | Batch Accuracy 88.91%
# Epoch [10/15] | Batch #590 | Batch Accuracy 88.87%
# Epoch [10/15] | Batch #591 | Batch Accuracy 89.06%
# Epoch [10/15] | Batch #592 | Batch Accuracy 89.24%
# Epoch [10/15] | Batch #593 | Batch Accuracy 89.42%
# Epoch [10/15] | Batch #594 | Batch Accuracy 89.44%
# Epoch [10/15] | Batch #595 | Batch Accuracy 89.61%
# Epoch [10/15] | Batch #596 | Batch Accuracy 89.56%
# Epoch [10/15] | Batch #597 | Batch Accuracy 89.39%
# Epoch [10/15] | Batch #598 | Batch Accuracy 89.35%
# Epoch [10/15] | Batch #599 | Batch Accuracy 89.31%
# Epoch [10/15] | Batch #600 | Batch Accuracy 89.34%
# Epoch [10/15] | Batch #601 | Batch Accuracy 89.36%
# Epoch [10/15] | Batch #602 | Batch Accuracy 89.39%
# Epoch [10/15] | Batch #603 | Batch Accuracy 89.41%
# Epoch [10/15] | Batch #604 | Batch Accuracy 89.55%
# Epoch [10/15] | Batch #605 | Batch Accuracy 89.45%
# Epoch [10/15] | Batch #606 | Batch Accuracy 89.47%
# Epoch [10/15] | Batch #607 | Batch Accuracy 89.55%
# Epoch [10/15] | Batch #608 | Batch Accuracy 89.57%
# Epoch [10/15] | Batch #609 | Batch Accuracy 89.64%
# Epoch [10/15] | Batch #610 | Batch Accuracy 89.34%
# Epoch [10/15] Train Loss: 0.3144 | Train Acc: 89.34% | Val Acc: 71.15% | Val Loss: 0.81%
# Epoch [11/15] | Batch #611 | Batch Accuracy 93.75%
# Epoch [11/15] | Batch #612 | Batch Accuracy 92.19%
# Epoch [11/15] | Batch #613 | Batch Accuracy 91.67%
# Epoch [11/15] | Batch #614 | Batch Accuracy 89.84%
# Epoch [11/15] | Batch #615 | Batch Accuracy 90.62%
# Epoch [11/15] | Batch #616 | Batch Accuracy 90.10%
# Epoch [11/15] | Batch #617 | Batch Accuracy 90.62%
# Epoch [11/15] | Batch #618 | Batch Accuracy 91.02%
# Epoch [11/15] | Batch #619 | Batch Accuracy 91.67%
# Epoch [11/15] | Batch #620 | Batch Accuracy 92.19%
# Epoch [11/15] | Batch #621 | Batch Accuracy 92.33%
# Epoch [11/15] | Batch #622 | Batch Accuracy 92.19%
# Epoch [11/15] | Batch #623 | Batch Accuracy 92.31%
# Epoch [11/15] | Batch #624 | Batch Accuracy 92.41%
# Epoch [11/15] | Batch #625 | Batch Accuracy 91.46%
# Epoch [11/15] | Batch #626 | Batch Accuracy 91.99%
# Epoch [11/15] | Batch #627 | Batch Accuracy 92.28%
# Epoch [11/15] | Batch #628 | Batch Accuracy 92.36%
# Epoch [11/15] | Batch #629 | Batch Accuracy 92.43%
# Epoch [11/15] | Batch #630 | Batch Accuracy 92.34%
# Epoch [11/15] | Batch #631 | Batch Accuracy 91.96%
# Epoch [11/15] | Batch #632 | Batch Accuracy 92.33%
# Epoch [11/15] | Batch #633 | Batch Accuracy 92.26%
# Epoch [11/15] | Batch #634 | Batch Accuracy 91.93%
# Epoch [11/15] | Batch #635 | Batch Accuracy 92.12%
# Epoch [11/15] | Batch #636 | Batch Accuracy 92.19%
# Epoch [11/15] | Batch #637 | Batch Accuracy 92.36%
# Epoch [11/15] | Batch #638 | Batch Accuracy 92.19%
# Epoch [11/15] | Batch #639 | Batch Accuracy 92.13%
# Epoch [11/15] | Batch #640 | Batch Accuracy 91.67%
# Epoch [11/15] | Batch #641 | Batch Accuracy 91.63%
# Epoch [11/15] | Batch #642 | Batch Accuracy 91.60%
# Epoch [11/15] | Batch #643 | Batch Accuracy 91.57%
# Epoch [11/15] | Batch #644 | Batch Accuracy 91.64%
# Epoch [11/15] | Batch #645 | Batch Accuracy 91.52%
# Epoch [11/15] | Batch #646 | Batch Accuracy 91.41%
# Epoch [11/15] | Batch #647 | Batch Accuracy 91.39%
# Epoch [11/15] | Batch #648 | Batch Accuracy 91.37%
# Epoch [11/15] | Batch #649 | Batch Accuracy 91.11%
# Epoch [11/15] | Batch #650 | Batch Accuracy 91.33%
# Epoch [11/15] | Batch #651 | Batch Accuracy 91.31%
# Epoch [11/15] | Batch #652 | Batch Accuracy 91.37%
# Epoch [11/15] | Batch #653 | Batch Accuracy 91.42%
# Epoch [11/15] | Batch #654 | Batch Accuracy 91.12%
# Epoch [11/15] | Batch #655 | Batch Accuracy 91.04%
# Epoch [11/15] | Batch #656 | Batch Accuracy 91.17%
# Epoch [11/15] | Batch #657 | Batch Accuracy 91.09%
# Epoch [11/15] | Batch #658 | Batch Accuracy 91.15%
# Epoch [11/15] | Batch #659 | Batch Accuracy 91.20%
# Epoch [11/15] | Batch #660 | Batch Accuracy 91.31%
# Epoch [11/15] | Batch #661 | Batch Accuracy 91.18%
# Epoch [11/15] | Batch #662 | Batch Accuracy 91.29%
# Epoch [11/15] | Batch #663 | Batch Accuracy 91.10%
# Epoch [11/15] | Batch #664 | Batch Accuracy 91.03%
# Epoch [11/15] | Batch #665 | Batch Accuracy 91.08%
# Epoch [11/15] | Batch #666 | Batch Accuracy 91.02%
# Epoch [11/15] | Batch #667 | Batch Accuracy 90.95%
# Epoch [11/15] | Batch #668 | Batch Accuracy 91.00%
# Epoch [11/15] | Batch #669 | Batch Accuracy 91.00%
# Epoch [11/15] | Batch #670 | Batch Accuracy 90.78%
# Epoch [11/15] | Batch #671 | Batch Accuracy 90.83%
# Epoch [11/15] Train Loss: 0.2646 | Train Acc: 90.83% | Val Acc: 77.88% | Val Loss: 0.71%
# Epoch [12/15] | Batch #672 | Batch Accuracy 78.12%
# Epoch [12/15] | Batch #673 | Batch Accuracy 84.38%
# Epoch [12/15] | Batch #674 | Batch Accuracy 85.42%
# Epoch [12/15] | Batch #675 | Batch Accuracy 87.50%
# Epoch [12/15] | Batch #676 | Batch Accuracy 88.75%
# Epoch [12/15] | Batch #677 | Batch Accuracy 88.54%
# Epoch [12/15] | Batch #678 | Batch Accuracy 87.95%
# Epoch [12/15] | Batch #679 | Batch Accuracy 88.28%
# Epoch [12/15] | Batch #680 | Batch Accuracy 88.89%
# Epoch [12/15] | Batch #681 | Batch Accuracy 90.00%
# Epoch [12/15] | Batch #682 | Batch Accuracy 90.62%
# Epoch [12/15] | Batch #683 | Batch Accuracy 90.62%
# Epoch [12/15] | Batch #684 | Batch Accuracy 90.87%
# Epoch [12/15] | Batch #685 | Batch Accuracy 90.85%
# Epoch [12/15] | Batch #686 | Batch Accuracy 90.83%
# Epoch [12/15] | Batch #687 | Batch Accuracy 90.82%
# Epoch [12/15] | Batch #688 | Batch Accuracy 90.62%
# Epoch [12/15] | Batch #689 | Batch Accuracy 90.80%
# Epoch [12/15] | Batch #690 | Batch Accuracy 90.79%
# Epoch [12/15] | Batch #691 | Batch Accuracy 90.78%
# Epoch [12/15] | Batch #692 | Batch Accuracy 90.92%
# Epoch [12/15] | Batch #693 | Batch Accuracy 90.91%
# Epoch [12/15] | Batch #694 | Batch Accuracy 90.76%
# Epoch [12/15] | Batch #695 | Batch Accuracy 90.89%
# Epoch [12/15] | Batch #696 | Batch Accuracy 91.00%
# Epoch [12/15] | Batch #697 | Batch Accuracy 91.23%
# Epoch [12/15] | Batch #698 | Batch Accuracy 91.09%
# Epoch [12/15] | Batch #699 | Batch Accuracy 91.18%
# Epoch [12/15] | Batch #700 | Batch Accuracy 91.49%
# Epoch [12/15] | Batch #701 | Batch Accuracy 91.46%
# Epoch [12/15] | Batch #702 | Batch Accuracy 91.63%
# Epoch [12/15] | Batch #703 | Batch Accuracy 91.60%
# Epoch [12/15] | Batch #704 | Batch Accuracy 91.48%
# Epoch [12/15] | Batch #705 | Batch Accuracy 91.73%
# Epoch [12/15] | Batch #706 | Batch Accuracy 91.70%
# Epoch [12/15] | Batch #707 | Batch Accuracy 91.67%
# Epoch [12/15] | Batch #708 | Batch Accuracy 91.64%
# Epoch [12/15] | Batch #709 | Batch Accuracy 91.37%
# Epoch [12/15] | Batch #710 | Batch Accuracy 91.19%
# Epoch [12/15] | Batch #711 | Batch Accuracy 91.25%
# Epoch [12/15] | Batch #712 | Batch Accuracy 91.31%
# Epoch [12/15] | Batch #713 | Batch Accuracy 91.52%
# Epoch [12/15] | Batch #714 | Batch Accuracy 91.57%
# Epoch [12/15] | Batch #715 | Batch Accuracy 91.69%
# Epoch [12/15] | Batch #716 | Batch Accuracy 91.67%
# Epoch [12/15] | Batch #717 | Batch Accuracy 91.71%
# Epoch [12/15] | Batch #718 | Batch Accuracy 91.62%
# Epoch [12/15] | Batch #719 | Batch Accuracy 91.47%
# Epoch [12/15] | Batch #720 | Batch Accuracy 91.45%
# Epoch [12/15] | Batch #721 | Batch Accuracy 91.44%
# Epoch [12/15] | Batch #722 | Batch Accuracy 91.54%
# Epoch [12/15] | Batch #723 | Batch Accuracy 91.71%
# Epoch [12/15] | Batch #724 | Batch Accuracy 91.69%
# Epoch [12/15] | Batch #725 | Batch Accuracy 91.78%
# Epoch [12/15] | Batch #726 | Batch Accuracy 91.76%
# Epoch [12/15] | Batch #727 | Batch Accuracy 91.85%
# Epoch [12/15] | Batch #728 | Batch Accuracy 91.83%
# Epoch [12/15] | Batch #729 | Batch Accuracy 91.86%
# Epoch [12/15] | Batch #730 | Batch Accuracy 91.90%
# Epoch [12/15] | Batch #731 | Batch Accuracy 91.88%
# Epoch [12/15] | Batch #732 | Batch Accuracy 91.91%
# Epoch [12/15] Train Loss: 0.2277 | Train Acc: 91.91% | Val Acc: 74.52% | Val Loss: 0.75%
# Epoch [13/15] | Batch #733 | Batch Accuracy 84.38%
# Epoch [13/15] | Batch #734 | Batch Accuracy 89.06%
# Epoch [13/15] | Batch #735 | Batch Accuracy 92.71%
# Epoch [13/15] | Batch #736 | Batch Accuracy 92.19%
# Epoch [13/15] | Batch #737 | Batch Accuracy 90.62%
# Epoch [13/15] | Batch #738 | Batch Accuracy 92.19%
# Epoch [13/15] | Batch #739 | Batch Accuracy 92.86%
# Epoch [13/15] | Batch #740 | Batch Accuracy 93.36%
# Epoch [13/15] | Batch #741 | Batch Accuracy 93.75%
# Epoch [13/15] | Batch #742 | Batch Accuracy 93.44%
# Epoch [13/15] | Batch #743 | Batch Accuracy 93.75%
# Epoch [13/15] | Batch #744 | Batch Accuracy 94.01%
# Epoch [13/15] | Batch #745 | Batch Accuracy 93.51%
# Epoch [13/15] | Batch #746 | Batch Accuracy 93.53%
# Epoch [13/15] | Batch #747 | Batch Accuracy 93.12%
# Epoch [13/15] | Batch #748 | Batch Accuracy 93.36%
# Epoch [13/15] | Batch #749 | Batch Accuracy 93.57%
# Epoch [13/15] | Batch #750 | Batch Accuracy 93.92%
# Epoch [13/15] | Batch #751 | Batch Accuracy 93.59%
# Epoch [13/15] | Batch #752 | Batch Accuracy 93.44%
# Epoch [13/15] | Batch #753 | Batch Accuracy 93.30%
# Epoch [13/15] | Batch #754 | Batch Accuracy 93.61%
# Epoch [13/15] | Batch #755 | Batch Accuracy 93.48%
# Epoch [13/15] | Batch #756 | Batch Accuracy 93.49%
# Epoch [13/15] | Batch #757 | Batch Accuracy 93.50%
# Epoch [13/15] | Batch #758 | Batch Accuracy 93.27%
# Epoch [13/15] | Batch #759 | Batch Accuracy 93.29%
# Epoch [13/15] | Batch #760 | Batch Accuracy 93.53%
# Epoch [13/15] | Batch #761 | Batch Accuracy 93.53%
# Epoch [13/15] | Batch #762 | Batch Accuracy 93.33%
# Epoch [13/15] | Batch #763 | Batch Accuracy 93.45%
# Epoch [13/15] | Batch #764 | Batch Accuracy 93.46%
# Epoch [13/15] | Batch #765 | Batch Accuracy 93.56%
# Epoch [13/15] | Batch #766 | Batch Accuracy 93.66%
# Epoch [13/15] | Batch #767 | Batch Accuracy 93.57%
# Epoch [13/15] | Batch #768 | Batch Accuracy 93.40%
# Epoch [13/15] | Batch #769 | Batch Accuracy 93.50%
# Epoch [13/15] | Batch #770 | Batch Accuracy 93.50%
# Epoch [13/15] | Batch #771 | Batch Accuracy 93.43%
# Epoch [13/15] | Batch #772 | Batch Accuracy 93.59%
# Epoch [13/15] | Batch #773 | Batch Accuracy 93.52%
# Epoch [13/15] | Batch #774 | Batch Accuracy 93.45%
# Epoch [13/15] | Batch #775 | Batch Accuracy 93.24%
# Epoch [13/15] | Batch #776 | Batch Accuracy 93.32%
# Epoch [13/15] | Batch #777 | Batch Accuracy 93.26%
# Epoch [13/15] | Batch #778 | Batch Accuracy 93.34%
# Epoch [13/15] | Batch #779 | Batch Accuracy 93.42%
# Epoch [13/15] | Batch #780 | Batch Accuracy 93.36%
# Epoch [13/15] | Batch #781 | Batch Accuracy 93.49%
# Epoch [13/15] | Batch #782 | Batch Accuracy 93.56%
# Epoch [13/15] | Batch #783 | Batch Accuracy 93.57%
# Epoch [13/15] | Batch #784 | Batch Accuracy 93.69%
# Epoch [13/15] | Batch #785 | Batch Accuracy 93.69%
# Epoch [13/15] | Batch #786 | Batch Accuracy 93.75%
# Epoch [13/15] | Batch #787 | Batch Accuracy 93.69%
# Epoch [13/15] | Batch #788 | Batch Accuracy 93.69%
# Epoch [13/15] | Batch #789 | Batch Accuracy 93.75%
# Epoch [13/15] | Batch #790 | Batch Accuracy 93.64%
# Epoch [13/15] | Batch #791 | Batch Accuracy 93.64%
# Epoch [13/15] | Batch #792 | Batch Accuracy 93.59%
# Epoch [13/15] | Batch #793 | Batch Accuracy 93.65%
# Epoch [13/15] Train Loss: 0.1927 | Train Acc: 93.65% | Val Acc: 75.24% | Val Loss: 0.68%
# Epoch [14/15] | Batch #794 | Batch Accuracy 100.00%
# Epoch [14/15] | Batch #795 | Batch Accuracy 98.44%
# Epoch [14/15] | Batch #796 | Batch Accuracy 96.88%
# Epoch [14/15] | Batch #797 | Batch Accuracy 96.09%
# Epoch [14/15] | Batch #798 | Batch Accuracy 94.38%
# Epoch [14/15] | Batch #799 | Batch Accuracy 95.31%
# Epoch [14/15] | Batch #800 | Batch Accuracy 95.54%
# Epoch [14/15] | Batch #801 | Batch Accuracy 96.09%
# Epoch [14/15] | Batch #802 | Batch Accuracy 96.18%
# Epoch [14/15] | Batch #803 | Batch Accuracy 96.25%
# Epoch [14/15] | Batch #804 | Batch Accuracy 96.59%
# Epoch [14/15] | Batch #805 | Batch Accuracy 96.88%
# Epoch [14/15] | Batch #806 | Batch Accuracy 96.88%
# Epoch [14/15] | Batch #807 | Batch Accuracy 96.65%
# Epoch [14/15] | Batch #808 | Batch Accuracy 96.67%
# Epoch [14/15] | Batch #809 | Batch Accuracy 96.48%
# Epoch [14/15] | Batch #810 | Batch Accuracy 96.51%
# Epoch [14/15] | Batch #811 | Batch Accuracy 96.35%
# Epoch [14/15] | Batch #812 | Batch Accuracy 96.22%
# Epoch [14/15] | Batch #813 | Batch Accuracy 96.41%
# Epoch [14/15] | Batch #814 | Batch Accuracy 96.58%
# Epoch [14/15] | Batch #815 | Batch Accuracy 96.59%
# Epoch [14/15] | Batch #816 | Batch Accuracy 96.60%
# Epoch [14/15] | Batch #817 | Batch Accuracy 96.61%
# Epoch [14/15] | Batch #818 | Batch Accuracy 96.12%
# Epoch [14/15] | Batch #819 | Batch Accuracy 95.91%
# Epoch [14/15] | Batch #820 | Batch Accuracy 95.49%
# Epoch [14/15] | Batch #821 | Batch Accuracy 95.54%
# Epoch [14/15] | Batch #822 | Batch Accuracy 95.58%
# Epoch [14/15] | Batch #823 | Batch Accuracy 95.62%
# Epoch [14/15] | Batch #824 | Batch Accuracy 95.56%
# Epoch [14/15] | Batch #825 | Batch Accuracy 95.31%
# Epoch [14/15] | Batch #826 | Batch Accuracy 95.27%
# Epoch [14/15] | Batch #827 | Batch Accuracy 95.31%
# Epoch [14/15] | Batch #828 | Batch Accuracy 95.36%
# Epoch [14/15] | Batch #829 | Batch Accuracy 95.23%
# Epoch [14/15] | Batch #830 | Batch Accuracy 95.35%
# Epoch [14/15] | Batch #831 | Batch Accuracy 95.31%
# Epoch [14/15] | Batch #832 | Batch Accuracy 95.35%
# Epoch [14/15] | Batch #833 | Batch Accuracy 95.39%
# Epoch [14/15] | Batch #834 | Batch Accuracy 95.27%
# Epoch [14/15] | Batch #835 | Batch Accuracy 95.31%
# Epoch [14/15] | Batch #836 | Batch Accuracy 95.20%
# Epoch [14/15] | Batch #837 | Batch Accuracy 95.31%
# Epoch [14/15] | Batch #838 | Batch Accuracy 95.42%
# Epoch [14/15] | Batch #839 | Batch Accuracy 95.52%
# Epoch [14/15] | Batch #840 | Batch Accuracy 95.48%
# Epoch [14/15] | Batch #841 | Batch Accuracy 95.51%
# Epoch [14/15] | Batch #842 | Batch Accuracy 95.41%
# Epoch [14/15] | Batch #843 | Batch Accuracy 95.50%
# Epoch [14/15] | Batch #844 | Batch Accuracy 95.53%
# Epoch [14/15] | Batch #845 | Batch Accuracy 95.55%
# Epoch [14/15] | Batch #846 | Batch Accuracy 95.52%
# Epoch [14/15] | Batch #847 | Batch Accuracy 95.37%
# Epoch [14/15] | Batch #848 | Batch Accuracy 95.34%
# Epoch [14/15] | Batch #849 | Batch Accuracy 95.42%
# Epoch [14/15] | Batch #850 | Batch Accuracy 95.39%
# Epoch [14/15] | Batch #851 | Batch Accuracy 95.42%
# Epoch [14/15] | Batch #852 | Batch Accuracy 95.39%
# Epoch [14/15] | Batch #853 | Batch Accuracy 95.47%
# Epoch [14/15] | Batch #854 | Batch Accuracy 95.49%
# Epoch [14/15] Train Loss: 0.1595 | Train Acc: 95.49% | Val Acc: 74.52% | Val Loss: 0.74%
# Epoch [15/15] | Batch #855 | Batch Accuracy 96.88%
# Epoch [15/15] | Batch #856 | Batch Accuracy 98.44%
# Epoch [15/15] | Batch #857 | Batch Accuracy 96.88%
# Epoch [15/15] | Batch #858 | Batch Accuracy 95.31%
# Epoch [15/15] | Batch #859 | Batch Accuracy 95.00%
# Epoch [15/15] | Batch #860 | Batch Accuracy 95.31%
# Epoch [15/15] | Batch #861 | Batch Accuracy 95.54%
# Epoch [15/15] | Batch #862 | Batch Accuracy 94.14%
# Epoch [15/15] | Batch #863 | Batch Accuracy 94.79%
# Epoch [15/15] | Batch #864 | Batch Accuracy 95.00%
# Epoch [15/15] | Batch #865 | Batch Accuracy 95.17%
# Epoch [15/15] | Batch #866 | Batch Accuracy 95.05%
# Epoch [15/15] | Batch #867 | Batch Accuracy 93.99%
# Epoch [15/15] | Batch #868 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #869 | Batch Accuracy 93.96%
# Epoch [15/15] | Batch #870 | Batch Accuracy 93.95%
# Epoch [15/15] | Batch #871 | Batch Accuracy 94.12%
# Epoch [15/15] | Batch #872 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #873 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #874 | Batch Accuracy 93.91%
# Epoch [15/15] | Batch #875 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #876 | Batch Accuracy 93.47%
# Epoch [15/15] | Batch #877 | Batch Accuracy 93.61%
# Epoch [15/15] | Batch #878 | Batch Accuracy 93.62%
# Epoch [15/15] | Batch #879 | Batch Accuracy 93.88%
# Epoch [15/15] | Batch #880 | Batch Accuracy 93.87%
# Epoch [15/15] | Batch #881 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #882 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #883 | Batch Accuracy 93.97%
# Epoch [15/15] | Batch #884 | Batch Accuracy 93.85%
# Epoch [15/15] | Batch #885 | Batch Accuracy 93.65%
# Epoch [15/15] | Batch #886 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #887 | Batch Accuracy 93.94%
# Epoch [15/15] | Batch #888 | Batch Accuracy 93.84%
# Epoch [15/15] | Batch #889 | Batch Accuracy 93.75%
# Epoch [15/15] | Batch #890 | Batch Accuracy 93.92%
# Epoch [15/15] | Batch #891 | Batch Accuracy 94.09%
# Epoch [15/15] | Batch #892 | Batch Accuracy 94.16%
# Epoch [15/15] | Batch #893 | Batch Accuracy 93.99%
# Epoch [15/15] | Batch #894 | Batch Accuracy 94.06%
# Epoch [15/15] | Batch #895 | Batch Accuracy 94.13%
# Epoch [15/15] | Batch #896 | Batch Accuracy 94.20%
# Epoch [15/15] | Batch #897 | Batch Accuracy 94.33%
# Epoch [15/15] | Batch #898 | Batch Accuracy 94.25%
# Epoch [15/15] | Batch #899 | Batch Accuracy 94.31%
# Epoch [15/15] | Batch #900 | Batch Accuracy 94.36%
# Epoch [15/15] | Batch #901 | Batch Accuracy 94.28%
# Epoch [15/15] | Batch #902 | Batch Accuracy 94.14%
# Epoch [15/15] | Batch #903 | Batch Accuracy 94.13%
# Epoch [15/15] | Batch #904 | Batch Accuracy 94.12%
# Epoch [15/15] | Batch #905 | Batch Accuracy 94.24%
# Epoch [15/15] | Batch #906 | Batch Accuracy 94.23%
# Epoch [15/15] | Batch #907 | Batch Accuracy 94.22%
# Epoch [15/15] | Batch #908 | Batch Accuracy 94.27%
# Epoch [15/15] | Batch #909 | Batch Accuracy 94.32%
# Epoch [15/15] | Batch #910 | Batch Accuracy 94.42%
# Epoch [15/15] | Batch #911 | Batch Accuracy 94.35%
# Epoch [15/15] | Batch #912 | Batch Accuracy 94.29%
# Epoch [15/15] | Batch #913 | Batch Accuracy 94.28%
# Epoch [15/15] | Batch #914 | Batch Accuracy 94.22%
# Epoch [15/15] | Batch #915 | Batch Accuracy 94.21%
# Epoch [15/15] Train Loss: 0.1748 | Train Acc: 94.21% | Val Acc: 80.53% | Val Loss: 0.69%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▆▅▄▃▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▃▃▅▆▆▆▆▇▆█▇▇▇█</td></tr><tr><td>validation_loss</td><td>█▇▅▃▂▃▂▂▂▂▁▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.17483</td></tr><tr><td>validation_accuracy</td><td>80.52885</td></tr><tr><td>validation_loss</td><td>0.69157</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod2</strong> at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/gas35bj8' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/gas35bj8</a><br> View project at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_150246-gas35bj8/logs</code>

# %%
plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_741931/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# *Yes, these changes were successful. The validation accuracy increased to 80.53%, which is considerable improvement over the previous model (65.62%). Having the model go through the dataset more times (higher number of epochs) gave it more time to converge on more optimal weights/biases. 15 epochs seems like a reasonable point to stop, where the accuracy is high and has somewhat leveled out between epochs. The lower batch size may have also helped the model become more generalizable to unseen data.*

# %% [markdown]
# #### Your Model 3 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# *I kept my model the same (as model 2), but added 3 image transformations to the input images (ColorJitter, GaussianBlur, and RandomSolarize). I wanted to add more variety to the images, to help prevent overfitting of the model, and thereby increase generalizability to unseen data (the validation data). This is because there was a 15% accuracy difference when going from training to validation accuracy in my previous model. My hope was to bring down this difference.*

# %%
transform = transforms.Compose([
            transforms.Resize([32,32]), # Resize the image as our model is optimized for 224x224 pixels
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]), # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))
            transforms.RandomInvert(),
            transforms.RandomAdjustSharpness(sharpness_factor=2),
            transforms.ColorJitter(brightness=.5, hue=.3),
            transforms.GaussianBlur(kernel_size=(5,9), sigma=(0.1, 5)),
            transforms.RandomSolarize(threshold=.5)])
all_images = datasets.ImageFolder(images, transform)

# %%
train_size = int(0.7 * len(all_images))
val_size = int(0.15 * len(all_images))
test_size = len(all_images) - (train_size + val_size)
print(train_size, val_size, test_size)
assert train_size + val_size + test_size == len(all_images)
train_set, val_set, test_set = torch.utils.data.random_split(all_images, [train_size, val_size, test_size])
# Out:
# 1955 419 420

# %%
train_weights = _get_weights(train_set,all_images)
train_sampler = WeightedRandomSampler(train_weights, len(train_weights))
# Out:
# Number of images per class:
# 	beluga:	n=462	weight=0.0021645021645021645
# 	common_dolphin:	n=49	weight=0.02040816326530612
# 	false_killer_whale:	n=716	weight=0.0013966480446927375
# 	fin_whale:	n=122	weight=0.00819672131147541
# 	gray_whale:	n=49	weight=0.02040816326530612
# 	humpback_whale:	n=557	weight=0.0017953321364452424

# %%
batchsize = 32
learning_rate=1e-3
epochs=15

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum = 0.9)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Vini-HappyWhale-SpeciesDataset-hyperparameters_mod3", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 15, "batch_size":32}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod3</strong> at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/inprzpco' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/inprzpco</a><br> View project at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_155811-inprzpco/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/vini/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260225_155832-9tsowjbd</code>
# Syncing run <strong><a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/9tsowjbd' target="_blank">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod3</a></strong> to <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/9tsowjbd' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/9tsowjbd</a>
# Epoch [1/15] | Batch #1 | Batch Accuracy 18.75%
# Epoch [1/15] | Batch #2 | Batch Accuracy 18.75%
# Epoch [1/15] | Batch #3 | Batch Accuracy 22.92%
# Epoch [1/15] | Batch #4 | Batch Accuracy 20.31%
# Epoch [1/15] | Batch #5 | Batch Accuracy 23.75%
# Epoch [1/15] | Batch #6 | Batch Accuracy 24.48%
# Epoch [1/15] | Batch #7 | Batch Accuracy 25.45%
# Epoch [1/15] | Batch #8 | Batch Accuracy 24.22%
# Epoch [1/15] | Batch #9 | Batch Accuracy 25.00%
# Epoch [1/15] | Batch #10 | Batch Accuracy 24.69%
# Epoch [1/15] | Batch #11 | Batch Accuracy 23.86%
# Epoch [1/15] | Batch #12 | Batch Accuracy 23.44%
# Epoch [1/15] | Batch #13 | Batch Accuracy 24.04%
# Epoch [1/15] | Batch #14 | Batch Accuracy 24.55%
# Epoch [1/15] | Batch #15 | Batch Accuracy 25.42%
# Epoch [1/15] | Batch #16 | Batch Accuracy 26.37%
# Epoch [1/15] | Batch #17 | Batch Accuracy 26.10%
# Epoch [1/15] | Batch #18 | Batch Accuracy 26.56%
# Epoch [1/15] | Batch #19 | Batch Accuracy 26.15%
# Epoch [1/15] | Batch #20 | Batch Accuracy 26.41%
# Epoch [1/15] | Batch #21 | Batch Accuracy 26.19%
# Epoch [1/15] | Batch #22 | Batch Accuracy 26.56%
# Epoch [1/15] | Batch #23 | Batch Accuracy 27.04%
# Epoch [1/15] | Batch #24 | Batch Accuracy 26.43%
# Epoch [1/15] | Batch #25 | Batch Accuracy 27.12%
# Epoch [1/15] | Batch #26 | Batch Accuracy 27.28%
# Epoch [1/15] | Batch #27 | Batch Accuracy 26.97%
# Epoch [1/15] | Batch #28 | Batch Accuracy 26.56%
# Epoch [1/15] | Batch #29 | Batch Accuracy 26.72%
# Epoch [1/15] | Batch #30 | Batch Accuracy 26.98%
# Epoch [1/15] | Batch #31 | Batch Accuracy 26.81%
# Epoch [1/15] | Batch #32 | Batch Accuracy 26.86%
# Epoch [1/15] | Batch #33 | Batch Accuracy 27.27%
# Epoch [1/15] | Batch #34 | Batch Accuracy 27.39%
# Epoch [1/15] | Batch #35 | Batch Accuracy 27.77%
# Epoch [1/15] | Batch #36 | Batch Accuracy 27.78%
# Epoch [1/15] | Batch #37 | Batch Accuracy 27.87%
# Epoch [1/15] | Batch #38 | Batch Accuracy 27.80%
# Epoch [1/15] | Batch #39 | Batch Accuracy 27.96%
# Epoch [1/15] | Batch #40 | Batch Accuracy 28.28%
# Epoch [1/15] | Batch #41 | Batch Accuracy 28.12%
# Epoch [1/15] | Batch #42 | Batch Accuracy 28.35%
# Epoch [1/15] | Batch #43 | Batch Accuracy 28.71%
# Epoch [1/15] | Batch #44 | Batch Accuracy 28.62%
# Epoch [1/15] | Batch #45 | Batch Accuracy 29.10%
# Epoch [1/15] | Batch #46 | Batch Accuracy 29.35%
# Epoch [1/15] | Batch #47 | Batch Accuracy 29.52%
# Epoch [1/15] | Batch #48 | Batch Accuracy 29.56%
# Epoch [1/15] | Batch #49 | Batch Accuracy 29.91%
# Epoch [1/15] | Batch #50 | Batch Accuracy 29.69%
# Epoch [1/15] | Batch #51 | Batch Accuracy 29.84%
# Epoch [1/15] | Batch #52 | Batch Accuracy 30.05%
# Epoch [1/15] | Batch #53 | Batch Accuracy 30.01%
# Epoch [1/15] | Batch #54 | Batch Accuracy 30.32%
# Epoch [1/15] | Batch #55 | Batch Accuracy 30.51%
# Epoch [1/15] | Batch #56 | Batch Accuracy 30.64%
# Epoch [1/15] | Batch #57 | Batch Accuracy 30.59%
# Epoch [1/15] | Batch #58 | Batch Accuracy 30.60%
# Epoch [1/15] | Batch #59 | Batch Accuracy 30.67%
# Epoch [1/15] | Batch #60 | Batch Accuracy 30.99%
# Epoch [1/15] | Batch #61 | Batch Accuracy 31.15%
# Epoch [1/15] Train Loss: 1.6541 | Train Acc: 31.15% | Val Acc: 31.97% | Val Loss: 1.56%
# Epoch [2/15] | Batch #62 | Batch Accuracy 31.25%
# Epoch [2/15] | Batch #63 | Batch Accuracy 35.94%
# Epoch [2/15] | Batch #64 | Batch Accuracy 38.54%
# Epoch [2/15] | Batch #65 | Batch Accuracy 38.28%
# Epoch [2/15] | Batch #66 | Batch Accuracy 40.00%
# Epoch [2/15] | Batch #67 | Batch Accuracy 39.06%
# Epoch [2/15] | Batch #68 | Batch Accuracy 37.50%
# Epoch [2/15] | Batch #69 | Batch Accuracy 38.28%
# Epoch [2/15] | Batch #70 | Batch Accuracy 38.89%
# Epoch [2/15] | Batch #71 | Batch Accuracy 39.06%
# Epoch [2/15] | Batch #72 | Batch Accuracy 40.06%
# Epoch [2/15] | Batch #73 | Batch Accuracy 40.62%
# Epoch [2/15] | Batch #74 | Batch Accuracy 40.87%
# Epoch [2/15] | Batch #75 | Batch Accuracy 41.96%
# Epoch [2/15] | Batch #76 | Batch Accuracy 41.04%
# Epoch [2/15] | Batch #77 | Batch Accuracy 41.02%
# Epoch [2/15] | Batch #78 | Batch Accuracy 41.36%
# Epoch [2/15] | Batch #79 | Batch Accuracy 41.67%
# Epoch [2/15] | Batch #80 | Batch Accuracy 41.94%
# Epoch [2/15] | Batch #81 | Batch Accuracy 41.72%
# Epoch [2/15] | Batch #82 | Batch Accuracy 42.41%
# Epoch [2/15] | Batch #83 | Batch Accuracy 42.19%
# Epoch [2/15] | Batch #84 | Batch Accuracy 41.71%
# Epoch [2/15] | Batch #85 | Batch Accuracy 41.54%
# Epoch [2/15] | Batch #86 | Batch Accuracy 41.62%
# Epoch [2/15] | Batch #87 | Batch Accuracy 41.71%
# Epoch [2/15] | Batch #88 | Batch Accuracy 41.67%
# Epoch [2/15] | Batch #89 | Batch Accuracy 41.63%
# Epoch [2/15] | Batch #90 | Batch Accuracy 41.81%
# Epoch [2/15] | Batch #91 | Batch Accuracy 41.56%
# Epoch [2/15] | Batch #92 | Batch Accuracy 41.53%
# Epoch [2/15] | Batch #93 | Batch Accuracy 41.70%
# Epoch [2/15] | Batch #94 | Batch Accuracy 41.67%
# Epoch [2/15] | Batch #95 | Batch Accuracy 41.64%
# Epoch [2/15] | Batch #96 | Batch Accuracy 41.25%
# Epoch [2/15] | Batch #97 | Batch Accuracy 41.15%
# Epoch [2/15] | Batch #98 | Batch Accuracy 41.13%
# Epoch [2/15] | Batch #99 | Batch Accuracy 41.12%
# Epoch [2/15] | Batch #100 | Batch Accuracy 41.19%
# Epoch [2/15] | Batch #101 | Batch Accuracy 41.56%
# Epoch [2/15] | Batch #102 | Batch Accuracy 41.46%
# Epoch [2/15] | Batch #103 | Batch Accuracy 41.44%
# Epoch [2/15] | Batch #104 | Batch Accuracy 41.86%
# Epoch [2/15] | Batch #105 | Batch Accuracy 42.05%
# Epoch [2/15] | Batch #106 | Batch Accuracy 41.88%
# Epoch [2/15] | Batch #107 | Batch Accuracy 41.85%
# Epoch [2/15] | Batch #108 | Batch Accuracy 42.02%
# Epoch [2/15] | Batch #109 | Batch Accuracy 42.19%
# Epoch [2/15] | Batch #110 | Batch Accuracy 42.47%
# Epoch [2/15] | Batch #111 | Batch Accuracy 42.44%
# Epoch [2/15] | Batch #112 | Batch Accuracy 42.40%
# Epoch [2/15] | Batch #113 | Batch Accuracy 42.31%
# Epoch [2/15] | Batch #114 | Batch Accuracy 42.28%
# Epoch [2/15] | Batch #115 | Batch Accuracy 42.30%
# Epoch [2/15] | Batch #116 | Batch Accuracy 42.50%
# Epoch [2/15] | Batch #117 | Batch Accuracy 42.63%
# Epoch [2/15] | Batch #118 | Batch Accuracy 42.43%
# Epoch [2/15] | Batch #119 | Batch Accuracy 42.40%
# Epoch [2/15] | Batch #120 | Batch Accuracy 42.53%
# Epoch [2/15] | Batch #121 | Batch Accuracy 42.40%
# Epoch [2/15] | Batch #122 | Batch Accuracy 42.47%
# Epoch [2/15] Train Loss: 1.4813 | Train Acc: 42.47% | Val Acc: 43.27% | Val Loss: 1.42%
# Epoch [3/15] | Batch #123 | Batch Accuracy 56.25%
# Epoch [3/15] | Batch #124 | Batch Accuracy 60.94%
# Epoch [3/15] | Batch #125 | Batch Accuracy 53.12%
# Epoch [3/15] | Batch #126 | Batch Accuracy 53.91%
# Epoch [3/15] | Batch #127 | Batch Accuracy 54.37%
# Epoch [3/15] | Batch #128 | Batch Accuracy 52.60%
# Epoch [3/15] | Batch #129 | Batch Accuracy 50.45%
# Epoch [3/15] | Batch #130 | Batch Accuracy 50.39%
# Epoch [3/15] | Batch #131 | Batch Accuracy 52.08%
# Epoch [3/15] | Batch #132 | Batch Accuracy 52.81%
# Epoch [3/15] | Batch #133 | Batch Accuracy 53.12%
# Epoch [3/15] | Batch #134 | Batch Accuracy 51.56%
# Epoch [3/15] | Batch #135 | Batch Accuracy 52.16%
# Epoch [3/15] | Batch #136 | Batch Accuracy 52.23%
# Epoch [3/15] | Batch #137 | Batch Accuracy 51.88%
# Epoch [3/15] | Batch #138 | Batch Accuracy 51.17%
# Epoch [3/15] | Batch #139 | Batch Accuracy 50.55%
# Epoch [3/15] | Batch #140 | Batch Accuracy 51.22%
# Epoch [3/15] | Batch #141 | Batch Accuracy 50.33%
# Epoch [3/15] | Batch #142 | Batch Accuracy 50.47%
# Epoch [3/15] | Batch #143 | Batch Accuracy 50.15%
# Epoch [3/15] | Batch #144 | Batch Accuracy 50.14%
# Epoch [3/15] | Batch #145 | Batch Accuracy 50.82%
# Epoch [3/15] | Batch #146 | Batch Accuracy 50.78%
# Epoch [3/15] | Batch #147 | Batch Accuracy 50.62%
# Epoch [3/15] | Batch #148 | Batch Accuracy 50.36%
# Epoch [3/15] | Batch #149 | Batch Accuracy 49.77%
# Epoch [3/15] | Batch #150 | Batch Accuracy 49.33%
# Epoch [3/15] | Batch #151 | Batch Accuracy 49.03%
# Epoch [3/15] | Batch #152 | Batch Accuracy 48.96%
# Epoch [3/15] | Batch #153 | Batch Accuracy 48.99%
# Epoch [3/15] | Batch #154 | Batch Accuracy 49.02%
# Epoch [3/15] | Batch #155 | Batch Accuracy 48.96%
# Epoch [3/15] | Batch #156 | Batch Accuracy 48.81%
# Epoch [3/15] | Batch #157 | Batch Accuracy 48.93%
# Epoch [3/15] | Batch #158 | Batch Accuracy 48.61%
# Epoch [3/15] | Batch #159 | Batch Accuracy 47.97%
# Epoch [3/15] | Batch #160 | Batch Accuracy 48.11%
# Epoch [3/15] | Batch #161 | Batch Accuracy 47.92%
# Epoch [3/15] | Batch #162 | Batch Accuracy 47.58%
# Epoch [3/15] | Batch #163 | Batch Accuracy 47.56%
# Epoch [3/15] | Batch #164 | Batch Accuracy 47.62%
# Epoch [3/15] | Batch #165 | Batch Accuracy 47.67%
# Epoch [3/15] | Batch #166 | Batch Accuracy 47.66%
# Epoch [3/15] | Batch #167 | Batch Accuracy 47.36%
# Epoch [3/15] | Batch #168 | Batch Accuracy 47.21%
# Epoch [3/15] | Batch #169 | Batch Accuracy 47.21%
# Epoch [3/15] | Batch #170 | Batch Accuracy 47.14%
# Epoch [3/15] | Batch #171 | Batch Accuracy 47.19%
# Epoch [3/15] | Batch #172 | Batch Accuracy 47.50%
# Epoch [3/15] | Batch #173 | Batch Accuracy 47.49%
# Epoch [3/15] | Batch #174 | Batch Accuracy 47.48%
# Epoch [3/15] | Batch #175 | Batch Accuracy 47.41%
# Epoch [3/15] | Batch #176 | Batch Accuracy 47.45%
# Epoch [3/15] | Batch #177 | Batch Accuracy 47.44%
# Epoch [3/15] | Batch #178 | Batch Accuracy 47.32%
# Epoch [3/15] | Batch #179 | Batch Accuracy 47.42%
# Epoch [3/15] | Batch #180 | Batch Accuracy 47.41%
# Epoch [3/15] | Batch #181 | Batch Accuracy 47.56%
# Epoch [3/15] | Batch #182 | Batch Accuracy 47.86%
# Epoch [3/15] | Batch #183 | Batch Accuracy 47.59%
# Epoch [3/15] Train Loss: 1.3635 | Train Acc: 47.59% | Val Acc: 36.54% | Val Loss: 1.44%
# Epoch [4/15] | Batch #184 | Batch Accuracy 43.75%
# Epoch [4/15] | Batch #185 | Batch Accuracy 50.00%
# Epoch [4/15] | Batch #186 | Batch Accuracy 53.12%
# Epoch [4/15] | Batch #187 | Batch Accuracy 50.78%
# Epoch [4/15] | Batch #188 | Batch Accuracy 46.88%
# Epoch [4/15] | Batch #189 | Batch Accuracy 47.92%
# Epoch [4/15] | Batch #190 | Batch Accuracy 48.21%
# Epoch [4/15] | Batch #191 | Batch Accuracy 48.05%
# Epoch [4/15] | Batch #192 | Batch Accuracy 49.31%
# Epoch [4/15] | Batch #193 | Batch Accuracy 47.81%
# Epoch [4/15] | Batch #194 | Batch Accuracy 48.01%
# Epoch [4/15] | Batch #195 | Batch Accuracy 49.74%
# Epoch [4/15] | Batch #196 | Batch Accuracy 50.24%
# Epoch [4/15] | Batch #197 | Batch Accuracy 51.12%
# Epoch [4/15] | Batch #198 | Batch Accuracy 51.04%
# Epoch [4/15] | Batch #199 | Batch Accuracy 51.17%
# Epoch [4/15] | Batch #200 | Batch Accuracy 50.92%
# Epoch [4/15] | Batch #201 | Batch Accuracy 51.39%
# Epoch [4/15] | Batch #202 | Batch Accuracy 51.48%
# Epoch [4/15] | Batch #203 | Batch Accuracy 51.25%
# Epoch [4/15] | Batch #204 | Batch Accuracy 50.60%
# Epoch [4/15] | Batch #205 | Batch Accuracy 50.57%
# Epoch [4/15] | Batch #206 | Batch Accuracy 50.27%
# Epoch [4/15] | Batch #207 | Batch Accuracy 50.13%
# Epoch [4/15] | Batch #208 | Batch Accuracy 50.25%
# Epoch [4/15] | Batch #209 | Batch Accuracy 50.84%
# Epoch [4/15] | Batch #210 | Batch Accuracy 50.81%
# Epoch [4/15] | Batch #211 | Batch Accuracy 50.45%
# Epoch [4/15] | Batch #212 | Batch Accuracy 50.32%
# Epoch [4/15] | Batch #213 | Batch Accuracy 50.73%
# Epoch [4/15] | Batch #214 | Batch Accuracy 50.20%
# Epoch [4/15] | Batch #215 | Batch Accuracy 49.90%
# Epoch [4/15] | Batch #216 | Batch Accuracy 49.81%
# Epoch [4/15] | Batch #217 | Batch Accuracy 49.72%
# Epoch [4/15] | Batch #218 | Batch Accuracy 50.00%
# Epoch [4/15] | Batch #219 | Batch Accuracy 49.83%
# Epoch [4/15] | Batch #220 | Batch Accuracy 49.58%
# Epoch [4/15] | Batch #221 | Batch Accuracy 49.75%
# Epoch [4/15] | Batch #222 | Batch Accuracy 49.84%
# Epoch [4/15] | Batch #223 | Batch Accuracy 49.61%
# Epoch [4/15] | Batch #224 | Batch Accuracy 49.47%
# Epoch [4/15] | Batch #225 | Batch Accuracy 49.78%
# Epoch [4/15] | Batch #226 | Batch Accuracy 49.85%
# Epoch [4/15] | Batch #227 | Batch Accuracy 49.86%
# Epoch [4/15] | Batch #228 | Batch Accuracy 49.58%
# Epoch [4/15] | Batch #229 | Batch Accuracy 49.52%
# Epoch [4/15] | Batch #230 | Batch Accuracy 49.53%
# Epoch [4/15] | Batch #231 | Batch Accuracy 49.74%
# Epoch [4/15] | Batch #232 | Batch Accuracy 49.74%
# Epoch [4/15] | Batch #233 | Batch Accuracy 50.00%
# Epoch [4/15] | Batch #234 | Batch Accuracy 49.94%
# Epoch [4/15] | Batch #235 | Batch Accuracy 49.94%
# Epoch [4/15] | Batch #236 | Batch Accuracy 49.88%
# Epoch [4/15] | Batch #237 | Batch Accuracy 50.06%
# Epoch [4/15] | Batch #238 | Batch Accuracy 50.51%
# Epoch [4/15] | Batch #239 | Batch Accuracy 50.39%
# Epoch [4/15] | Batch #240 | Batch Accuracy 50.38%
# Epoch [4/15] | Batch #241 | Batch Accuracy 50.38%
# Epoch [4/15] | Batch #242 | Batch Accuracy 50.21%
# Epoch [4/15] | Batch #243 | Batch Accuracy 50.31%
# Epoch [4/15] | Batch #244 | Batch Accuracy 50.26%
# Epoch [4/15] Train Loss: 1.2798 | Train Acc: 50.26% | Val Acc: 43.99% | Val Loss: 1.32%
# Epoch [5/15] | Batch #245 | Batch Accuracy 59.38%
# Epoch [5/15] | Batch #246 | Batch Accuracy 59.38%
# Epoch [5/15] | Batch #247 | Batch Accuracy 56.25%
# Epoch [5/15] | Batch #248 | Batch Accuracy 54.69%
# Epoch [5/15] | Batch #249 | Batch Accuracy 53.75%
# Epoch [5/15] | Batch #250 | Batch Accuracy 54.17%
# Epoch [5/15] | Batch #251 | Batch Accuracy 55.36%
# Epoch [5/15] | Batch #252 | Batch Accuracy 55.47%
# Epoch [5/15] | Batch #253 | Batch Accuracy 54.86%
# Epoch [5/15] | Batch #254 | Batch Accuracy 55.00%
# Epoch [5/15] | Batch #255 | Batch Accuracy 54.55%
# Epoch [5/15] | Batch #256 | Batch Accuracy 54.69%
# Epoch [5/15] | Batch #257 | Batch Accuracy 55.29%
# Epoch [5/15] | Batch #258 | Batch Accuracy 55.58%
# Epoch [5/15] | Batch #259 | Batch Accuracy 54.58%
# Epoch [5/15] | Batch #260 | Batch Accuracy 53.71%
# Epoch [5/15] | Batch #261 | Batch Accuracy 53.31%
# Epoch [5/15] | Batch #262 | Batch Accuracy 52.78%
# Epoch [5/15] | Batch #263 | Batch Accuracy 53.45%
# Epoch [5/15] | Batch #264 | Batch Accuracy 53.75%
# Epoch [5/15] | Batch #265 | Batch Accuracy 54.61%
# Epoch [5/15] | Batch #266 | Batch Accuracy 54.97%
# Epoch [5/15] | Batch #267 | Batch Accuracy 55.03%
# Epoch [5/15] | Batch #268 | Batch Accuracy 55.21%
# Epoch [5/15] | Batch #269 | Batch Accuracy 55.12%
# Epoch [5/15] | Batch #270 | Batch Accuracy 55.65%
# Epoch [5/15] | Batch #271 | Batch Accuracy 55.56%
# Epoch [5/15] | Batch #272 | Batch Accuracy 55.92%
# Epoch [5/15] | Batch #273 | Batch Accuracy 55.60%
# Epoch [5/15] | Batch #274 | Batch Accuracy 55.21%
# Epoch [5/15] | Batch #275 | Batch Accuracy 54.84%
# Epoch [5/15] | Batch #276 | Batch Accuracy 54.39%
# Epoch [5/15] | Batch #277 | Batch Accuracy 54.36%
# Epoch [5/15] | Batch #278 | Batch Accuracy 54.78%
# Epoch [5/15] | Batch #279 | Batch Accuracy 55.00%
# Epoch [5/15] | Batch #280 | Batch Accuracy 54.69%
# Epoch [5/15] | Batch #281 | Batch Accuracy 54.65%
# Epoch [5/15] | Batch #282 | Batch Accuracy 54.61%
# Epoch [5/15] | Batch #283 | Batch Accuracy 54.65%
# Epoch [5/15] | Batch #284 | Batch Accuracy 54.61%
# Epoch [5/15] | Batch #285 | Batch Accuracy 54.57%
# Epoch [5/15] | Batch #286 | Batch Accuracy 54.54%
# Epoch [5/15] | Batch #287 | Batch Accuracy 54.36%
# Epoch [5/15] | Batch #288 | Batch Accuracy 54.19%
# Epoch [5/15] | Batch #289 | Batch Accuracy 54.24%
# Epoch [5/15] | Batch #290 | Batch Accuracy 54.14%
# Epoch [5/15] | Batch #291 | Batch Accuracy 54.45%
# Epoch [5/15] | Batch #292 | Batch Accuracy 54.43%
# Epoch [5/15] | Batch #293 | Batch Accuracy 54.40%
# Epoch [5/15] | Batch #294 | Batch Accuracy 54.25%
# Epoch [5/15] | Batch #295 | Batch Accuracy 54.29%
# Epoch [5/15] | Batch #296 | Batch Accuracy 54.33%
# Epoch [5/15] | Batch #297 | Batch Accuracy 54.19%
# Epoch [5/15] | Batch #298 | Batch Accuracy 54.17%
# Epoch [5/15] | Batch #299 | Batch Accuracy 54.15%
# Epoch [5/15] | Batch #300 | Batch Accuracy 54.19%
# Epoch [5/15] | Batch #301 | Batch Accuracy 54.11%
# Epoch [5/15] | Batch #302 | Batch Accuracy 53.93%
# Epoch [5/15] | Batch #303 | Batch Accuracy 54.18%
# Epoch [5/15] | Batch #304 | Batch Accuracy 54.43%
# Epoch [5/15] | Batch #305 | Batch Accuracy 54.51%
# Epoch [5/15] Train Loss: 1.1713 | Train Acc: 54.51% | Val Acc: 48.08% | Val Loss: 1.30%
# Epoch [6/15] | Batch #306 | Batch Accuracy 53.12%
# Epoch [6/15] | Batch #307 | Batch Accuracy 60.94%
# Epoch [6/15] | Batch #308 | Batch Accuracy 62.50%
# Epoch [6/15] | Batch #309 | Batch Accuracy 60.94%
# Epoch [6/15] | Batch #310 | Batch Accuracy 59.38%
# Epoch [6/15] | Batch #311 | Batch Accuracy 61.46%
# Epoch [6/15] | Batch #312 | Batch Accuracy 60.27%
# Epoch [6/15] | Batch #313 | Batch Accuracy 57.42%
# Epoch [6/15] | Batch #314 | Batch Accuracy 55.90%
# Epoch [6/15] | Batch #315 | Batch Accuracy 55.00%
# Epoch [6/15] | Batch #316 | Batch Accuracy 55.40%
# Epoch [6/15] | Batch #317 | Batch Accuracy 53.91%
# Epoch [6/15] | Batch #318 | Batch Accuracy 53.61%
# Epoch [6/15] | Batch #319 | Batch Accuracy 53.57%
# Epoch [6/15] | Batch #320 | Batch Accuracy 53.33%
# Epoch [6/15] | Batch #321 | Batch Accuracy 53.12%
# Epoch [6/15] | Batch #322 | Batch Accuracy 53.31%
# Epoch [6/15] | Batch #323 | Batch Accuracy 53.47%
# Epoch [6/15] | Batch #324 | Batch Accuracy 54.11%
# Epoch [6/15] | Batch #325 | Batch Accuracy 54.69%
# Epoch [6/15] | Batch #326 | Batch Accuracy 55.51%
# Epoch [6/15] | Batch #327 | Batch Accuracy 55.26%
# Epoch [6/15] | Batch #328 | Batch Accuracy 55.71%
# Epoch [6/15] | Batch #329 | Batch Accuracy 56.12%
# Epoch [6/15] | Batch #330 | Batch Accuracy 55.88%
# Epoch [6/15] | Batch #331 | Batch Accuracy 56.25%
# Epoch [6/15] | Batch #332 | Batch Accuracy 56.71%
# Epoch [6/15] | Batch #333 | Batch Accuracy 56.58%
# Epoch [6/15] | Batch #334 | Batch Accuracy 56.36%
# Epoch [6/15] | Batch #335 | Batch Accuracy 56.67%
# Epoch [6/15] | Batch #336 | Batch Accuracy 56.55%
# Epoch [6/15] | Batch #337 | Batch Accuracy 56.74%
# Epoch [6/15] | Batch #338 | Batch Accuracy 56.82%
# Epoch [6/15] | Batch #339 | Batch Accuracy 56.34%
# Epoch [6/15] | Batch #340 | Batch Accuracy 56.07%
# Epoch [6/15] | Batch #341 | Batch Accuracy 56.51%
# Epoch [6/15] | Batch #342 | Batch Accuracy 56.67%
# Epoch [6/15] | Batch #343 | Batch Accuracy 56.74%
# Epoch [6/15] | Batch #344 | Batch Accuracy 56.73%
# Epoch [6/15] | Batch #345 | Batch Accuracy 56.72%
# Epoch [6/15] | Batch #346 | Batch Accuracy 56.55%
# Epoch [6/15] | Batch #347 | Batch Accuracy 57.14%
# Epoch [6/15] | Batch #348 | Batch Accuracy 56.98%
# Epoch [6/15] | Batch #349 | Batch Accuracy 57.17%
# Epoch [6/15] | Batch #350 | Batch Accuracy 57.22%
# Epoch [6/15] | Batch #351 | Batch Accuracy 57.47%
# Epoch [6/15] | Batch #352 | Batch Accuracy 57.65%
# Epoch [6/15] | Batch #353 | Batch Accuracy 57.36%
# Epoch [6/15] | Batch #354 | Batch Accuracy 57.46%
# Epoch [6/15] | Batch #355 | Batch Accuracy 57.56%
# Epoch [6/15] | Batch #356 | Batch Accuracy 57.72%
# Epoch [6/15] | Batch #357 | Batch Accuracy 57.75%
# Epoch [6/15] | Batch #358 | Batch Accuracy 57.90%
# Epoch [6/15] | Batch #359 | Batch Accuracy 58.04%
# Epoch [6/15] | Batch #360 | Batch Accuracy 58.18%
# Epoch [6/15] | Batch #361 | Batch Accuracy 57.87%
# Epoch [6/15] | Batch #362 | Batch Accuracy 57.84%
# Epoch [6/15] | Batch #363 | Batch Accuracy 57.81%
# Epoch [6/15] | Batch #364 | Batch Accuracy 57.84%
# Epoch [6/15] | Batch #365 | Batch Accuracy 57.81%
# Epoch [6/15] | Batch #366 | Batch Accuracy 57.84%
# Epoch [6/15] Train Loss: 1.0858 | Train Acc: 57.84% | Val Acc: 52.88% | Val Loss: 1.20%
# Epoch [7/15] | Batch #367 | Batch Accuracy 65.62%
# Epoch [7/15] | Batch #368 | Batch Accuracy 57.81%
# Epoch [7/15] | Batch #369 | Batch Accuracy 59.38%
# Epoch [7/15] | Batch #370 | Batch Accuracy 59.38%
# Epoch [7/15] | Batch #371 | Batch Accuracy 54.37%
# Epoch [7/15] | Batch #372 | Batch Accuracy 52.60%
# Epoch [7/15] | Batch #373 | Batch Accuracy 52.68%
# Epoch [7/15] | Batch #374 | Batch Accuracy 53.91%
# Epoch [7/15] | Batch #375 | Batch Accuracy 54.51%
# Epoch [7/15] | Batch #376 | Batch Accuracy 53.75%
# Epoch [7/15] | Batch #377 | Batch Accuracy 54.26%
# Epoch [7/15] | Batch #378 | Batch Accuracy 54.69%
# Epoch [7/15] | Batch #379 | Batch Accuracy 55.53%
# Epoch [7/15] | Batch #380 | Batch Accuracy 56.03%
# Epoch [7/15] | Batch #381 | Batch Accuracy 56.46%
# Epoch [7/15] | Batch #382 | Batch Accuracy 56.84%
# Epoch [7/15] | Batch #383 | Batch Accuracy 57.17%
# Epoch [7/15] | Batch #384 | Batch Accuracy 57.12%
# Epoch [7/15] | Batch #385 | Batch Accuracy 57.89%
# Epoch [7/15] | Batch #386 | Batch Accuracy 57.66%
# Epoch [7/15] | Batch #387 | Batch Accuracy 58.18%
# Epoch [7/15] | Batch #388 | Batch Accuracy 58.66%
# Epoch [7/15] | Batch #389 | Batch Accuracy 58.15%
# Epoch [7/15] | Batch #390 | Batch Accuracy 58.20%
# Epoch [7/15] | Batch #391 | Batch Accuracy 58.00%
# Epoch [7/15] | Batch #392 | Batch Accuracy 58.05%
# Epoch [7/15] | Batch #393 | Batch Accuracy 57.99%
# Epoch [7/15] | Batch #394 | Batch Accuracy 58.04%
# Epoch [7/15] | Batch #395 | Batch Accuracy 58.08%
# Epoch [7/15] | Batch #396 | Batch Accuracy 58.23%
# Epoch [7/15] | Batch #397 | Batch Accuracy 57.76%
# Epoch [7/15] | Batch #398 | Batch Accuracy 57.91%
# Epoch [7/15] | Batch #399 | Batch Accuracy 58.05%
# Epoch [7/15] | Batch #400 | Batch Accuracy 57.54%
# Epoch [7/15] | Batch #401 | Batch Accuracy 57.50%
# Epoch [7/15] | Batch #402 | Batch Accuracy 57.29%
# Epoch [7/15] | Batch #403 | Batch Accuracy 56.93%
# Epoch [7/15] | Batch #404 | Batch Accuracy 57.15%
# Epoch [7/15] | Batch #405 | Batch Accuracy 57.05%
# Epoch [7/15] | Batch #406 | Batch Accuracy 57.11%
# Epoch [7/15] | Batch #407 | Batch Accuracy 57.47%
# Epoch [7/15] | Batch #408 | Batch Accuracy 57.29%
# Epoch [7/15] | Batch #409 | Batch Accuracy 57.56%
# Epoch [7/15] | Batch #410 | Batch Accuracy 57.88%
# Epoch [7/15] | Batch #411 | Batch Accuracy 57.99%
# Epoch [7/15] | Batch #412 | Batch Accuracy 57.81%
# Epoch [7/15] | Batch #413 | Batch Accuracy 58.05%
# Epoch [7/15] | Batch #414 | Batch Accuracy 58.14%
# Epoch [7/15] | Batch #415 | Batch Accuracy 58.16%
# Epoch [7/15] | Batch #416 | Batch Accuracy 58.19%
# Epoch [7/15] | Batch #417 | Batch Accuracy 58.09%
# Epoch [7/15] | Batch #418 | Batch Accuracy 57.99%
# Epoch [7/15] | Batch #419 | Batch Accuracy 58.02%
# Epoch [7/15] | Batch #420 | Batch Accuracy 58.04%
# Epoch [7/15] | Batch #421 | Batch Accuracy 58.13%
# Epoch [7/15] | Batch #422 | Batch Accuracy 58.15%
# Epoch [7/15] | Batch #423 | Batch Accuracy 58.17%
# Epoch [7/15] | Batch #424 | Batch Accuracy 58.24%
# Epoch [7/15] | Batch #425 | Batch Accuracy 58.37%
# Epoch [7/15] | Batch #426 | Batch Accuracy 58.54%
# Epoch [7/15] | Batch #427 | Batch Accuracy 58.56%
# Epoch [7/15] Train Loss: 1.0682 | Train Acc: 58.56% | Val Acc: 46.88% | Val Loss: 1.27%
# Epoch [8/15] | Batch #428 | Batch Accuracy 65.62%
# Epoch [8/15] | Batch #429 | Batch Accuracy 65.62%
# Epoch [8/15] | Batch #430 | Batch Accuracy 65.62%
# Epoch [8/15] | Batch #431 | Batch Accuracy 65.62%
# Epoch [8/15] | Batch #432 | Batch Accuracy 62.50%
# Epoch [8/15] | Batch #433 | Batch Accuracy 64.06%
# Epoch [8/15] | Batch #434 | Batch Accuracy 64.29%
# Epoch [8/15] | Batch #435 | Batch Accuracy 63.28%
# Epoch [8/15] | Batch #436 | Batch Accuracy 63.19%
# Epoch [8/15] | Batch #437 | Batch Accuracy 62.81%
# Epoch [8/15] | Batch #438 | Batch Accuracy 63.07%
# Epoch [8/15] | Batch #439 | Batch Accuracy 62.24%
# Epoch [8/15] | Batch #440 | Batch Accuracy 62.98%
# Epoch [8/15] | Batch #441 | Batch Accuracy 63.84%
# Epoch [8/15] | Batch #442 | Batch Accuracy 64.17%
# Epoch [8/15] | Batch #443 | Batch Accuracy 64.26%
# Epoch [8/15] | Batch #444 | Batch Accuracy 64.15%
# Epoch [8/15] | Batch #445 | Batch Accuracy 64.24%
# Epoch [8/15] | Batch #446 | Batch Accuracy 63.49%
# Epoch [8/15] | Batch #447 | Batch Accuracy 63.12%
# Epoch [8/15] | Batch #448 | Batch Accuracy 63.24%
# Epoch [8/15] | Batch #449 | Batch Accuracy 62.93%
# Epoch [8/15] | Batch #450 | Batch Accuracy 62.77%
# Epoch [8/15] | Batch #451 | Batch Accuracy 63.28%
# Epoch [8/15] | Batch #452 | Batch Accuracy 63.38%
# Epoch [8/15] | Batch #453 | Batch Accuracy 63.46%
# Epoch [8/15] | Batch #454 | Batch Accuracy 63.89%
# Epoch [8/15] | Batch #455 | Batch Accuracy 63.39%
# Epoch [8/15] | Batch #456 | Batch Accuracy 63.15%
# Epoch [8/15] | Batch #457 | Batch Accuracy 62.50%
# Epoch [8/15] | Batch #458 | Batch Accuracy 62.00%
# Epoch [8/15] | Batch #459 | Batch Accuracy 62.01%
# Epoch [8/15] | Batch #460 | Batch Accuracy 62.22%
# Epoch [8/15] | Batch #461 | Batch Accuracy 62.41%
# Epoch [8/15] | Batch #462 | Batch Accuracy 62.50%
# Epoch [8/15] | Batch #463 | Batch Accuracy 62.24%
# Epoch [8/15] | Batch #464 | Batch Accuracy 62.58%
# Epoch [8/15] | Batch #465 | Batch Accuracy 62.34%
# Epoch [8/15] | Batch #466 | Batch Accuracy 62.18%
# Epoch [8/15] | Batch #467 | Batch Accuracy 62.19%
# Epoch [8/15] | Batch #468 | Batch Accuracy 62.20%
# Epoch [8/15] | Batch #469 | Batch Accuracy 61.76%
# Epoch [8/15] | Batch #470 | Batch Accuracy 61.77%
# Epoch [8/15] | Batch #471 | Batch Accuracy 61.65%
# Epoch [8/15] | Batch #472 | Batch Accuracy 61.67%
# Epoch [8/15] | Batch #473 | Batch Accuracy 61.75%
# Epoch [8/15] | Batch #474 | Batch Accuracy 61.70%
# Epoch [8/15] | Batch #475 | Batch Accuracy 61.59%
# Epoch [8/15] | Batch #476 | Batch Accuracy 61.67%
# Epoch [8/15] | Batch #477 | Batch Accuracy 61.75%
# Epoch [8/15] | Batch #478 | Batch Accuracy 61.58%
# Epoch [8/15] | Batch #479 | Batch Accuracy 61.78%
# Epoch [8/15] | Batch #480 | Batch Accuracy 61.97%
# Epoch [8/15] | Batch #481 | Batch Accuracy 61.92%
# Epoch [8/15] | Batch #482 | Batch Accuracy 62.10%
# Epoch [8/15] | Batch #483 | Batch Accuracy 62.22%
# Epoch [8/15] | Batch #484 | Batch Accuracy 62.06%
# Epoch [8/15] | Batch #485 | Batch Accuracy 62.28%
# Epoch [8/15] | Batch #486 | Batch Accuracy 62.08%
# Epoch [8/15] | Batch #487 | Batch Accuracy 62.14%
# Epoch [8/15] | Batch #488 | Batch Accuracy 62.09%
# Epoch [8/15] Train Loss: 0.9841 | Train Acc: 62.09% | Val Acc: 57.21% | Val Loss: 1.08%
# Epoch [9/15] | Batch #489 | Batch Accuracy 75.00%
# Epoch [9/15] | Batch #490 | Batch Accuracy 71.88%
# Epoch [9/15] | Batch #491 | Batch Accuracy 65.62%
# Epoch [9/15] | Batch #492 | Batch Accuracy 64.06%
# Epoch [9/15] | Batch #493 | Batch Accuracy 60.00%
# Epoch [9/15] | Batch #494 | Batch Accuracy 60.42%
# Epoch [9/15] | Batch #495 | Batch Accuracy 58.93%
# Epoch [9/15] | Batch #496 | Batch Accuracy 58.59%
# Epoch [9/15] | Batch #497 | Batch Accuracy 60.07%
# Epoch [9/15] | Batch #498 | Batch Accuracy 60.31%
# Epoch [9/15] | Batch #499 | Batch Accuracy 60.23%
# Epoch [9/15] | Batch #500 | Batch Accuracy 60.16%
# Epoch [9/15] | Batch #501 | Batch Accuracy 60.10%
# Epoch [9/15] | Batch #502 | Batch Accuracy 60.04%
# Epoch [9/15] | Batch #503 | Batch Accuracy 60.42%
# Epoch [9/15] | Batch #504 | Batch Accuracy 59.96%
# Epoch [9/15] | Batch #505 | Batch Accuracy 60.66%
# Epoch [9/15] | Batch #506 | Batch Accuracy 60.42%
# Epoch [9/15] | Batch #507 | Batch Accuracy 61.02%
# Epoch [9/15] | Batch #508 | Batch Accuracy 61.09%
# Epoch [9/15] | Batch #509 | Batch Accuracy 61.01%
# Epoch [9/15] | Batch #510 | Batch Accuracy 60.80%
# Epoch [9/15] | Batch #511 | Batch Accuracy 60.60%
# Epoch [9/15] | Batch #512 | Batch Accuracy 61.20%
# Epoch [9/15] | Batch #513 | Batch Accuracy 61.12%
# Epoch [9/15] | Batch #514 | Batch Accuracy 61.18%
# Epoch [9/15] | Batch #515 | Batch Accuracy 61.00%
# Epoch [9/15] | Batch #516 | Batch Accuracy 61.16%
# Epoch [9/15] | Batch #517 | Batch Accuracy 61.10%
# Epoch [9/15] | Batch #518 | Batch Accuracy 61.25%
# Epoch [9/15] | Batch #519 | Batch Accuracy 60.79%
# Epoch [9/15] | Batch #520 | Batch Accuracy 60.74%
# Epoch [9/15] | Batch #521 | Batch Accuracy 60.42%
# Epoch [9/15] | Batch #522 | Batch Accuracy 59.83%
# Epoch [9/15] | Batch #523 | Batch Accuracy 60.18%
# Epoch [9/15] | Batch #524 | Batch Accuracy 60.33%
# Epoch [9/15] | Batch #525 | Batch Accuracy 60.30%
# Epoch [9/15] | Batch #526 | Batch Accuracy 60.20%
# Epoch [9/15] | Batch #527 | Batch Accuracy 60.18%
# Epoch [9/15] | Batch #528 | Batch Accuracy 60.31%
# Epoch [9/15] | Batch #529 | Batch Accuracy 60.82%
# Epoch [9/15] | Batch #530 | Batch Accuracy 60.94%
# Epoch [9/15] | Batch #531 | Batch Accuracy 60.68%
# Epoch [9/15] | Batch #532 | Batch Accuracy 61.15%
# Epoch [9/15] | Batch #533 | Batch Accuracy 61.18%
# Epoch [9/15] | Batch #534 | Batch Accuracy 61.01%
# Epoch [9/15] | Batch #535 | Batch Accuracy 61.04%
# Epoch [9/15] | Batch #536 | Batch Accuracy 61.07%
# Epoch [9/15] | Batch #537 | Batch Accuracy 61.22%
# Epoch [9/15] | Batch #538 | Batch Accuracy 61.12%
# Epoch [9/15] | Batch #539 | Batch Accuracy 61.34%
# Epoch [9/15] | Batch #540 | Batch Accuracy 61.54%
# Epoch [9/15] | Batch #541 | Batch Accuracy 61.38%
# Epoch [9/15] | Batch #542 | Batch Accuracy 61.23%
# Epoch [9/15] | Batch #543 | Batch Accuracy 61.19%
# Epoch [9/15] | Batch #544 | Batch Accuracy 61.33%
# Epoch [9/15] | Batch #545 | Batch Accuracy 61.62%
# Epoch [9/15] | Batch #546 | Batch Accuracy 61.42%
# Epoch [9/15] | Batch #547 | Batch Accuracy 61.12%
# Epoch [9/15] | Batch #548 | Batch Accuracy 61.25%
# Epoch [9/15] | Batch #549 | Batch Accuracy 61.17%
# Epoch [9/15] Train Loss: 0.9977 | Train Acc: 61.17% | Val Acc: 60.10% | Val Loss: 1.07%
# Epoch [10/15] | Batch #550 | Batch Accuracy 68.75%
# Epoch [10/15] | Batch #551 | Batch Accuracy 64.06%
# Epoch [10/15] | Batch #552 | Batch Accuracy 59.38%
# Epoch [10/15] | Batch #553 | Batch Accuracy 63.28%
# Epoch [10/15] | Batch #554 | Batch Accuracy 63.75%
# Epoch [10/15] | Batch #555 | Batch Accuracy 62.50%
# Epoch [10/15] | Batch #556 | Batch Accuracy 62.95%
# Epoch [10/15] | Batch #557 | Batch Accuracy 63.67%
# Epoch [10/15] | Batch #558 | Batch Accuracy 64.93%
# Epoch [10/15] | Batch #559 | Batch Accuracy 64.38%
# Epoch [10/15] | Batch #560 | Batch Accuracy 64.49%
# Epoch [10/15] | Batch #561 | Batch Accuracy 63.80%
# Epoch [10/15] | Batch #562 | Batch Accuracy 63.94%
# Epoch [10/15] | Batch #563 | Batch Accuracy 63.84%
# Epoch [10/15] | Batch #564 | Batch Accuracy 64.17%
# Epoch [10/15] | Batch #565 | Batch Accuracy 64.26%
# Epoch [10/15] | Batch #566 | Batch Accuracy 64.15%
# Epoch [10/15] | Batch #567 | Batch Accuracy 63.89%
# Epoch [10/15] | Batch #568 | Batch Accuracy 63.98%
# Epoch [10/15] | Batch #569 | Batch Accuracy 63.91%
# Epoch [10/15] | Batch #570 | Batch Accuracy 63.84%
# Epoch [10/15] | Batch #571 | Batch Accuracy 63.92%
# Epoch [10/15] | Batch #572 | Batch Accuracy 63.99%
# Epoch [10/15] | Batch #573 | Batch Accuracy 63.93%
# Epoch [10/15] | Batch #574 | Batch Accuracy 64.12%
# Epoch [10/15] | Batch #575 | Batch Accuracy 64.30%
# Epoch [10/15] | Batch #576 | Batch Accuracy 64.58%
# Epoch [10/15] | Batch #577 | Batch Accuracy 64.84%
# Epoch [10/15] | Batch #578 | Batch Accuracy 64.98%
# Epoch [10/15] | Batch #579 | Batch Accuracy 64.48%
# Epoch [10/15] | Batch #580 | Batch Accuracy 64.21%
# Epoch [10/15] | Batch #581 | Batch Accuracy 64.45%
# Epoch [10/15] | Batch #582 | Batch Accuracy 64.11%
# Epoch [10/15] | Batch #583 | Batch Accuracy 64.15%
# Epoch [10/15] | Batch #584 | Batch Accuracy 63.66%
# Epoch [10/15] | Batch #585 | Batch Accuracy 63.63%
# Epoch [10/15] | Batch #586 | Batch Accuracy 63.77%
# Epoch [10/15] | Batch #587 | Batch Accuracy 63.82%
# Epoch [10/15] | Batch #588 | Batch Accuracy 63.78%
# Epoch [10/15] | Batch #589 | Batch Accuracy 63.91%
# Epoch [10/15] | Batch #590 | Batch Accuracy 64.10%
# Epoch [10/15] | Batch #591 | Batch Accuracy 64.21%
# Epoch [10/15] | Batch #592 | Batch Accuracy 64.39%
# Epoch [10/15] | Batch #593 | Batch Accuracy 64.70%
# Epoch [10/15] | Batch #594 | Batch Accuracy 64.65%
# Epoch [10/15] | Batch #595 | Batch Accuracy 64.67%
# Epoch [10/15] | Batch #596 | Batch Accuracy 64.89%
# Epoch [10/15] | Batch #597 | Batch Accuracy 64.84%
# Epoch [10/15] | Batch #598 | Batch Accuracy 64.35%
# Epoch [10/15] | Batch #599 | Batch Accuracy 64.31%
# Epoch [10/15] | Batch #600 | Batch Accuracy 64.34%
# Epoch [10/15] | Batch #601 | Batch Accuracy 64.30%
# Epoch [10/15] | Batch #602 | Batch Accuracy 64.33%
# Epoch [10/15] | Batch #603 | Batch Accuracy 64.24%
# Epoch [10/15] | Batch #604 | Batch Accuracy 64.20%
# Epoch [10/15] | Batch #605 | Batch Accuracy 64.17%
# Epoch [10/15] | Batch #606 | Batch Accuracy 64.14%
# Epoch [10/15] | Batch #607 | Batch Accuracy 63.95%
# Epoch [10/15] | Batch #608 | Batch Accuracy 64.19%
# Epoch [10/15] | Batch #609 | Batch Accuracy 64.06%
# Epoch [10/15] | Batch #610 | Batch Accuracy 64.14%
# Epoch [10/15] Train Loss: 0.9317 | Train Acc: 64.14% | Val Acc: 51.20% | Val Loss: 1.28%
# Epoch [11/15] | Batch #611 | Batch Accuracy 59.38%
# Epoch [11/15] | Batch #612 | Batch Accuracy 65.62%
# Epoch [11/15] | Batch #613 | Batch Accuracy 65.62%
# Epoch [11/15] | Batch #614 | Batch Accuracy 65.62%
# Epoch [11/15] | Batch #615 | Batch Accuracy 66.25%
# Epoch [11/15] | Batch #616 | Batch Accuracy 65.10%
# Epoch [11/15] | Batch #617 | Batch Accuracy 64.73%
# Epoch [11/15] | Batch #618 | Batch Accuracy 65.23%
# Epoch [11/15] | Batch #619 | Batch Accuracy 64.93%
# Epoch [11/15] | Batch #620 | Batch Accuracy 65.31%
# Epoch [11/15] | Batch #621 | Batch Accuracy 63.64%
# Epoch [11/15] | Batch #622 | Batch Accuracy 64.32%
# Epoch [11/15] | Batch #623 | Batch Accuracy 63.94%
# Epoch [11/15] | Batch #624 | Batch Accuracy 63.39%
# Epoch [11/15] | Batch #625 | Batch Accuracy 63.33%
# Epoch [11/15] | Batch #626 | Batch Accuracy 64.06%
# Epoch [11/15] | Batch #627 | Batch Accuracy 63.24%
# Epoch [11/15] | Batch #628 | Batch Accuracy 63.37%
# Epoch [11/15] | Batch #629 | Batch Accuracy 63.32%
# Epoch [11/15] | Batch #630 | Batch Accuracy 63.44%
# Epoch [11/15] | Batch #631 | Batch Accuracy 64.14%
# Epoch [11/15] | Batch #632 | Batch Accuracy 64.06%
# Epoch [11/15] | Batch #633 | Batch Accuracy 63.86%
# Epoch [11/15] | Batch #634 | Batch Accuracy 63.80%
# Epoch [11/15] | Batch #635 | Batch Accuracy 64.38%
# Epoch [11/15] | Batch #636 | Batch Accuracy 64.06%
# Epoch [11/15] | Batch #637 | Batch Accuracy 64.58%
# Epoch [11/15] | Batch #638 | Batch Accuracy 64.62%
# Epoch [11/15] | Batch #639 | Batch Accuracy 65.19%
# Epoch [11/15] | Batch #640 | Batch Accuracy 65.21%
# Epoch [11/15] | Batch #641 | Batch Accuracy 65.02%
# Epoch [11/15] | Batch #642 | Batch Accuracy 64.84%
# Epoch [11/15] | Batch #643 | Batch Accuracy 64.87%
# Epoch [11/15] | Batch #644 | Batch Accuracy 64.98%
# Epoch [11/15] | Batch #645 | Batch Accuracy 65.09%
# Epoch [11/15] | Batch #646 | Batch Accuracy 65.02%
# Epoch [11/15] | Batch #647 | Batch Accuracy 65.20%
# Epoch [11/15] | Batch #648 | Batch Accuracy 65.21%
# Epoch [11/15] | Batch #649 | Batch Accuracy 65.14%
# Epoch [11/15] | Batch #650 | Batch Accuracy 64.92%
# Epoch [11/15] | Batch #651 | Batch Accuracy 64.94%
# Epoch [11/15] | Batch #652 | Batch Accuracy 65.18%
# Epoch [11/15] | Batch #653 | Batch Accuracy 64.90%
# Epoch [11/15] | Batch #654 | Batch Accuracy 64.70%
# Epoch [11/15] | Batch #655 | Batch Accuracy 64.65%
# Epoch [11/15] | Batch #656 | Batch Accuracy 64.81%
# Epoch [11/15] | Batch #657 | Batch Accuracy 64.89%
# Epoch [11/15] | Batch #658 | Batch Accuracy 64.78%
# Epoch [11/15] | Batch #659 | Batch Accuracy 64.80%
# Epoch [11/15] | Batch #660 | Batch Accuracy 64.50%
# Epoch [11/15] | Batch #661 | Batch Accuracy 64.34%
# Epoch [11/15] | Batch #662 | Batch Accuracy 64.36%
# Epoch [11/15] | Batch #663 | Batch Accuracy 64.74%
# Epoch [11/15] | Batch #664 | Batch Accuracy 64.99%
# Epoch [11/15] | Batch #665 | Batch Accuracy 65.06%
# Epoch [11/15] | Batch #666 | Batch Accuracy 65.07%
# Epoch [11/15] | Batch #667 | Batch Accuracy 65.19%
# Epoch [11/15] | Batch #668 | Batch Accuracy 65.30%
# Epoch [11/15] | Batch #669 | Batch Accuracy 65.15%
# Epoch [11/15] | Batch #670 | Batch Accuracy 65.00%
# Epoch [11/15] | Batch #671 | Batch Accuracy 64.96%
# Epoch [11/15] Train Loss: 0.9047 | Train Acc: 64.96% | Val Acc: 57.21% | Val Loss: 1.07%
# Epoch [12/15] | Batch #672 | Batch Accuracy 75.00%
# Epoch [12/15] | Batch #673 | Batch Accuracy 75.00%
# Epoch [12/15] | Batch #674 | Batch Accuracy 75.00%
# Epoch [12/15] | Batch #675 | Batch Accuracy 77.34%
# Epoch [12/15] | Batch #676 | Batch Accuracy 78.12%
# Epoch [12/15] | Batch #677 | Batch Accuracy 75.52%
# Epoch [12/15] | Batch #678 | Batch Accuracy 72.77%
# Epoch [12/15] | Batch #679 | Batch Accuracy 71.88%
# Epoch [12/15] | Batch #680 | Batch Accuracy 69.44%
# Epoch [12/15] | Batch #681 | Batch Accuracy 69.69%
# Epoch [12/15] | Batch #682 | Batch Accuracy 69.03%
# Epoch [12/15] | Batch #683 | Batch Accuracy 69.53%
# Epoch [12/15] | Batch #684 | Batch Accuracy 69.47%
# Epoch [12/15] | Batch #685 | Batch Accuracy 68.53%
# Epoch [12/15] | Batch #686 | Batch Accuracy 69.38%
# Epoch [12/15] | Batch #687 | Batch Accuracy 68.55%
# Epoch [12/15] | Batch #688 | Batch Accuracy 68.20%
# Epoch [12/15] | Batch #689 | Batch Accuracy 67.88%
# Epoch [12/15] | Batch #690 | Batch Accuracy 68.09%
# Epoch [12/15] | Batch #691 | Batch Accuracy 67.50%
# Epoch [12/15] | Batch #692 | Batch Accuracy 67.41%
# Epoch [12/15] | Batch #693 | Batch Accuracy 67.33%
# Epoch [12/15] | Batch #694 | Batch Accuracy 67.12%
# Epoch [12/15] | Batch #695 | Batch Accuracy 67.45%
# Epoch [12/15] | Batch #696 | Batch Accuracy 68.12%
# Epoch [12/15] | Batch #697 | Batch Accuracy 67.91%
# Epoch [12/15] | Batch #698 | Batch Accuracy 67.36%
# Epoch [12/15] | Batch #699 | Batch Accuracy 67.52%
# Epoch [12/15] | Batch #700 | Batch Accuracy 67.35%
# Epoch [12/15] | Batch #701 | Batch Accuracy 67.19%
# Epoch [12/15] | Batch #702 | Batch Accuracy 67.24%
# Epoch [12/15] | Batch #703 | Batch Accuracy 67.38%
# Epoch [12/15] | Batch #704 | Batch Accuracy 67.33%
# Epoch [12/15] | Batch #705 | Batch Accuracy 67.56%
# Epoch [12/15] | Batch #706 | Batch Accuracy 67.41%
# Epoch [12/15] | Batch #707 | Batch Accuracy 67.80%
# Epoch [12/15] | Batch #708 | Batch Accuracy 67.65%
# Epoch [12/15] | Batch #709 | Batch Accuracy 67.93%
# Epoch [12/15] | Batch #710 | Batch Accuracy 67.79%
# Epoch [12/15] | Batch #711 | Batch Accuracy 68.20%
# Epoch [12/15] | Batch #712 | Batch Accuracy 67.76%
# Epoch [12/15] | Batch #713 | Batch Accuracy 67.78%
# Epoch [12/15] | Batch #714 | Batch Accuracy 67.66%
# Epoch [12/15] | Batch #715 | Batch Accuracy 67.76%
# Epoch [12/15] | Batch #716 | Batch Accuracy 67.78%
# Epoch [12/15] | Batch #717 | Batch Accuracy 67.60%
# Epoch [12/15] | Batch #718 | Batch Accuracy 67.49%
# Epoch [12/15] | Batch #719 | Batch Accuracy 67.51%
# Epoch [12/15] | Batch #720 | Batch Accuracy 67.47%
# Epoch [12/15] | Batch #721 | Batch Accuracy 67.31%
# Epoch [12/15] | Batch #722 | Batch Accuracy 67.34%
# Epoch [12/15] | Batch #723 | Batch Accuracy 67.61%
# Epoch [12/15] | Batch #724 | Batch Accuracy 67.63%
# Epoch [12/15] | Batch #725 | Batch Accuracy 67.59%
# Epoch [12/15] | Batch #726 | Batch Accuracy 67.61%
# Epoch [12/15] | Batch #727 | Batch Accuracy 67.58%
# Epoch [12/15] | Batch #728 | Batch Accuracy 67.43%
# Epoch [12/15] | Batch #729 | Batch Accuracy 67.56%
# Epoch [12/15] | Batch #730 | Batch Accuracy 67.37%
# Epoch [12/15] | Batch #731 | Batch Accuracy 67.50%
# Epoch [12/15] | Batch #732 | Batch Accuracy 67.47%
# Epoch [12/15] Train Loss: 0.8620 | Train Acc: 67.47% | Val Acc: 52.40% | Val Loss: 1.32%
# Epoch [13/15] | Batch #733 | Batch Accuracy 71.88%
# Epoch [13/15] | Batch #734 | Batch Accuracy 67.19%
# Epoch [13/15] | Batch #735 | Batch Accuracy 68.75%
# Epoch [13/15] | Batch #736 | Batch Accuracy 67.19%
# Epoch [13/15] | Batch #737 | Batch Accuracy 68.75%
# Epoch [13/15] | Batch #738 | Batch Accuracy 69.79%
# Epoch [13/15] | Batch #739 | Batch Accuracy 68.75%
# Epoch [13/15] | Batch #740 | Batch Accuracy 69.14%
# Epoch [13/15] | Batch #741 | Batch Accuracy 67.71%
# Epoch [13/15] | Batch #742 | Batch Accuracy 68.12%
# Epoch [13/15] | Batch #743 | Batch Accuracy 67.90%
# Epoch [13/15] | Batch #744 | Batch Accuracy 67.97%
# Epoch [13/15] | Batch #745 | Batch Accuracy 67.55%
# Epoch [13/15] | Batch #746 | Batch Accuracy 66.96%
# Epoch [13/15] | Batch #747 | Batch Accuracy 67.08%
# Epoch [13/15] | Batch #748 | Batch Accuracy 66.60%
# Epoch [13/15] | Batch #749 | Batch Accuracy 66.73%
# Epoch [13/15] | Batch #750 | Batch Accuracy 66.49%
# Epoch [13/15] | Batch #751 | Batch Accuracy 66.12%
# Epoch [13/15] | Batch #752 | Batch Accuracy 66.25%
# Epoch [13/15] | Batch #753 | Batch Accuracy 66.22%
# Epoch [13/15] | Batch #754 | Batch Accuracy 66.19%
# Epoch [13/15] | Batch #755 | Batch Accuracy 65.35%
# Epoch [13/15] | Batch #756 | Batch Accuracy 65.23%
# Epoch [13/15] | Batch #757 | Batch Accuracy 65.38%
# Epoch [13/15] | Batch #758 | Batch Accuracy 65.62%
# Epoch [13/15] | Batch #759 | Batch Accuracy 65.86%
# Epoch [13/15] | Batch #760 | Batch Accuracy 65.85%
# Epoch [13/15] | Batch #761 | Batch Accuracy 66.16%
# Epoch [13/15] | Batch #762 | Batch Accuracy 65.83%
# Epoch [13/15] | Batch #763 | Batch Accuracy 65.83%
# Epoch [13/15] | Batch #764 | Batch Accuracy 66.02%
# Epoch [13/15] | Batch #765 | Batch Accuracy 66.48%
# Epoch [13/15] | Batch #766 | Batch Accuracy 66.73%
# Epoch [13/15] | Batch #767 | Batch Accuracy 66.88%
# Epoch [13/15] | Batch #768 | Batch Accuracy 67.10%
# Epoch [13/15] | Batch #769 | Batch Accuracy 67.31%
# Epoch [13/15] | Batch #770 | Batch Accuracy 67.52%
# Epoch [13/15] | Batch #771 | Batch Accuracy 67.79%
# Epoch [13/15] | Batch #772 | Batch Accuracy 67.89%
# Epoch [13/15] | Batch #773 | Batch Accuracy 67.99%
# Epoch [13/15] | Batch #774 | Batch Accuracy 67.86%
# Epoch [13/15] | Batch #775 | Batch Accuracy 67.73%
# Epoch [13/15] | Batch #776 | Batch Accuracy 67.83%
# Epoch [13/15] | Batch #777 | Batch Accuracy 67.57%
# Epoch [13/15] | Batch #778 | Batch Accuracy 67.46%
# Epoch [13/15] | Batch #779 | Batch Accuracy 67.69%
# Epoch [13/15] | Batch #780 | Batch Accuracy 67.64%
# Epoch [13/15] | Batch #781 | Batch Accuracy 67.54%
# Epoch [13/15] | Batch #782 | Batch Accuracy 67.44%
# Epoch [13/15] | Batch #783 | Batch Accuracy 67.65%
# Epoch [13/15] | Batch #784 | Batch Accuracy 67.91%
# Epoch [13/15] | Batch #785 | Batch Accuracy 68.10%
# Epoch [13/15] | Batch #786 | Batch Accuracy 68.34%
# Epoch [13/15] | Batch #787 | Batch Accuracy 68.47%
# Epoch [13/15] | Batch #788 | Batch Accuracy 68.58%
# Epoch [13/15] | Batch #789 | Batch Accuracy 68.75%
# Epoch [13/15] | Batch #790 | Batch Accuracy 68.91%
# Epoch [13/15] | Batch #791 | Batch Accuracy 69.12%
# Epoch [13/15] | Batch #792 | Batch Accuracy 69.11%
# Epoch [13/15] | Batch #793 | Batch Accuracy 68.95%
# Epoch [13/15] Train Loss: 0.8273 | Train Acc: 68.95% | Val Acc: 50.00% | Val Loss: 1.18%
# Epoch [14/15] | Batch #794 | Batch Accuracy 62.50%
# Epoch [14/15] | Batch #795 | Batch Accuracy 68.75%
# Epoch [14/15] | Batch #796 | Batch Accuracy 65.62%
# Epoch [14/15] | Batch #797 | Batch Accuracy 67.97%
# Epoch [14/15] | Batch #798 | Batch Accuracy 68.12%
# Epoch [14/15] | Batch #799 | Batch Accuracy 69.27%
# Epoch [14/15] | Batch #800 | Batch Accuracy 71.88%
# Epoch [14/15] | Batch #801 | Batch Accuracy 71.48%
# Epoch [14/15] | Batch #802 | Batch Accuracy 71.53%
# Epoch [14/15] | Batch #803 | Batch Accuracy 71.56%
# Epoch [14/15] | Batch #804 | Batch Accuracy 70.17%
# Epoch [14/15] | Batch #805 | Batch Accuracy 69.01%
# Epoch [14/15] | Batch #806 | Batch Accuracy 69.23%
# Epoch [14/15] | Batch #807 | Batch Accuracy 69.42%
# Epoch [14/15] | Batch #808 | Batch Accuracy 69.38%
# Epoch [14/15] | Batch #809 | Batch Accuracy 69.73%
# Epoch [14/15] | Batch #810 | Batch Accuracy 69.49%
# Epoch [14/15] | Batch #811 | Batch Accuracy 69.79%
# Epoch [14/15] | Batch #812 | Batch Accuracy 69.74%
# Epoch [14/15] | Batch #813 | Batch Accuracy 69.06%
# Epoch [14/15] | Batch #814 | Batch Accuracy 68.90%
# Epoch [14/15] | Batch #815 | Batch Accuracy 68.32%
# Epoch [14/15] | Batch #816 | Batch Accuracy 68.61%
# Epoch [14/15] | Batch #817 | Batch Accuracy 69.01%
# Epoch [14/15] | Batch #818 | Batch Accuracy 68.88%
# Epoch [14/15] | Batch #819 | Batch Accuracy 69.71%
# Epoch [14/15] | Batch #820 | Batch Accuracy 70.02%
# Epoch [14/15] | Batch #821 | Batch Accuracy 70.09%
# Epoch [14/15] | Batch #822 | Batch Accuracy 69.94%
# Epoch [14/15] | Batch #823 | Batch Accuracy 70.10%
# Epoch [14/15] | Batch #824 | Batch Accuracy 70.06%
# Epoch [14/15] | Batch #825 | Batch Accuracy 70.02%
# Epoch [14/15] | Batch #826 | Batch Accuracy 69.79%
# Epoch [14/15] | Batch #827 | Batch Accuracy 70.13%
# Epoch [14/15] | Batch #828 | Batch Accuracy 70.18%
# Epoch [14/15] | Batch #829 | Batch Accuracy 69.88%
# Epoch [14/15] | Batch #830 | Batch Accuracy 70.35%
# Epoch [14/15] | Batch #831 | Batch Accuracy 69.98%
# Epoch [14/15] | Batch #832 | Batch Accuracy 70.03%
# Epoch [14/15] | Batch #833 | Batch Accuracy 70.00%
# Epoch [14/15] | Batch #834 | Batch Accuracy 70.12%
# Epoch [14/15] | Batch #835 | Batch Accuracy 69.94%
# Epoch [14/15] | Batch #836 | Batch Accuracy 69.99%
# Epoch [14/15] | Batch #837 | Batch Accuracy 70.31%
# Epoch [14/15] | Batch #838 | Batch Accuracy 70.35%
# Epoch [14/15] | Batch #839 | Batch Accuracy 70.38%
# Epoch [14/15] | Batch #840 | Batch Accuracy 70.28%
# Epoch [14/15] | Batch #841 | Batch Accuracy 70.25%
# Epoch [14/15] | Batch #842 | Batch Accuracy 70.34%
# Epoch [14/15] | Batch #843 | Batch Accuracy 70.44%
# Epoch [14/15] | Batch #844 | Batch Accuracy 70.53%
# Epoch [14/15] | Batch #845 | Batch Accuracy 70.25%
# Epoch [14/15] | Batch #846 | Batch Accuracy 69.93%
# Epoch [14/15] | Batch #847 | Batch Accuracy 69.85%
# Epoch [14/15] | Batch #848 | Batch Accuracy 70.00%
# Epoch [14/15] | Batch #849 | Batch Accuracy 69.70%
# Epoch [14/15] | Batch #850 | Batch Accuracy 69.57%
# Epoch [14/15] | Batch #851 | Batch Accuracy 69.56%
# Epoch [14/15] | Batch #852 | Batch Accuracy 69.28%
# Epoch [14/15] | Batch #853 | Batch Accuracy 69.48%
# Epoch [14/15] | Batch #854 | Batch Accuracy 69.47%
# Epoch [14/15] Train Loss: 0.8043 | Train Acc: 69.47% | Val Acc: 65.38% | Val Loss: 0.93%
# Epoch [15/15] | Batch #855 | Batch Accuracy 81.25%
# Epoch [15/15] | Batch #856 | Batch Accuracy 78.12%
# Epoch [15/15] | Batch #857 | Batch Accuracy 71.88%
# Epoch [15/15] | Batch #858 | Batch Accuracy 72.66%
# Epoch [15/15] | Batch #859 | Batch Accuracy 70.62%
# Epoch [15/15] | Batch #860 | Batch Accuracy 73.44%
# Epoch [15/15] | Batch #861 | Batch Accuracy 73.21%
# Epoch [15/15] | Batch #862 | Batch Accuracy 73.05%
# Epoch [15/15] | Batch #863 | Batch Accuracy 73.26%
# Epoch [15/15] | Batch #864 | Batch Accuracy 74.06%
# Epoch [15/15] | Batch #865 | Batch Accuracy 72.44%
# Epoch [15/15] | Batch #866 | Batch Accuracy 72.14%
# Epoch [15/15] | Batch #867 | Batch Accuracy 71.39%
# Epoch [15/15] | Batch #868 | Batch Accuracy 71.88%
# Epoch [15/15] | Batch #869 | Batch Accuracy 72.71%
# Epoch [15/15] | Batch #870 | Batch Accuracy 72.46%
# Epoch [15/15] | Batch #871 | Batch Accuracy 71.32%
# Epoch [15/15] | Batch #872 | Batch Accuracy 71.01%
# Epoch [15/15] | Batch #873 | Batch Accuracy 70.72%
# Epoch [15/15] | Batch #874 | Batch Accuracy 70.62%
# Epoch [15/15] | Batch #875 | Batch Accuracy 70.54%
# Epoch [15/15] | Batch #876 | Batch Accuracy 70.60%
# Epoch [15/15] | Batch #877 | Batch Accuracy 70.52%
# Epoch [15/15] | Batch #878 | Batch Accuracy 70.83%
# Epoch [15/15] | Batch #879 | Batch Accuracy 70.50%
# Epoch [15/15] | Batch #880 | Batch Accuracy 70.91%
# Epoch [15/15] | Batch #881 | Batch Accuracy 70.49%
# Epoch [15/15] | Batch #882 | Batch Accuracy 70.87%
# Epoch [15/15] | Batch #883 | Batch Accuracy 70.58%
# Epoch [15/15] | Batch #884 | Batch Accuracy 70.83%
# Epoch [15/15] | Batch #885 | Batch Accuracy 71.17%
# Epoch [15/15] | Batch #886 | Batch Accuracy 70.90%
# Epoch [15/15] | Batch #887 | Batch Accuracy 70.93%
# Epoch [15/15] | Batch #888 | Batch Accuracy 70.68%
# Epoch [15/15] | Batch #889 | Batch Accuracy 70.71%
# Epoch [15/15] | Batch #890 | Batch Accuracy 70.57%
# Epoch [15/15] | Batch #891 | Batch Accuracy 70.95%
# Epoch [15/15] | Batch #892 | Batch Accuracy 70.81%
# Epoch [15/15] | Batch #893 | Batch Accuracy 70.51%
# Epoch [15/15] | Batch #894 | Batch Accuracy 70.70%
# Epoch [15/15] | Batch #895 | Batch Accuracy 70.58%
# Epoch [15/15] | Batch #896 | Batch Accuracy 70.83%
# Epoch [15/15] | Batch #897 | Batch Accuracy 70.57%
# Epoch [15/15] | Batch #898 | Batch Accuracy 70.60%
# Epoch [15/15] | Batch #899 | Batch Accuracy 70.76%
# Epoch [15/15] | Batch #900 | Batch Accuracy 70.58%
# Epoch [15/15] | Batch #901 | Batch Accuracy 70.61%
# Epoch [15/15] | Batch #902 | Batch Accuracy 70.70%
# Epoch [15/15] | Batch #903 | Batch Accuracy 70.73%
# Epoch [15/15] | Batch #904 | Batch Accuracy 70.69%
# Epoch [15/15] | Batch #905 | Batch Accuracy 70.53%
# Epoch [15/15] | Batch #906 | Batch Accuracy 70.61%
# Epoch [15/15] | Batch #907 | Batch Accuracy 70.52%
# Epoch [15/15] | Batch #908 | Batch Accuracy 70.43%
# Epoch [15/15] | Batch #909 | Batch Accuracy 70.34%
# Epoch [15/15] | Batch #910 | Batch Accuracy 70.48%
# Epoch [15/15] | Batch #911 | Batch Accuracy 70.50%
# Epoch [15/15] | Batch #912 | Batch Accuracy 70.42%
# Epoch [15/15] | Batch #913 | Batch Accuracy 70.55%
# Epoch [15/15] | Batch #914 | Batch Accuracy 70.83%
# Epoch [15/15] | Batch #915 | Batch Accuracy 70.59%
# Epoch [15/15] Train Loss: 0.8078 | Train Acc: 70.59% | Val Acc: 61.30% | Val Loss: 1.00%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▇▆▅▄▃▃▂▃▂▂▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▃▂▄▄▅▄▆▇▅▆▅▅█▇</td></tr><tr><td>validation_loss</td><td>█▆▇▅▅▄▅▃▂▅▃▅▄▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.80784</td></tr><tr><td>validation_accuracy</td><td>61.29808</td></tr><tr><td>validation_loss</td><td>0.99586</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod3</strong> at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/9tsowjbd' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/9tsowjbd</a><br> View project at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_155832-9tsowjbd/logs</code>

# %%
plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_741931/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# *This model, with a validation accuracy of 61.23%, performed worse than Models 1 and 2, but better than the original model. I may have added too much noise to the images with the excessive image transformations, which could have made it difficult for the model to pick up on features useful for classification. This is supported by the fact that there were more drastic jumps in validation accuracy between epochs, meaning the model was having trouble converging on optimal weights/biases.*

# %% [markdown]
# #### Model 4 (Assignment Part 3)

# %%
batchsize = 32
learning_rate = 5e-3
epochs = 11

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

## Model: Changing the model to a different pre-made model architecture, with pre-trained weights
#########
import torchvision.models as models
from torchvision.models import resnet18, ResNet18_Weights

num_classes = 6 # same as mod1 and mod2
weights = ResNet18_Weights.DEFAULT

# Pre-trained torchvision ResNet18, ResNet18_Weights.DEFAULT (aka ResNet18_Weights.IMAGENET1K_V1)
model = resnet18(weights=weights)

# Replace classification head
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, num_classes)

## Getting our model and transferring it to the GPU
model = model.to(device)

# Make sure transforms match the pre-trained weights, ResNet18_Weights.DEFAULT (aka ResNet18_Weights.IMAGENET1K_V1)
preprocess = weights.transforms()
train_set.transform = preprocess
val_set.transform = preprocess
test_set.transform = preprocess

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=1e-4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/vini/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 298MB/s]

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Vini-HappyWhale-SpeciesDataset-hyperparameters_mod4", ##update this with your name
    config={"learning rate": learning_rate, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": epochs, "batch_size": batchsize}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/vini/.netrc.
# wandb: Currently logged in as: vini_k (vini_k-university-of-oregon) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/projects/bgmp/vini/bioinfo/Bi625/HappyWhaleClassifier/wandb/run-20260305_160459-6rsfi9d6</code>
# Syncing run <strong><a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/6rsfi9d6' target="_blank">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod4</a></strong> to <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/6rsfi9d6' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/6rsfi9d6</a>
# Epoch [1/11] | Batch #1 | Batch Accuracy 18.75%
# Epoch [1/11] | Batch #2 | Batch Accuracy 15.62%
# Epoch [1/11] | Batch #3 | Batch Accuracy 18.75%
# Epoch [1/11] | Batch #4 | Batch Accuracy 17.19%
# Epoch [1/11] | Batch #5 | Batch Accuracy 21.88%
# Epoch [1/11] | Batch #6 | Batch Accuracy 21.35%
# Epoch [1/11] | Batch #7 | Batch Accuracy 25.89%
# Epoch [1/11] | Batch #8 | Batch Accuracy 29.69%
# Epoch [1/11] | Batch #9 | Batch Accuracy 29.86%
# Epoch [1/11] | Batch #10 | Batch Accuracy 31.25%
# Epoch [1/11] | Batch #11 | Batch Accuracy 33.24%
# Epoch [1/11] | Batch #12 | Batch Accuracy 36.46%
# Epoch [1/11] | Batch #13 | Batch Accuracy 37.74%
# Epoch [1/11] | Batch #14 | Batch Accuracy 38.17%
# Epoch [1/11] | Batch #15 | Batch Accuracy 40.21%
# Epoch [1/11] | Batch #16 | Batch Accuracy 41.80%
# Epoch [1/11] | Batch #17 | Batch Accuracy 43.93%
# Epoch [1/11] | Batch #18 | Batch Accuracy 45.49%
# Epoch [1/11] | Batch #19 | Batch Accuracy 46.38%
# Epoch [1/11] | Batch #20 | Batch Accuracy 48.28%
# Epoch [1/11] | Batch #21 | Batch Accuracy 49.70%
# Epoch [1/11] | Batch #22 | Batch Accuracy 50.99%
# Epoch [1/11] | Batch #23 | Batch Accuracy 51.63%
# Epoch [1/11] | Batch #24 | Batch Accuracy 53.12%
# Epoch [1/11] | Batch #25 | Batch Accuracy 54.25%
# Epoch [1/11] | Batch #26 | Batch Accuracy 55.29%
# Epoch [1/11] | Batch #27 | Batch Accuracy 56.25%
# Epoch [1/11] | Batch #28 | Batch Accuracy 57.25%
# Epoch [1/11] | Batch #29 | Batch Accuracy 58.30%
# Epoch [1/11] | Batch #30 | Batch Accuracy 59.17%
# Epoch [1/11] | Batch #31 | Batch Accuracy 59.98%
# Epoch [1/11] | Batch #32 | Batch Accuracy 60.64%
# Epoch [1/11] | Batch #33 | Batch Accuracy 60.98%
# Epoch [1/11] | Batch #34 | Batch Accuracy 61.49%
# Epoch [1/11] | Batch #35 | Batch Accuracy 62.50%
# Epoch [1/11] | Batch #36 | Batch Accuracy 63.11%
# Epoch [1/11] | Batch #37 | Batch Accuracy 64.10%
# Epoch [1/11] | Batch #38 | Batch Accuracy 64.88%
# Epoch [1/11] | Batch #39 | Batch Accuracy 65.38%
# Epoch [1/11] | Batch #40 | Batch Accuracy 65.78%
# Epoch [1/11] | Batch #41 | Batch Accuracy 66.31%
# Epoch [1/11] | Batch #42 | Batch Accuracy 66.67%
# Epoch [1/11] | Batch #43 | Batch Accuracy 66.79%
# Epoch [1/11] | Batch #44 | Batch Accuracy 67.19%
# Epoch [1/11] | Batch #45 | Batch Accuracy 67.22%
# Epoch [1/11] | Batch #46 | Batch Accuracy 67.73%
# Epoch [1/11] | Batch #47 | Batch Accuracy 68.22%
# Epoch [1/11] | Batch #48 | Batch Accuracy 68.82%
# Epoch [1/11] | Batch #49 | Batch Accuracy 69.39%
# Epoch [1/11] | Batch #50 | Batch Accuracy 69.75%
# Epoch [1/11] | Batch #51 | Batch Accuracy 70.10%
# Epoch [1/11] | Batch #52 | Batch Accuracy 70.43%
# Epoch [1/11] | Batch #53 | Batch Accuracy 70.87%
# Epoch [1/11] | Batch #54 | Batch Accuracy 71.18%
# Epoch [1/11] | Batch #55 | Batch Accuracy 71.59%
# Epoch [1/11] | Batch #56 | Batch Accuracy 71.93%
# Epoch [1/11] | Batch #57 | Batch Accuracy 72.37%
# Epoch [1/11] | Batch #58 | Batch Accuracy 72.63%
# Epoch [1/11] | Batch #59 | Batch Accuracy 72.99%
# Epoch [1/11] | Batch #60 | Batch Accuracy 73.23%
# Epoch [1/11] | Batch #61 | Batch Accuracy 73.41%
# Epoch [1/11] Train Loss: 0.7097 | Train Acc: 73.41% | Val Acc: 87.50% | Val Loss: 0.43%
# Epoch [2/11] | Batch #62 | Batch Accuracy 78.12%
# Epoch [2/11] | Batch #63 | Batch Accuracy 89.06%
# Epoch [2/11] | Batch #64 | Batch Accuracy 91.67%
# Epoch [2/11] | Batch #65 | Batch Accuracy 89.06%
# Epoch [2/11] | Batch #66 | Batch Accuracy 88.12%
# Epoch [2/11] | Batch #67 | Batch Accuracy 89.58%
# Epoch [2/11] | Batch #68 | Batch Accuracy 91.07%
# Epoch [2/11] | Batch #69 | Batch Accuracy 91.41%
# Epoch [2/11] | Batch #70 | Batch Accuracy 90.97%
# Epoch [2/11] | Batch #71 | Batch Accuracy 90.31%
# Epoch [2/11] | Batch #72 | Batch Accuracy 90.62%
# Epoch [2/11] | Batch #73 | Batch Accuracy 90.36%
# Epoch [2/11] | Batch #74 | Batch Accuracy 90.87%
# Epoch [2/11] | Batch #75 | Batch Accuracy 91.07%
# Epoch [2/11] | Batch #76 | Batch Accuracy 91.04%
# Epoch [2/11] | Batch #77 | Batch Accuracy 91.21%
# Epoch [2/11] | Batch #78 | Batch Accuracy 91.36%
# Epoch [2/11] | Batch #79 | Batch Accuracy 91.32%
# Epoch [2/11] | Batch #80 | Batch Accuracy 91.45%
# Epoch [2/11] | Batch #81 | Batch Accuracy 91.09%
# Epoch [2/11] | Batch #82 | Batch Accuracy 91.37%
# Epoch [2/11] | Batch #83 | Batch Accuracy 91.76%
# Epoch [2/11] | Batch #84 | Batch Accuracy 91.98%
# Epoch [2/11] | Batch #85 | Batch Accuracy 92.06%
# Epoch [2/11] | Batch #86 | Batch Accuracy 92.12%
# Epoch [2/11] | Batch #87 | Batch Accuracy 92.19%
# Epoch [2/11] | Batch #88 | Batch Accuracy 92.13%
# Epoch [2/11] | Batch #89 | Batch Accuracy 92.41%
# Epoch [2/11] | Batch #90 | Batch Accuracy 92.56%
# Epoch [2/11] | Batch #91 | Batch Accuracy 92.60%
# Epoch [2/11] | Batch #92 | Batch Accuracy 92.74%
# Epoch [2/11] | Batch #93 | Batch Accuracy 92.77%
# Epoch [2/11] | Batch #94 | Batch Accuracy 92.71%
# Epoch [2/11] | Batch #95 | Batch Accuracy 92.56%
# Epoch [2/11] | Batch #96 | Batch Accuracy 92.41%
# Epoch [2/11] | Batch #97 | Batch Accuracy 92.36%
# Epoch [2/11] | Batch #98 | Batch Accuracy 92.40%
# Epoch [2/11] | Batch #99 | Batch Accuracy 92.27%
# Epoch [2/11] | Batch #100 | Batch Accuracy 92.31%
# Epoch [2/11] | Batch #101 | Batch Accuracy 92.50%
# Epoch [2/11] | Batch #102 | Batch Accuracy 92.45%
# Epoch [2/11] | Batch #103 | Batch Accuracy 92.49%
# Epoch [2/11] | Batch #104 | Batch Accuracy 92.37%
# Epoch [2/11] | Batch #105 | Batch Accuracy 92.40%
# Epoch [2/11] | Batch #106 | Batch Accuracy 92.50%
# Epoch [2/11] | Batch #107 | Batch Accuracy 92.53%
# Epoch [2/11] | Batch #108 | Batch Accuracy 92.29%
# Epoch [2/11] | Batch #109 | Batch Accuracy 92.32%
# Epoch [2/11] | Batch #110 | Batch Accuracy 92.41%
# Epoch [2/11] | Batch #111 | Batch Accuracy 92.50%
# Epoch [2/11] | Batch #112 | Batch Accuracy 92.65%
# Epoch [2/11] | Batch #113 | Batch Accuracy 92.79%
# Epoch [2/11] | Batch #114 | Batch Accuracy 92.75%
# Epoch [2/11] | Batch #115 | Batch Accuracy 92.65%
# Epoch [2/11] | Batch #116 | Batch Accuracy 92.78%
# Epoch [2/11] | Batch #117 | Batch Accuracy 92.86%
# Epoch [2/11] | Batch #118 | Batch Accuracy 92.93%
# Epoch [2/11] | Batch #119 | Batch Accuracy 93.00%
# Epoch [2/11] | Batch #120 | Batch Accuracy 92.85%
# Epoch [2/11] | Batch #121 | Batch Accuracy 92.81%
# Epoch [2/11] | Batch #122 | Batch Accuracy 92.73%
# Epoch [2/11] Train Loss: 0.1987 | Train Acc: 92.73% | Val Acc: 88.94% | Val Loss: 0.37%
# Epoch [3/11] | Batch #123 | Batch Accuracy 87.50%
# Epoch [3/11] | Batch #124 | Batch Accuracy 90.62%
# Epoch [3/11] | Batch #125 | Batch Accuracy 92.71%
# Epoch [3/11] | Batch #126 | Batch Accuracy 92.19%
# Epoch [3/11] | Batch #127 | Batch Accuracy 93.12%
# Epoch [3/11] | Batch #128 | Batch Accuracy 93.23%
# Epoch [3/11] | Batch #129 | Batch Accuracy 92.86%
# Epoch [3/11] | Batch #130 | Batch Accuracy 92.97%
# Epoch [3/11] | Batch #131 | Batch Accuracy 93.06%
# Epoch [3/11] | Batch #132 | Batch Accuracy 93.44%
# Epoch [3/11] | Batch #133 | Batch Accuracy 94.03%
# Epoch [3/11] | Batch #134 | Batch Accuracy 94.53%
# Epoch [3/11] | Batch #135 | Batch Accuracy 94.47%
# Epoch [3/11] | Batch #136 | Batch Accuracy 94.64%
# Epoch [3/11] | Batch #137 | Batch Accuracy 94.17%
# Epoch [3/11] | Batch #138 | Batch Accuracy 94.34%
# Epoch [3/11] | Batch #139 | Batch Accuracy 94.12%
# Epoch [3/11] | Batch #140 | Batch Accuracy 94.10%
# Epoch [3/11] | Batch #141 | Batch Accuracy 93.75%
# Epoch [3/11] | Batch #142 | Batch Accuracy 94.06%
# Epoch [3/11] | Batch #143 | Batch Accuracy 94.35%
# Epoch [3/11] | Batch #144 | Batch Accuracy 94.60%
# Epoch [3/11] | Batch #145 | Batch Accuracy 94.70%
# Epoch [3/11] | Batch #146 | Batch Accuracy 94.66%
# Epoch [3/11] | Batch #147 | Batch Accuracy 94.88%
# Epoch [3/11] | Batch #148 | Batch Accuracy 94.95%
# Epoch [3/11] | Batch #149 | Batch Accuracy 94.68%
# Epoch [3/11] | Batch #150 | Batch Accuracy 94.75%
# Epoch [3/11] | Batch #151 | Batch Accuracy 94.83%
# Epoch [3/11] | Batch #152 | Batch Accuracy 94.79%
# Epoch [3/11] | Batch #153 | Batch Accuracy 94.86%
# Epoch [3/11] | Batch #154 | Batch Accuracy 95.02%
# Epoch [3/11] | Batch #155 | Batch Accuracy 95.17%
# Epoch [3/11] | Batch #156 | Batch Accuracy 95.31%
# Epoch [3/11] | Batch #157 | Batch Accuracy 95.18%
# Epoch [3/11] | Batch #158 | Batch Accuracy 95.31%
# Epoch [3/11] | Batch #159 | Batch Accuracy 95.44%
# Epoch [3/11] | Batch #160 | Batch Accuracy 95.23%
# Epoch [3/11] | Batch #161 | Batch Accuracy 95.19%
# Epoch [3/11] | Batch #162 | Batch Accuracy 95.23%
# Epoch [3/11] | Batch #163 | Batch Accuracy 95.27%
# Epoch [3/11] | Batch #164 | Batch Accuracy 95.31%
# Epoch [3/11] | Batch #165 | Batch Accuracy 95.42%
# Epoch [3/11] | Batch #166 | Batch Accuracy 95.53%
# Epoch [3/11] | Batch #167 | Batch Accuracy 95.56%
# Epoch [3/11] | Batch #168 | Batch Accuracy 95.52%
# Epoch [3/11] | Batch #169 | Batch Accuracy 95.55%
# Epoch [3/11] | Batch #170 | Batch Accuracy 95.57%
# Epoch [3/11] | Batch #171 | Batch Accuracy 95.60%
# Epoch [3/11] | Batch #172 | Batch Accuracy 95.62%
# Epoch [3/11] | Batch #173 | Batch Accuracy 95.59%
# Epoch [3/11] | Batch #174 | Batch Accuracy 95.67%
# Epoch [3/11] | Batch #175 | Batch Accuracy 95.75%
# Epoch [3/11] | Batch #176 | Batch Accuracy 95.66%
# Epoch [3/11] | Batch #177 | Batch Accuracy 95.68%
# Epoch [3/11] | Batch #178 | Batch Accuracy 95.76%
# Epoch [3/11] | Batch #179 | Batch Accuracy 95.72%
# Epoch [3/11] | Batch #180 | Batch Accuracy 95.80%
# Epoch [3/11] | Batch #181 | Batch Accuracy 95.82%
# Epoch [3/11] | Batch #182 | Batch Accuracy 95.83%
# Epoch [3/11] | Batch #183 | Batch Accuracy 95.80%
# Epoch [3/11] Train Loss: 0.1201 | Train Acc: 95.80% | Val Acc: 91.83% | Val Loss: 0.26%
# Epoch [4/11] | Batch #184 | Batch Accuracy 100.00%
# Epoch [4/11] | Batch #185 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #186 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #187 | Batch Accuracy 96.09%
# Epoch [4/11] | Batch #188 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #189 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #190 | Batch Accuracy 97.32%
# Epoch [4/11] | Batch #191 | Batch Accuracy 97.27%
# Epoch [4/11] | Batch #192 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #193 | Batch Accuracy 97.19%
# Epoch [4/11] | Batch #194 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #195 | Batch Accuracy 97.14%
# Epoch [4/11] | Batch #196 | Batch Accuracy 96.63%
# Epoch [4/11] | Batch #197 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #198 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #199 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #200 | Batch Accuracy 97.06%
# Epoch [4/11] | Batch #201 | Batch Accuracy 97.05%
# Epoch [4/11] | Batch #202 | Batch Accuracy 97.04%
# Epoch [4/11] | Batch #203 | Batch Accuracy 97.03%
# Epoch [4/11] | Batch #204 | Batch Accuracy 96.88%
# Epoch [4/11] | Batch #205 | Batch Accuracy 97.02%
# Epoch [4/11] | Batch #206 | Batch Accuracy 97.15%
# Epoch [4/11] | Batch #207 | Batch Accuracy 97.27%
# Epoch [4/11] | Batch #208 | Batch Accuracy 97.12%
# Epoch [4/11] | Batch #209 | Batch Accuracy 97.12%
# Epoch [4/11] | Batch #210 | Batch Accuracy 97.22%
# Epoch [4/11] | Batch #211 | Batch Accuracy 97.32%
# Epoch [4/11] | Batch #212 | Batch Accuracy 97.31%
# Epoch [4/11] | Batch #213 | Batch Accuracy 97.40%
# Epoch [4/11] | Batch #214 | Batch Accuracy 97.48%
# Epoch [4/11] | Batch #215 | Batch Accuracy 97.56%
# Epoch [4/11] | Batch #216 | Batch Accuracy 97.54%
# Epoch [4/11] | Batch #217 | Batch Accuracy 97.43%
# Epoch [4/11] | Batch #218 | Batch Accuracy 97.50%
# Epoch [4/11] | Batch #219 | Batch Accuracy 97.57%
# Epoch [4/11] | Batch #220 | Batch Accuracy 97.55%
# Epoch [4/11] | Batch #221 | Batch Accuracy 97.53%
# Epoch [4/11] | Batch #222 | Batch Accuracy 97.52%
# Epoch [4/11] | Batch #223 | Batch Accuracy 97.42%
# Epoch [4/11] | Batch #224 | Batch Accuracy 97.33%
# Epoch [4/11] | Batch #225 | Batch Accuracy 97.32%
# Epoch [4/11] | Batch #226 | Batch Accuracy 97.38%
# Epoch [4/11] | Batch #227 | Batch Accuracy 97.30%
# Epoch [4/11] | Batch #228 | Batch Accuracy 97.29%
# Epoch [4/11] | Batch #229 | Batch Accuracy 97.28%
# Epoch [4/11] | Batch #230 | Batch Accuracy 97.27%
# Epoch [4/11] | Batch #231 | Batch Accuracy 97.20%
# Epoch [4/11] | Batch #232 | Batch Accuracy 97.13%
# Epoch [4/11] | Batch #233 | Batch Accuracy 97.12%
# Epoch [4/11] | Batch #234 | Batch Accuracy 97.18%
# Epoch [4/11] | Batch #235 | Batch Accuracy 97.18%
# Epoch [4/11] | Batch #236 | Batch Accuracy 97.17%
# Epoch [4/11] | Batch #237 | Batch Accuracy 97.16%
# Epoch [4/11] | Batch #238 | Batch Accuracy 97.22%
# Epoch [4/11] | Batch #239 | Batch Accuracy 97.27%
# Epoch [4/11] | Batch #240 | Batch Accuracy 97.26%
# Epoch [4/11] | Batch #241 | Batch Accuracy 97.31%
# Epoch [4/11] | Batch #242 | Batch Accuracy 97.35%
# Epoch [4/11] | Batch #243 | Batch Accuracy 97.34%
# Epoch [4/11] | Batch #244 | Batch Accuracy 97.39%
# Epoch [4/11] Train Loss: 0.0835 | Train Acc: 97.39% | Val Acc: 93.99% | Val Loss: 0.26%
# Epoch [5/11] | Batch #245 | Batch Accuracy 100.00%
# Epoch [5/11] | Batch #246 | Batch Accuracy 98.44%
# Epoch [5/11] | Batch #247 | Batch Accuracy 98.96%
# Epoch [5/11] | Batch #248 | Batch Accuracy 98.44%
# Epoch [5/11] | Batch #249 | Batch Accuracy 98.75%
# Epoch [5/11] | Batch #250 | Batch Accuracy 97.40%
# Epoch [5/11] | Batch #251 | Batch Accuracy 97.32%
# Epoch [5/11] | Batch #252 | Batch Accuracy 97.66%
# Epoch [5/11] | Batch #253 | Batch Accuracy 97.92%
# Epoch [5/11] | Batch #254 | Batch Accuracy 97.50%
# Epoch [5/11] | Batch #255 | Batch Accuracy 97.73%
# Epoch [5/11] | Batch #256 | Batch Accuracy 97.92%
# Epoch [5/11] | Batch #257 | Batch Accuracy 97.84%
# Epoch [5/11] | Batch #258 | Batch Accuracy 97.54%
# Epoch [5/11] | Batch #259 | Batch Accuracy 97.71%
# Epoch [5/11] | Batch #260 | Batch Accuracy 97.85%
# Epoch [5/11] | Batch #261 | Batch Accuracy 97.98%
# Epoch [5/11] | Batch #262 | Batch Accuracy 97.92%
# Epoch [5/11] | Batch #263 | Batch Accuracy 97.70%
# Epoch [5/11] | Batch #264 | Batch Accuracy 97.34%
# Epoch [5/11] | Batch #265 | Batch Accuracy 97.32%
# Epoch [5/11] | Batch #266 | Batch Accuracy 97.30%
# Epoch [5/11] | Batch #267 | Batch Accuracy 97.42%
# Epoch [5/11] | Batch #268 | Batch Accuracy 97.53%
# Epoch [5/11] | Batch #269 | Batch Accuracy 97.50%
# Epoch [5/11] | Batch #270 | Batch Accuracy 97.60%
# Epoch [5/11] | Batch #271 | Batch Accuracy 97.57%
# Epoch [5/11] | Batch #272 | Batch Accuracy 97.54%
# Epoch [5/11] | Batch #273 | Batch Accuracy 97.52%
# Epoch [5/11] | Batch #274 | Batch Accuracy 97.60%
# Epoch [5/11] | Batch #275 | Batch Accuracy 97.58%
# Epoch [5/11] | Batch #276 | Batch Accuracy 97.46%
# Epoch [5/11] | Batch #277 | Batch Accuracy 97.54%
# Epoch [5/11] | Batch #278 | Batch Accuracy 97.43%
# Epoch [5/11] | Batch #279 | Batch Accuracy 97.41%
# Epoch [5/11] | Batch #280 | Batch Accuracy 97.40%
# Epoch [5/11] | Batch #281 | Batch Accuracy 97.38%
# Epoch [5/11] | Batch #282 | Batch Accuracy 97.37%
# Epoch [5/11] | Batch #283 | Batch Accuracy 97.44%
# Epoch [5/11] | Batch #284 | Batch Accuracy 97.50%
# Epoch [5/11] | Batch #285 | Batch Accuracy 97.56%
# Epoch [5/11] | Batch #286 | Batch Accuracy 97.62%
# Epoch [5/11] | Batch #287 | Batch Accuracy 97.67%
# Epoch [5/11] | Batch #288 | Batch Accuracy 97.66%
# Epoch [5/11] | Batch #289 | Batch Accuracy 97.71%
# Epoch [5/11] | Batch #290 | Batch Accuracy 97.76%
# Epoch [5/11] | Batch #291 | Batch Accuracy 97.74%
# Epoch [5/11] | Batch #292 | Batch Accuracy 97.79%
# Epoch [5/11] | Batch #293 | Batch Accuracy 97.77%
# Epoch [5/11] | Batch #294 | Batch Accuracy 97.75%
# Epoch [5/11] | Batch #295 | Batch Accuracy 97.73%
# Epoch [5/11] | Batch #296 | Batch Accuracy 97.66%
# Epoch [5/11] | Batch #297 | Batch Accuracy 97.64%
# Epoch [5/11] | Batch #298 | Batch Accuracy 97.57%
# Epoch [5/11] | Batch #299 | Batch Accuracy 97.56%
# Epoch [5/11] | Batch #300 | Batch Accuracy 97.60%
# Epoch [5/11] | Batch #301 | Batch Accuracy 97.64%
# Epoch [5/11] | Batch #302 | Batch Accuracy 97.63%
# Epoch [5/11] | Batch #303 | Batch Accuracy 97.67%
# Epoch [5/11] | Batch #304 | Batch Accuracy 97.71%
# Epoch [5/11] | Batch #305 | Batch Accuracy 97.75%
# Epoch [5/11] Train Loss: 0.0768 | Train Acc: 97.75% | Val Acc: 92.07% | Val Loss: 0.26%
# Epoch [6/11] | Batch #306 | Batch Accuracy 100.00%
# Epoch [6/11] | Batch #307 | Batch Accuracy 100.00%
# Epoch [6/11] | Batch #308 | Batch Accuracy 98.96%
# Epoch [6/11] | Batch #309 | Batch Accuracy 99.22%
# Epoch [6/11] | Batch #310 | Batch Accuracy 98.75%
# Epoch [6/11] | Batch #311 | Batch Accuracy 98.44%
# Epoch [6/11] | Batch #312 | Batch Accuracy 98.21%
# Epoch [6/11] | Batch #313 | Batch Accuracy 98.44%
# Epoch [6/11] | Batch #314 | Batch Accuracy 98.26%
# Epoch [6/11] | Batch #315 | Batch Accuracy 98.44%
# Epoch [6/11] | Batch #316 | Batch Accuracy 98.58%
# Epoch [6/11] | Batch #317 | Batch Accuracy 98.44%
# Epoch [6/11] | Batch #318 | Batch Accuracy 98.56%
# Epoch [6/11] | Batch #319 | Batch Accuracy 98.66%
# Epoch [6/11] | Batch #320 | Batch Accuracy 98.54%
# Epoch [6/11] | Batch #321 | Batch Accuracy 98.63%
# Epoch [6/11] | Batch #322 | Batch Accuracy 98.35%
# Epoch [6/11] | Batch #323 | Batch Accuracy 98.44%
# Epoch [6/11] | Batch #324 | Batch Accuracy 98.52%
# Epoch [6/11] | Batch #325 | Batch Accuracy 98.59%
# Epoch [6/11] | Batch #326 | Batch Accuracy 98.66%
# Epoch [6/11] | Batch #327 | Batch Accuracy 98.72%
# Epoch [6/11] | Batch #328 | Batch Accuracy 98.78%
# Epoch [6/11] | Batch #329 | Batch Accuracy 98.70%
# Epoch [6/11] | Batch #330 | Batch Accuracy 98.75%
# Epoch [6/11] | Batch #331 | Batch Accuracy 98.80%
# Epoch [6/11] | Batch #332 | Batch Accuracy 98.73%
# Epoch [6/11] | Batch #333 | Batch Accuracy 98.77%
# Epoch [6/11] | Batch #334 | Batch Accuracy 98.81%
# Epoch [6/11] | Batch #335 | Batch Accuracy 98.75%
# Epoch [6/11] | Batch #336 | Batch Accuracy 98.59%
# Epoch [6/11] | Batch #337 | Batch Accuracy 98.54%
# Epoch [6/11] | Batch #338 | Batch Accuracy 98.58%
# Epoch [6/11] | Batch #339 | Batch Accuracy 98.62%
# Epoch [6/11] | Batch #340 | Batch Accuracy 98.57%
# Epoch [6/11] | Batch #341 | Batch Accuracy 98.61%
# Epoch [6/11] | Batch #342 | Batch Accuracy 98.56%
# Epoch [6/11] | Batch #343 | Batch Accuracy 98.60%
# Epoch [6/11] | Batch #344 | Batch Accuracy 98.64%
# Epoch [6/11] | Batch #345 | Batch Accuracy 98.67%
# Epoch [6/11] | Batch #346 | Batch Accuracy 98.70%
# Epoch [6/11] | Batch #347 | Batch Accuracy 98.74%
# Epoch [6/11] | Batch #348 | Batch Accuracy 98.76%
# Epoch [6/11] | Batch #349 | Batch Accuracy 98.72%
# Epoch [6/11] | Batch #350 | Batch Accuracy 98.68%
# Epoch [6/11] | Batch #351 | Batch Accuracy 98.57%
# Epoch [6/11] | Batch #352 | Batch Accuracy 98.60%
# Epoch [6/11] | Batch #353 | Batch Accuracy 98.57%
# Epoch [6/11] | Batch #354 | Batch Accuracy 98.53%
# Epoch [6/11] | Batch #355 | Batch Accuracy 98.56%
# Epoch [6/11] | Batch #356 | Batch Accuracy 98.59%
# Epoch [6/11] | Batch #357 | Batch Accuracy 98.62%
# Epoch [6/11] | Batch #358 | Batch Accuracy 98.58%
# Epoch [6/11] | Batch #359 | Batch Accuracy 98.50%
# Epoch [6/11] | Batch #360 | Batch Accuracy 98.52%
# Epoch [6/11] | Batch #361 | Batch Accuracy 98.49%
# Epoch [6/11] | Batch #362 | Batch Accuracy 98.52%
# Epoch [6/11] | Batch #363 | Batch Accuracy 98.55%
# Epoch [6/11] | Batch #364 | Batch Accuracy 98.57%
# Epoch [6/11] | Batch #365 | Batch Accuracy 98.59%
# Epoch [6/11] | Batch #366 | Batch Accuracy 98.57%
# Epoch [6/11] Train Loss: 0.0458 | Train Acc: 98.57% | Val Acc: 93.27% | Val Loss: 0.26%
# Epoch [7/11] | Batch #367 | Batch Accuracy 100.00%
# Epoch [7/11] | Batch #368 | Batch Accuracy 100.00%
# Epoch [7/11] | Batch #369 | Batch Accuracy 97.92%
# Epoch [7/11] | Batch #370 | Batch Accuracy 97.66%
# Epoch [7/11] | Batch #371 | Batch Accuracy 98.12%
# Epoch [7/11] | Batch #372 | Batch Accuracy 98.44%
# Epoch [7/11] | Batch #373 | Batch Accuracy 98.66%
# Epoch [7/11] | Batch #374 | Batch Accuracy 98.44%
# Epoch [7/11] | Batch #375 | Batch Accuracy 98.61%
# Epoch [7/11] | Batch #376 | Batch Accuracy 98.75%
# Epoch [7/11] | Batch #377 | Batch Accuracy 98.58%
# Epoch [7/11] | Batch #378 | Batch Accuracy 98.18%
# Epoch [7/11] | Batch #379 | Batch Accuracy 97.84%
# Epoch [7/11] | Batch #380 | Batch Accuracy 97.99%
# Epoch [7/11] | Batch #381 | Batch Accuracy 98.12%
# Epoch [7/11] | Batch #382 | Batch Accuracy 98.05%
# Epoch [7/11] | Batch #383 | Batch Accuracy 98.16%
# Epoch [7/11] | Batch #384 | Batch Accuracy 98.26%
# Epoch [7/11] | Batch #385 | Batch Accuracy 98.36%
# Epoch [7/11] | Batch #386 | Batch Accuracy 98.44%
# Epoch [7/11] | Batch #387 | Batch Accuracy 98.36%
# Epoch [7/11] | Batch #388 | Batch Accuracy 98.44%
# Epoch [7/11] | Batch #389 | Batch Accuracy 98.51%
# Epoch [7/11] | Batch #390 | Batch Accuracy 98.44%
# Epoch [7/11] | Batch #391 | Batch Accuracy 98.38%
# Epoch [7/11] | Batch #392 | Batch Accuracy 98.32%
# Epoch [7/11] | Batch #393 | Batch Accuracy 98.15%
# Epoch [7/11] | Batch #394 | Batch Accuracy 98.10%
# Epoch [7/11] | Batch #395 | Batch Accuracy 98.17%
# Epoch [7/11] | Batch #396 | Batch Accuracy 98.23%
# Epoch [7/11] | Batch #397 | Batch Accuracy 98.29%
# Epoch [7/11] | Batch #398 | Batch Accuracy 98.34%
# Epoch [7/11] | Batch #399 | Batch Accuracy 98.39%
# Epoch [7/11] | Batch #400 | Batch Accuracy 98.35%
# Epoch [7/11] | Batch #401 | Batch Accuracy 98.39%
# Epoch [7/11] | Batch #402 | Batch Accuracy 98.44%
# Epoch [7/11] | Batch #403 | Batch Accuracy 98.31%
# Epoch [7/11] | Batch #404 | Batch Accuracy 98.36%
# Epoch [7/11] | Batch #405 | Batch Accuracy 98.40%
# Epoch [7/11] | Batch #406 | Batch Accuracy 98.28%
# Epoch [7/11] | Batch #407 | Batch Accuracy 98.32%
# Epoch [7/11] | Batch #408 | Batch Accuracy 98.29%
# Epoch [7/11] | Batch #409 | Batch Accuracy 98.33%
# Epoch [7/11] | Batch #410 | Batch Accuracy 98.37%
# Epoch [7/11] | Batch #411 | Batch Accuracy 98.40%
# Epoch [7/11] | Batch #412 | Batch Accuracy 98.37%
# Epoch [7/11] | Batch #413 | Batch Accuracy 98.34%
# Epoch [7/11] | Batch #414 | Batch Accuracy 98.24%
# Epoch [7/11] | Batch #415 | Batch Accuracy 98.28%
# Epoch [7/11] | Batch #416 | Batch Accuracy 98.31%
# Epoch [7/11] | Batch #417 | Batch Accuracy 98.35%
# Epoch [7/11] | Batch #418 | Batch Accuracy 98.38%
# Epoch [7/11] | Batch #419 | Batch Accuracy 98.41%
# Epoch [7/11] | Batch #420 | Batch Accuracy 98.44%
# Epoch [7/11] | Batch #421 | Batch Accuracy 98.47%
# Epoch [7/11] | Batch #422 | Batch Accuracy 98.49%
# Epoch [7/11] | Batch #423 | Batch Accuracy 98.52%
# Epoch [7/11] | Batch #424 | Batch Accuracy 98.49%
# Epoch [7/11] | Batch #425 | Batch Accuracy 98.52%
# Epoch [7/11] | Batch #426 | Batch Accuracy 98.54%
# Epoch [7/11] | Batch #427 | Batch Accuracy 98.57%
# Epoch [7/11] Train Loss: 0.0419 | Train Acc: 98.57% | Val Acc: 93.03% | Val Loss: 0.27%
# Epoch [8/11] | Batch #428 | Batch Accuracy 96.88%
# Epoch [8/11] | Batch #429 | Batch Accuracy 96.88%
# Epoch [8/11] | Batch #430 | Batch Accuracy 97.92%
# Epoch [8/11] | Batch #431 | Batch Accuracy 98.44%
# Epoch [8/11] | Batch #432 | Batch Accuracy 98.75%
# Epoch [8/11] | Batch #433 | Batch Accuracy 98.44%
# Epoch [8/11] | Batch #434 | Batch Accuracy 98.66%
# Epoch [8/11] | Batch #435 | Batch Accuracy 98.83%
# Epoch [8/11] | Batch #436 | Batch Accuracy 98.61%
# Epoch [8/11] | Batch #437 | Batch Accuracy 98.75%
# Epoch [8/11] | Batch #438 | Batch Accuracy 98.86%
# Epoch [8/11] | Batch #439 | Batch Accuracy 98.70%
# Epoch [8/11] | Batch #440 | Batch Accuracy 98.56%
# Epoch [8/11] | Batch #441 | Batch Accuracy 98.66%
# Epoch [8/11] | Batch #442 | Batch Accuracy 98.75%
# Epoch [8/11] | Batch #443 | Batch Accuracy 98.83%
# Epoch [8/11] | Batch #444 | Batch Accuracy 98.90%
# Epoch [8/11] | Batch #445 | Batch Accuracy 98.78%
# Epoch [8/11] | Batch #446 | Batch Accuracy 98.85%
# Epoch [8/11] | Batch #447 | Batch Accuracy 98.91%
# Epoch [8/11] | Batch #448 | Batch Accuracy 98.81%
# Epoch [8/11] | Batch #449 | Batch Accuracy 98.86%
# Epoch [8/11] | Batch #450 | Batch Accuracy 98.91%
# Epoch [8/11] | Batch #451 | Batch Accuracy 98.83%
# Epoch [8/11] | Batch #452 | Batch Accuracy 98.88%
# Epoch [8/11] | Batch #453 | Batch Accuracy 98.80%
# Epoch [8/11] | Batch #454 | Batch Accuracy 98.73%
# Epoch [8/11] | Batch #455 | Batch Accuracy 98.55%
# Epoch [8/11] | Batch #456 | Batch Accuracy 98.60%
# Epoch [8/11] | Batch #457 | Batch Accuracy 98.65%
# Epoch [8/11] | Batch #458 | Batch Accuracy 98.69%
# Epoch [8/11] | Batch #459 | Batch Accuracy 98.73%
# Epoch [8/11] | Batch #460 | Batch Accuracy 98.77%
# Epoch [8/11] | Batch #461 | Batch Accuracy 98.81%
# Epoch [8/11] | Batch #462 | Batch Accuracy 98.84%
# Epoch [8/11] | Batch #463 | Batch Accuracy 98.87%
# Epoch [8/11] | Batch #464 | Batch Accuracy 98.90%
# Epoch [8/11] | Batch #465 | Batch Accuracy 98.85%
# Epoch [8/11] | Batch #466 | Batch Accuracy 98.88%
# Epoch [8/11] | Batch #467 | Batch Accuracy 98.91%
# Epoch [8/11] | Batch #468 | Batch Accuracy 98.86%
# Epoch [8/11] | Batch #469 | Batch Accuracy 98.88%
# Epoch [8/11] | Batch #470 | Batch Accuracy 98.84%
# Epoch [8/11] | Batch #471 | Batch Accuracy 98.86%
# Epoch [8/11] | Batch #472 | Batch Accuracy 98.82%
# Epoch [8/11] | Batch #473 | Batch Accuracy 98.85%
# Epoch [8/11] | Batch #474 | Batch Accuracy 98.87%
# Epoch [8/11] | Batch #475 | Batch Accuracy 98.89%
# Epoch [8/11] | Batch #476 | Batch Accuracy 98.92%
# Epoch [8/11] | Batch #477 | Batch Accuracy 98.94%
# Epoch [8/11] | Batch #478 | Batch Accuracy 98.96%
# Epoch [8/11] | Batch #479 | Batch Accuracy 98.98%
# Epoch [8/11] | Batch #480 | Batch Accuracy 99.00%
# Epoch [8/11] | Batch #481 | Batch Accuracy 99.02%
# Epoch [8/11] | Batch #482 | Batch Accuracy 99.03%
# Epoch [8/11] | Batch #483 | Batch Accuracy 99.05%
# Epoch [8/11] | Batch #484 | Batch Accuracy 99.07%
# Epoch [8/11] | Batch #485 | Batch Accuracy 99.03%
# Epoch [8/11] | Batch #486 | Batch Accuracy 99.05%
# Epoch [8/11] | Batch #487 | Batch Accuracy 99.01%
# Epoch [8/11] | Batch #488 | Batch Accuracy 99.03%
# Epoch [8/11] Train Loss: 0.0336 | Train Acc: 99.03% | Val Acc: 93.03% | Val Loss: 0.28%
# Epoch [9/11] | Batch #489 | Batch Accuracy 96.88%
# Epoch [9/11] | Batch #490 | Batch Accuracy 96.88%
# Epoch [9/11] | Batch #491 | Batch Accuracy 97.92%
# Epoch [9/11] | Batch #492 | Batch Accuracy 98.44%
# Epoch [9/11] | Batch #493 | Batch Accuracy 98.75%
# Epoch [9/11] | Batch #494 | Batch Accuracy 98.96%
# Epoch [9/11] | Batch #495 | Batch Accuracy 98.66%
# Epoch [9/11] | Batch #496 | Batch Accuracy 98.44%
# Epoch [9/11] | Batch #497 | Batch Accuracy 98.61%
# Epoch [9/11] | Batch #498 | Batch Accuracy 98.75%
# Epoch [9/11] | Batch #499 | Batch Accuracy 98.86%
# Epoch [9/11] | Batch #500 | Batch Accuracy 98.70%
# Epoch [9/11] | Batch #501 | Batch Accuracy 98.56%
# Epoch [9/11] | Batch #502 | Batch Accuracy 98.44%
# Epoch [9/11] | Batch #503 | Batch Accuracy 98.54%
# Epoch [9/11] | Batch #504 | Batch Accuracy 98.63%
# Epoch [9/11] | Batch #505 | Batch Accuracy 98.71%
# Epoch [9/11] | Batch #506 | Batch Accuracy 98.78%
# Epoch [9/11] | Batch #507 | Batch Accuracy 98.85%
# Epoch [9/11] | Batch #508 | Batch Accuracy 98.91%
# Epoch [9/11] | Batch #509 | Batch Accuracy 98.96%
# Epoch [9/11] | Batch #510 | Batch Accuracy 99.01%
# Epoch [9/11] | Batch #511 | Batch Accuracy 99.05%
# Epoch [9/11] | Batch #512 | Batch Accuracy 99.09%
# Epoch [9/11] | Batch #513 | Batch Accuracy 99.12%
# Epoch [9/11] | Batch #514 | Batch Accuracy 99.16%
# Epoch [9/11] | Batch #515 | Batch Accuracy 99.19%
# Epoch [9/11] | Batch #516 | Batch Accuracy 99.11%
# Epoch [9/11] | Batch #517 | Batch Accuracy 99.03%
# Epoch [9/11] | Batch #518 | Batch Accuracy 99.06%
# Epoch [9/11] | Batch #519 | Batch Accuracy 99.09%
# Epoch [9/11] | Batch #520 | Batch Accuracy 99.12%
# Epoch [9/11] | Batch #521 | Batch Accuracy 99.15%
# Epoch [9/11] | Batch #522 | Batch Accuracy 99.17%
# Epoch [9/11] | Batch #523 | Batch Accuracy 99.20%
# Epoch [9/11] | Batch #524 | Batch Accuracy 99.22%
# Epoch [9/11] | Batch #525 | Batch Accuracy 99.24%
# Epoch [9/11] | Batch #526 | Batch Accuracy 99.18%
# Epoch [9/11] | Batch #527 | Batch Accuracy 99.20%
# Epoch [9/11] | Batch #528 | Batch Accuracy 99.14%
# Epoch [9/11] | Batch #529 | Batch Accuracy 99.16%
# Epoch [9/11] | Batch #530 | Batch Accuracy 99.18%
# Epoch [9/11] | Batch #531 | Batch Accuracy 99.20%
# Epoch [9/11] | Batch #532 | Batch Accuracy 99.22%
# Epoch [9/11] | Batch #533 | Batch Accuracy 99.24%
# Epoch [9/11] | Batch #534 | Batch Accuracy 99.25%
# Epoch [9/11] | Batch #535 | Batch Accuracy 99.20%
# Epoch [9/11] | Batch #536 | Batch Accuracy 99.09%
# Epoch [9/11] | Batch #537 | Batch Accuracy 99.11%
# Epoch [9/11] | Batch #538 | Batch Accuracy 99.12%
# Epoch [9/11] | Batch #539 | Batch Accuracy 99.14%
# Epoch [9/11] | Batch #540 | Batch Accuracy 99.10%
# Epoch [9/11] | Batch #541 | Batch Accuracy 99.06%
# Epoch [9/11] | Batch #542 | Batch Accuracy 99.07%
# Epoch [9/11] | Batch #543 | Batch Accuracy 99.09%
# Epoch [9/11] | Batch #544 | Batch Accuracy 99.05%
# Epoch [9/11] | Batch #545 | Batch Accuracy 99.07%
# Epoch [9/11] | Batch #546 | Batch Accuracy 99.08%
# Epoch [9/11] | Batch #547 | Batch Accuracy 98.94%
# Epoch [9/11] | Batch #548 | Batch Accuracy 98.96%
# Epoch [9/11] | Batch #549 | Batch Accuracy 98.92%
# Epoch [9/11] Train Loss: 0.0279 | Train Acc: 98.92% | Val Acc: 94.23% | Val Loss: 0.26%
# Epoch [10/11] | Batch #550 | Batch Accuracy 100.00%
# Epoch [10/11] | Batch #551 | Batch Accuracy 100.00%
# Epoch [10/11] | Batch #552 | Batch Accuracy 100.00%
# Epoch [10/11] | Batch #553 | Batch Accuracy 99.22%
# Epoch [10/11] | Batch #554 | Batch Accuracy 99.38%
# Epoch [10/11] | Batch #555 | Batch Accuracy 99.48%
# Epoch [10/11] | Batch #556 | Batch Accuracy 99.55%
# Epoch [10/11] | Batch #557 | Batch Accuracy 99.61%
# Epoch [10/11] | Batch #558 | Batch Accuracy 99.65%
# Epoch [10/11] | Batch #559 | Batch Accuracy 99.69%
# Epoch [10/11] | Batch #560 | Batch Accuracy 99.72%
# Epoch [10/11] | Batch #561 | Batch Accuracy 99.74%
# Epoch [10/11] | Batch #562 | Batch Accuracy 99.76%
# Epoch [10/11] | Batch #563 | Batch Accuracy 99.78%
# Epoch [10/11] | Batch #564 | Batch Accuracy 99.79%
# Epoch [10/11] | Batch #565 | Batch Accuracy 99.80%
# Epoch [10/11] | Batch #566 | Batch Accuracy 99.82%
# Epoch [10/11] | Batch #567 | Batch Accuracy 99.65%
# Epoch [10/11] | Batch #568 | Batch Accuracy 99.34%
# Epoch [10/11] | Batch #569 | Batch Accuracy 99.38%
# Epoch [10/11] | Batch #570 | Batch Accuracy 99.40%
# Epoch [10/11] | Batch #571 | Batch Accuracy 99.43%
# Epoch [10/11] | Batch #572 | Batch Accuracy 99.46%
# Epoch [10/11] | Batch #573 | Batch Accuracy 99.48%
# Epoch [10/11] | Batch #574 | Batch Accuracy 99.50%
# Epoch [10/11] | Batch #575 | Batch Accuracy 99.52%
# Epoch [10/11] | Batch #576 | Batch Accuracy 99.54%
# Epoch [10/11] | Batch #577 | Batch Accuracy 99.55%
# Epoch [10/11] | Batch #578 | Batch Accuracy 99.57%
# Epoch [10/11] | Batch #579 | Batch Accuracy 99.58%
# Epoch [10/11] | Batch #580 | Batch Accuracy 99.60%
# Epoch [10/11] | Batch #581 | Batch Accuracy 99.51%
# Epoch [10/11] | Batch #582 | Batch Accuracy 99.43%
# Epoch [10/11] | Batch #583 | Batch Accuracy 99.45%
# Epoch [10/11] | Batch #584 | Batch Accuracy 99.38%
# Epoch [10/11] | Batch #585 | Batch Accuracy 99.39%
# Epoch [10/11] | Batch #586 | Batch Accuracy 99.41%
# Epoch [10/11] | Batch #587 | Batch Accuracy 99.42%
# Epoch [10/11] | Batch #588 | Batch Accuracy 99.44%
# Epoch [10/11] | Batch #589 | Batch Accuracy 99.45%
# Epoch [10/11] | Batch #590 | Batch Accuracy 99.47%
# Epoch [10/11] | Batch #591 | Batch Accuracy 99.48%
# Epoch [10/11] | Batch #592 | Batch Accuracy 99.35%
# Epoch [10/11] | Batch #593 | Batch Accuracy 99.36%
# Epoch [10/11] | Batch #594 | Batch Accuracy 99.38%
# Epoch [10/11] | Batch #595 | Batch Accuracy 99.39%
# Epoch [10/11] | Batch #596 | Batch Accuracy 99.40%
# Epoch [10/11] | Batch #597 | Batch Accuracy 99.35%
# Epoch [10/11] | Batch #598 | Batch Accuracy 99.36%
# Epoch [10/11] | Batch #599 | Batch Accuracy 99.38%
# Epoch [10/11] | Batch #600 | Batch Accuracy 99.39%
# Epoch [10/11] | Batch #601 | Batch Accuracy 99.40%
# Epoch [10/11] | Batch #602 | Batch Accuracy 99.41%
# Epoch [10/11] | Batch #603 | Batch Accuracy 99.42%
# Epoch [10/11] | Batch #604 | Batch Accuracy 99.43%
# Epoch [10/11] | Batch #605 | Batch Accuracy 99.44%
# Epoch [10/11] | Batch #606 | Batch Accuracy 99.45%
# Epoch [10/11] | Batch #607 | Batch Accuracy 99.46%
# Epoch [10/11] | Batch #608 | Batch Accuracy 99.47%
# Epoch [10/11] | Batch #609 | Batch Accuracy 99.48%
# Epoch [10/11] | Batch #610 | Batch Accuracy 99.49%
# Epoch [10/11] Train Loss: 0.0161 | Train Acc: 99.49% | Val Acc: 93.99% | Val Loss: 0.21%
# Epoch [11/11] | Batch #611 | Batch Accuracy 100.00%
# Epoch [11/11] | Batch #612 | Batch Accuracy 100.00%
# Epoch [11/11] | Batch #613 | Batch Accuracy 100.00%
# Epoch [11/11] | Batch #614 | Batch Accuracy 100.00%
# Epoch [11/11] | Batch #615 | Batch Accuracy 100.00%
# Epoch [11/11] | Batch #616 | Batch Accuracy 100.00%
# Epoch [11/11] | Batch #617 | Batch Accuracy 99.55%
# Epoch [11/11] | Batch #618 | Batch Accuracy 99.61%
# Epoch [11/11] | Batch #619 | Batch Accuracy 99.31%
# Epoch [11/11] | Batch #620 | Batch Accuracy 99.38%
# Epoch [11/11] | Batch #621 | Batch Accuracy 99.43%
# Epoch [11/11] | Batch #622 | Batch Accuracy 99.48%
# Epoch [11/11] | Batch #623 | Batch Accuracy 99.28%
# Epoch [11/11] | Batch #624 | Batch Accuracy 99.33%
# Epoch [11/11] | Batch #625 | Batch Accuracy 99.38%
# Epoch [11/11] | Batch #626 | Batch Accuracy 99.41%
# Epoch [11/11] | Batch #627 | Batch Accuracy 99.45%
# Epoch [11/11] | Batch #628 | Batch Accuracy 99.48%
# Epoch [11/11] | Batch #629 | Batch Accuracy 99.51%
# Epoch [11/11] | Batch #630 | Batch Accuracy 99.38%
# Epoch [11/11] | Batch #631 | Batch Accuracy 99.40%
# Epoch [11/11] | Batch #632 | Batch Accuracy 99.43%
# Epoch [11/11] | Batch #633 | Batch Accuracy 99.46%
# Epoch [11/11] | Batch #634 | Batch Accuracy 99.48%
# Epoch [11/11] | Batch #635 | Batch Accuracy 99.50%
# Epoch [11/11] | Batch #636 | Batch Accuracy 99.52%
# Epoch [11/11] | Batch #637 | Batch Accuracy 99.54%
# Epoch [11/11] | Batch #638 | Batch Accuracy 99.55%
# Epoch [11/11] | Batch #639 | Batch Accuracy 99.57%
# Epoch [11/11] | Batch #640 | Batch Accuracy 99.48%
# Epoch [11/11] | Batch #641 | Batch Accuracy 99.40%
# Epoch [11/11] | Batch #642 | Batch Accuracy 99.41%
# Epoch [11/11] | Batch #643 | Batch Accuracy 99.43%
# Epoch [11/11] | Batch #644 | Batch Accuracy 99.45%
# Epoch [11/11] | Batch #645 | Batch Accuracy 99.46%
# Epoch [11/11] | Batch #646 | Batch Accuracy 99.48%
# Epoch [11/11] | Batch #647 | Batch Accuracy 99.41%
# Epoch [11/11] | Batch #648 | Batch Accuracy 99.42%
# Epoch [11/11] | Batch #649 | Batch Accuracy 99.44%
# Epoch [11/11] | Batch #650 | Batch Accuracy 99.45%
# Epoch [11/11] | Batch #651 | Batch Accuracy 99.47%
# Epoch [11/11] | Batch #652 | Batch Accuracy 99.48%
# Epoch [11/11] | Batch #653 | Batch Accuracy 99.49%
# Epoch [11/11] | Batch #654 | Batch Accuracy 99.50%
# Epoch [11/11] | Batch #655 | Batch Accuracy 99.51%
# Epoch [11/11] | Batch #656 | Batch Accuracy 99.52%
# Epoch [11/11] | Batch #657 | Batch Accuracy 99.53%
# Epoch [11/11] | Batch #658 | Batch Accuracy 99.54%
# Epoch [11/11] | Batch #659 | Batch Accuracy 99.55%
# Epoch [11/11] | Batch #660 | Batch Accuracy 99.56%
# Epoch [11/11] | Batch #661 | Batch Accuracy 99.57%
# Epoch [11/11] | Batch #662 | Batch Accuracy 99.52%
# Epoch [11/11] | Batch #663 | Batch Accuracy 99.53%
# Epoch [11/11] | Batch #664 | Batch Accuracy 99.54%
# Epoch [11/11] | Batch #665 | Batch Accuracy 99.55%
# Epoch [11/11] | Batch #666 | Batch Accuracy 99.55%
# Epoch [11/11] | Batch #667 | Batch Accuracy 99.56%
# Epoch [11/11] | Batch #668 | Batch Accuracy 99.52%
# Epoch [11/11] | Batch #669 | Batch Accuracy 99.52%
# Epoch [11/11] | Batch #670 | Batch Accuracy 99.53%
# Epoch [11/11] | Batch #671 | Batch Accuracy 99.54%
# Epoch [11/11] Train Loss: 0.0161 | Train Acc: 99.54% | Val Acc: 92.79% | Val Loss: 0.27%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▂▅█▆▇▇▇██▇</td></tr><tr><td>validation_loss</td><td>█▆▃▃▃▃▃▃▃▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.01609</td></tr><tr><td>validation_accuracy</td><td>92.78846</td></tr><tr><td>validation_loss</td><td>0.27433</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Vini-HappyWhale-SpeciesDataset-hyperparameters_mod4</strong> at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/6rsfi9d6' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale/runs/6rsfi9d6</a><br> View project at: <a href='https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/vini_k-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260305_160459-6rsfi9d6/logs</code>

# %%
plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_1918377/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Summarize your 3 steps, their success, and what you learned (5 pts)

# %% [markdown]
# *Summary of models and performances (all changes from previous models were kept):*
#
# |Model| Changes Made | Batch Size | Learning Rate | Epochs | Validation Accuracy | Validation Loss
# |-|-|-|-|-|-|-|
# |Original| N/A | 48 | 0.001 | 5 | 48.70% | 1.21 |
# |Model 1| change optimizer to SGD with momentum | 48 | 0.001 | 5 |65.63% | 0.85 |
# |Model 2| lower batch size, increase number of epochs| 32 | 0.001 | 15 | 80.53% | 0.69 |
# |Model 3 | 3 additional image transformations, randomly adjusting color and blur | 32 | 0.001 | 15 | 61.23%| 1.00
#
# *Model 2 was the best performing model, with a final validation accuracy of 80.53% and a validation loss of 0.69. A combination of changing the optimizer to SGD, lowering batch size, and increasing the number of epochs helped improve model performance drastically, from the original validation accuracy of 48.70%.*
#
# *From this assignment, I gained more clarity on machine learning (i.e. the differences between hyperparameters and weights/biases, the concept of gradient descent, and what loss means) and gained exposure to how it can be implemented in Python with PyTorch. I learned how tedious it can be to select and fine tune hyperparameters, and that it may take many iterations for a model to yield desirable performance.*
